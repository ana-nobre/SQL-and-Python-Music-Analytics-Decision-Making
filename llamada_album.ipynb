# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=client, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
def album(genre):
    resultados_album = []

    for offset in range(0, 500, 50):  # hasta 500 resultados (Spotify limita a 1000 máx)
        datos = sp.search(q=f'{genre}', type='album', limit=50, offset=offset)

        for album in datos['albums']['items']:
            release_date = album.get('release_date', '')
            for year in range(2016, 2021):  # años 2016 a 2020
                if release_date.startswith(str(year)):
                    info = {
                        'album': album['name'],
                        'fecha': release_date,
                        'tipo': album['album_type'],
                        'id': album['id']  # puedes eliminar esto si no lo necesitas
                    }
                    print("El nombre del álbum es:", info['album'])
                    print("La fecha de lanzamiento es:", info['fecha'])
                    print("Tipo:", info['tipo'])
                    print("..........")
                    
                    resultados_album.append(info)
                    break

    return resultados_album

# %%
album("pop")
# Out:
# El nombre del álbum es: Pop 2
# La fecha de lanzamiento es: 2017-12-15
# Tipo: album
# ..........
# El nombre del álbum es: Pop
# La fecha de lanzamiento es: 2018-09-07
# Tipo: compilation
# ..........
# El nombre del álbum es: POP
# La fecha de lanzamiento es: 2020-05-29
# Tipo: album
# ..........
# El nombre del álbum es: Pop Español De Los 90
# La fecha de lanzamiento es: 2017-05-19
# Tipo: compilation
# ..........
# El nombre del álbum es: Shoot For The Stars Aim For The Moon
# La fecha de lanzamiento es: 2020-07-03
# Tipo: album
# ..........
# El nombre del álbum es: POP/STARS
# La fecha de lanzamiento es: 2018-11-03
# Tipo: single
# ..........
# El nombre del álbum es: Pop Food
# La fecha de lanzamiento es: 2017-03-25
# Tipo: album
# ..........
# El nombre del álbum es: Pop Decades: 00s
# La fecha de lanzamiento es: 2016-09-02
# Tipo: compilation
# ..........
# El nombre del álbum es: POPSTAR (feat. Drake)
# La fecha de lanzamiento es: 2020-07-17
# Tipo: single
# ..........
# El nombre del álbum es: City Pop
# La fecha de lanzamiento es: 2019-02-15
# Tipo: album
# ..........
# El nombre del álbum es: Popular Monster
# La fecha de lanzamiento es: 2019-11-20
# Tipo: single
# ..........
# El nombre del álbum es: Meet The Woo
# La fecha de lanzamiento es: 2019-07-26
# Tipo: album
# ..........
# El nombre del álbum es: Meet The Woo 2
# La fecha de lanzamiento es: 2020-02-07
# Tipo: album
# ..........
# El nombre del álbum es: POP
# La fecha de lanzamiento es: 2018-12-14
# Tipo: album
# ..........
# El nombre del álbum es: Pop
# La fecha de lanzamiento es: 2017-08-30
# Tipo: single
# ..........
# El nombre del álbum es: Pop Hits 2012-2015
# La fecha de lanzamiento es: 2019-08-09
# Tipo: compilation
# ..........
# El nombre del álbum es: Shoot For The Stars Aim For The Moon (Deluxe)
# La fecha de lanzamiento es: 2020-07-20
# Tipo: album
# ..........
# El nombre del álbum es: POP
# La fecha de lanzamiento es: 2020-12-16
# Tipo: album
# ..........
# El nombre del álbum es: POP
# La fecha de lanzamiento es: 2019-06-28
# Tipo: single
# ..........
# El nombre del álbum es: Pop
# La fecha de lanzamiento es: 2016-10-07
# Tipo: single
# ..........
# El nombre del álbum es: Pop
# La fecha de lanzamiento es: 2017-11-17
# Tipo: single
# ..........
# El nombre del álbum es: POP
# La fecha de lanzamiento es: 2017-03-24
# Tipo: single
# ..........
# El nombre del álbum es: Piano Pop Covers
# La fecha de lanzamiento es: 2019-11-22
# Tipo: album
# ..........
# El nombre del álbum es: Pop Hits for Ballet Class, Vol. 1
# La fecha de lanzamiento es: 2016-08-16
# Tipo: album
# ..........
# El nombre del álbum es: Popstar: Never Stop Never Stopping
# La fecha de lanzamiento es: 2016-06-03
# Tipo: album
# ..........
# El nombre del álbum es: Pop Covers
# La fecha de lanzamiento es: 2020-02-27
# Tipo: album
# ..........
# El nombre del álbum es: La Popi
# La fecha de lanzamiento es: 2020-04-24
# Tipo: single
# ..........
# El nombre del álbum es: Pop Evil
# La fecha de lanzamiento es: 2018-02-16
# Tipo: album
# ..........
# El nombre del álbum es: 2000's Pop Hits
# La fecha de lanzamiento es: 2020-07-03
# Tipo: compilation
# ..........
# El nombre del álbum es: Poppin Bottles
# La fecha de lanzamiento es: 2020-11-06
# Tipo: single
# ..........
# El nombre del álbum es: Azulejos
# La fecha de lanzamiento es: 2017-06-09
# Tipo: album
# ..........
# El nombre del álbum es: POP VIRUS
# La fecha de lanzamiento es: 2018-12-19
# Tipo: album
# ..........
# El nombre del álbum es: WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) [Remix]
# La fecha de lanzamiento es: 2020-06-24
# Tipo: single
# ..........
# El nombre del álbum es: La Voz Popular de América
# La fecha de lanzamiento es: 2017-12-01
# Tipo: album
# ..........
# El nombre del álbum es: Pop Star
# La fecha de lanzamiento es: 2020-12-18
# Tipo: single
# ..........
# El nombre del álbum es: Meet The Woo 2 (Deluxe)
# La fecha de lanzamiento es: 2020-02-12
# Tipo: album
# ..........
# El nombre del álbum es: Meet The Woo 2 (Deluxe)
# La fecha de lanzamiento es: 2020-02-12
# Tipo: album
# ..........
# El nombre del álbum es: Afro Pop, Vol. 1
# La fecha de lanzamiento es: 2020-08-21
# Tipo: album
# ..........
# El nombre del álbum es: I Disagree
# La fecha de lanzamiento es: 2020-01-10
# Tipo: album
# ..........
# El nombre del álbum es: Paranoia Pop
# La fecha de lanzamiento es: 2020-01-01
# Tipo: album
# ..........
# El nombre del álbum es: Popopop
# La fecha de lanzamiento es: 2019-10-04
# Tipo: single
# ..........
# El nombre del álbum es: Popotão Grandão
# La fecha de lanzamiento es: 2018-01-03
# Tipo: single
# ..........
# El nombre del álbum es: Populares de Ayer, Hoy y Siempre al Estilo Faver Producciones, Vol. 2
# La fecha de lanzamiento es: 2019-11-19
# Tipo: compilation
# ..........
# El nombre del álbum es: Golden Years Of Dutch Pop Music
# La fecha de lanzamiento es: 2016-04-08
# Tipo: album
# ..........
# El nombre del álbum es: Classic Pop Rock Solo Piano
# La fecha de lanzamiento es: 2017-07-01
# Tipo: album
# ..........
# El nombre del álbum es: Am I A Girl?
# La fecha de lanzamiento es: 2018-10-31
# Tipo: album
# ..........
# El nombre del álbum es: Pop Goes Classical
# La fecha de lanzamiento es: 2016-12-01
# Tipo: album
# ..........
# El nombre del álbum es: Pop Heart
# La fecha de lanzamiento es: 2018-11-16
# Tipo: album
# ..........
# El nombre del álbum es: Baladas Pop Para Bebés
# La fecha de lanzamiento es: 2017-02-10
# Tipo: album
# ..........
# El nombre del álbum es: Flexin'
# La fecha de lanzamiento es: 2019-06-28
# Tipo: single
# ..........
# El nombre del álbum es: EDM Pop
# La fecha de lanzamiento es: 2019-07-26
# Tipo: compilation
# ..........
# El nombre del álbum es: Pop! Goes the Piano: Let It Go
# La fecha de lanzamiento es: 2016-06-06
# Tipo: album
# ..........
# El nombre del álbum es: Despacito (Versión Pop)
# La fecha de lanzamiento es: 2017-03-17
# Tipo: single
# ..........
# El nombre del álbum es: Cipri Popescu
# La fecha de lanzamiento es: 2020-05-22
# Tipo: album
# ..........
# El nombre del álbum es: Shop: A Pop Opera
# La fecha de lanzamiento es: 2020-03-08
# Tipo: album
# ..........
# El nombre del álbum es: Mary Poppins Returns (Original Motion Picture Soundtrack)
# La fecha de lanzamiento es: 2018-12-07
# Tipo: compilation
# ..........
# El nombre del álbum es: FIXTAPE
# La fecha de lanzamiento es: 2020-08-07
# Tipo: album
# ..........
# El nombre del álbum es: Canciones Infantiles Populares
# La fecha de lanzamiento es: 2020-09-22
# Tipo: album
# ..........
# El nombre del álbum es: Come Over (feat. Popcaan)
# La fecha de lanzamiento es: 2020-10-01
# Tipo: single
# ..........
# El nombre del álbum es: Ya No Vives en Mí (Versión Pop) (feat. Carlos Rivera)
# La fecha de lanzamiento es: 2018-03-23
# Tipo: single
# ..........
# El nombre del álbum es: Piano Pop Covers
# La fecha de lanzamiento es: 2017-09-12
# Tipo: album
# ..........
# El nombre del álbum es: Pop Radio Hits
# La fecha de lanzamiento es: 2020-06-12
# Tipo: compilation
# ..........
# El nombre del álbum es: MPR
# La fecha de lanzamiento es: 2019-06-28
# Tipo: single
# ..........
# El nombre del álbum es: War
# La fecha de lanzamiento es: 2019-10-04
# Tipo: single
# ..........
# El nombre del álbum es: Meet The Woo (Deluxe Version)
# La fecha de lanzamiento es: 2019-09-13
# Tipo: album
# ..........
# El nombre del álbum es: Forever
# La fecha de lanzamiento es: 2018-07-20
# Tipo: album
# ..........
# El nombre del álbum es: 90's Pop Tour (En Vivo) [Deluxe Edition]
# La fecha de lanzamiento es: 2017-07-07
# Tipo: compilation
# ..........
# El nombre del álbum es: Chillout Pop inc. John Legend, Miley Cyrus & John Mayer
# La fecha de lanzamiento es: 2019-04-19
# Tipo: compilation
# ..........
# El nombre del álbum es: We Got That Cool (feat. Afrojack & Icona Pop)
# La fecha de lanzamiento es: 2019-06-28
# Tipo: single
# ..........
# El nombre del álbum es: Poppin’on!
# La fecha de lanzamiento es: 2019-01-30
# Tipo: album
# ..........
# El nombre del álbum es: All The Things She Said
# La fecha de lanzamiento es: 2020-06-03
# Tipo: single
# ..........
# El nombre del álbum es: Violent Pop
# La fecha de lanzamiento es: 2020-03-06
# Tipo: album
# ..........
# El nombre del álbum es: Piano Covers Vol.1 - Relaxing Piano Music - Best of Pop Hits and Classical Piano Masterpieces
# La fecha de lanzamiento es: 2019-11-24
# Tipo: compilation
# ..........
# El nombre del álbum es: Pop Corn e patatine
# La fecha de lanzamiento es: 2018-02-03
# Tipo: single
# ..........
# El nombre del álbum es: POP RETRO
# La fecha de lanzamiento es: 2020-11-13
# Tipo: compilation
# ..........
# El nombre del álbum es: TrapStar Turnt PopStar
# La fecha de lanzamiento es: 2019-05-02
# Tipo: album
# ..........
# El nombre del álbum es: Slide (Remix) (feat. Pop Smoke, A Boogie Wit da Hoodie & Chris Brown) (feat. Pop Smoke)
# La fecha de lanzamiento es: 2020-01-17
# Tipo: single
# ..........
# El nombre del álbum es: Kids Pop
# La fecha de lanzamiento es: 2019-12-13
# Tipo: compilation
# ..........
# El nombre del álbum es: Punk Goes Pop, Vol. 7
# La fecha de lanzamiento es: 2017-07-14
# Tipo: album
# ..........
# El nombre del álbum es: Pop Star
# La fecha de lanzamiento es: 2018-01-27
# Tipo: single
# ..........
# El nombre del álbum es: Pop en español 2000s
# La fecha de lanzamiento es: 2020-08-14
# Tipo: compilation
# ..........
# El nombre del álbum es: Bubblebath
# La fecha de lanzamiento es: 2016-06-10
# Tipo: single
# ..........
# El nombre del álbum es: 100k On A Coupe
# La fecha de lanzamiento es: 2019-12-13
# Tipo: single
# ..........
# El nombre del álbum es: My Type
# La fecha de lanzamiento es: 2018-03-09
# Tipo: single
# ..........
# El nombre del álbum es: PTX Presents: Top Pop, Vol. I
# La fecha de lanzamiento es: 2018-04-13
# Tipo: album
# ..........
# El nombre del álbum es: Candy Pop
# La fecha de lanzamiento es: 2018-01-12
# Tipo: single
# ..........
# El nombre del álbum es: Popcorn Monkey Tiger (Original Motion Picture Soundtrack)
# La fecha de lanzamiento es: 2020-02-27
# Tipo: single
# ..........
# El nombre del álbum es: Evolution Pop_Vol. 1
# La fecha de lanzamiento es: 2016-09-26
# Tipo: compilation
# ..........
# El nombre del álbum es: Baby Yuh Tight
# La fecha de lanzamiento es: 2019-07-03
# Tipo: single
# ..........
# El nombre del álbum es: Mecánica Popular
# La fecha de lanzamiento es: 2019-12-20
# Tipo: album
# ..........
# El nombre del álbum es: 90's Pop Tour, Vol. 3 (En Vivo)
# La fecha de lanzamiento es: 2019-03-29
# Tipo: compilation
# ..........
# El nombre del álbum es: Family
# La fecha de lanzamiento es: 2017-10-30
# Tipo: single
# ..........
# [{'album': 'Pop 2',
#   'fecha': '2017-12-15',
#   'tipo': 'album',
#   'id': '2HIwUmdxEl7SeWa1ndH5wC'},
#  {'album': 'Pop',
#   'fecha': '2018-09-07',
#   'tipo': 'compilation',
#   'id': '0mCLQVHEZ3X8k4sE0yyNZq'},
#  {'album': 'POP',
#   'fecha': '2020-05-29',
#   'tipo': 'album',
#   'id': '78qD6T34x0zDcg3PFyh4zl'},
#  {'album': 'Pop Español De Los 90',
#   'fecha': '2017-05-19',
#   'tipo': 'compilation',
#   'id': '5Qk1y41EXPWr98u1TsH35Y'},
#  {'album': 'Shoot For The Stars Aim For The Moon',
#   'fecha': '2020-07-03',
#   'tipo': 'album',
#   'id': '7e7t0MCrNDcJZsPwUKjmOc'},
#  {'album': 'POP/STARS',
#   'fecha': '2018-11-03',
#   'tipo': 'single',
#   'id': '0UnBZ8laFgLUq5Ty5vbikQ'},
#  {'album': 'Pop Food',
#   'fecha': '2017-03-25',
#   'tipo': 'album',
#   'id': '1RHa1VdX6lsLbeedgsV1cb'},
#  {'album': 'Pop Decades: 00s',
#   'fecha': '2016-09-02',
#   'tipo': 'compilation',
#   'id': '2qJqTqEUp5TD9CNie4XMtg'},
#  {'album': 'POPSTAR (feat. Drake)',
#   'fecha': '2020-07-17',
#   'tipo': 'single',
#   'id': '5nNtpPsSUgb9Hlb3dF1gXa'},
#  {'album': 'City Pop',
#   'fecha': '2019-02-15',
#   'tipo': 'album',
#   'id': '249z3MS2m8SeEeDuoDVjWB'},
#  {'album': 'Popular Monster',
#   'fecha': '2019-11-20',
#   'tipo': 'single',
#   'id': '4gxFqhVYU4wp1XDH1KiIo4'},
#  {'album': 'Meet The Woo',
#   'fecha': '2019-07-26',
#   'tipo': 'album',
#   'id': '6d1vGZsr6Uy3h9IigBpPAf'},
#  {'album': 'Meet The Woo 2',
#   'fecha': '2020-02-07',
#   'tipo': 'album',
#   'id': '4MZnolldq7ciKKlbVDzLm5'},
#  {'album': 'POP',
#   'fecha': '2018-12-14',
#   'tipo': 'album',
#   'id': '0szC3aA7V8qdBFRbHZwlX6'},
#  {'album': 'Pop',
#   'fecha': '2017-08-30',
#   'tipo': 'single',
#   'id': '223iwdcpZPEO9xnXJtrZMo'},
#  {'album': 'Pop Hits 2012-2015',
#   'fecha': '2019-08-09',
#   'tipo': 'compilation',
#   'id': '51Z21bW6Pc6JRx9Iob7gno'},
#  {'album': 'Shoot For The Stars Aim For The Moon (Deluxe)',
#   'fecha': '2020-07-20',
#   'tipo': 'album',
#   'id': '2MDU46hcBn3u94s46BOSdv'},
#  {'album': 'POP',
#   'fecha': '2020-12-16',
#   'tipo': 'album',
#   'id': '71O4TeeWwhkw1Mw2fYM3le'},
#  {'album': 'POP',
#   'fecha': '2019-06-28',
#   'tipo': 'single',
#   'id': '1VrLTUE5ivuWa49Cd63MSx'},
#  {'album': 'Pop',
#   'fecha': '2016-10-07',
#   'tipo': 'single',
#   'id': '7D7qUgx5iAYJ0TaGsuQqTv'},
#  {'album': 'Pop',
#   'fecha': '2017-11-17',
#   'tipo': 'single',
#   'id': '4vVaGBF0V6Gwz1Ni243DE5'},
#  {'album': 'POP',
#   'fecha': '2017-03-24',
#   'tipo': 'single',
#   'id': '1l7q5CXuXdKs2rmYMEBSiS'},
#  {'album': 'Piano Pop Covers',
#   'fecha': '2019-11-22',
#   'tipo': 'album',
#   'id': '1KQhp9DHKaTIHws6iwgtyd'},
#  {'album': 'Pop Hits for Ballet Class, Vol. 1',
#   'fecha': '2016-08-16',
#   'tipo': 'album',
#   'id': '2hS9jwGmDYaQiZAZdoJTnf'},
#  {'album': 'Popstar: Never Stop Never Stopping',
#   'fecha': '2016-06-03',
#   'tipo': 'album',
#   'id': '07fcZXkBS0y4Y80GT60PZq'},
#  {'album': 'Pop Covers',
#   'fecha': '2020-02-27',
#   'tipo': 'album',
#   'id': '3Njb7Inlc8IO9Er1HkXYoC'},
#  {'album': 'La Popi',
#   'fecha': '2020-04-24',
#   'tipo': 'single',
#   'id': '1RhIzoLC3C9dyDu4E2X0Sg'},
#  {'album': 'Pop Evil',
#   'fecha': '2018-02-16',
#   'tipo': 'album',
#   'id': '3qytVWeUzpO3PkxPWurIfY'},
#  {'album': "2000's Pop Hits",
#   'fecha': '2020-07-03',
#   'tipo': 'compilation',
#   'id': '0jGr47rDzTuy8LH1kgf56D'},
#  {'album': 'Poppin Bottles',
#   'fecha': '2020-11-06',
#   'tipo': 'single',
#   'id': '1QCMJsTQC8osFp4j35PyKM'},
#  {'album': 'Azulejos',
#   'fecha': '2017-06-09',
#   'tipo': 'album',
#   'id': '1hpTHSEosXRl8z47mcRL2J'},
#  {'album': 'POP VIRUS',
#   'fecha': '2018-12-19',
#   'tipo': 'album',
#   'id': '7oFLY1YL5bBI32UHsmQO6q'},
#  {'album': 'WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) [Remix]',
#   'fecha': '2020-06-24',
#   'tipo': 'single',
#   'id': '36jrqYRpGVpJqztuqCii22'},
#  {'album': 'La Voz Popular de América',
#   'fecha': '2017-12-01',
#   'tipo': 'album',
#   'id': '6ymFtmeQp25jwk5KOOZ5qZ'},
#  {'album': 'Pop Star',
#   'fecha': '2020-12-18',
#   'tipo': 'single',
#   'id': '3NQ8KvOzujCdmQYohAm4lS'},
#  {'album': 'Meet The Woo 2 (Deluxe)',
#   'fecha': '2020-02-12',
#   'tipo': 'album',
#   'id': '5NTOvCGu7HT4DgJGLXtKUU'},
#  {'album': 'Meet The Woo 2 (Deluxe)',
#   'fecha': '2020-02-12',
#   'tipo': 'album',
#   'id': '5NTOvCGu7HT4DgJGLXtKUU'},
#  {'album': 'Afro Pop, Vol. 1',
#   'fecha': '2020-08-21',
#   'tipo': 'album',
#   'id': '6GHHoK6LC0Y36nYsouK8qR'},
#  {'album': 'I Disagree',
#   'fecha': '2020-01-10',
#   'tipo': 'album',
#   'id': '4uTce2w80loIu3oLnW0irN'},
#  {'album': 'Paranoia Pop',
#   'fecha': '2020-01-01',
#   'tipo': 'album',
#   'id': '7uBGiYnTpzMqcyQtxaYgIy'},
#  {'album': 'Popopop',
#   'fecha': '2019-10-04',
#   'tipo': 'single',
#   'id': '0JJoNDGjK0N0SolzcDQpbX'},
#  {'album': 'Popotão Grandão',
#   'fecha': '2018-01-03',
#   'tipo': 'single',
#   'id': '0DWDEZ0R8mkCVvVZJXOIcN'},
#  {'album': 'Populares de Ayer, Hoy y Siempre al Estilo Faver Producciones, Vol. 2',
#   'fecha': '2019-11-19',
#   'tipo': 'compilation',
#   'id': '1RuhW2TlKPoDG7iPNjACad'},
#  {'album': 'Golden Years Of Dutch Pop Music',
#   'fecha': '2016-04-08',
#   'tipo': 'album',
#   'id': '5YKFdp4rB34KOsF8RlvhaI'},
#  {'album': 'Classic Pop Rock Solo Piano',
#   'fecha': '2017-07-01',
#   'tipo': 'album',
#   'id': '57kSkTUkVpS12Qwlx7kJrS'},
#  {'album': 'Am I A Girl?',
#   'fecha': '2018-10-31',
#   'tipo': 'album',
#   'id': '5QCXxPUwoOtxeZQmve6w2u'},
#  {'album': 'Pop Goes Classical',
#   'fecha': '2016-12-01',
#   'tipo': 'album',
#   'id': '4LVqqBFHCYUSPOvW5ug4T9'},
#  {'album': 'Pop Heart',
#   'fecha': '2018-11-16',
#   'tipo': 'album',
#   'id': '3QdnfBO9mFeajNbJt9Kc9R'},
#  {'album': 'Baladas Pop Para Bebés',
#   'fecha': '2017-02-10',
#   'tipo': 'album',
#   'id': '7xDscOkU9g17j2358RSdsz'},
#  {'album': "Flexin'",
#   'fecha': '2019-06-28',
#   'tipo': 'single',
#   'id': '5jSifSNBzx4irk78gafWld'},
#  {'album': 'EDM Pop',
#   'fecha': '2019-07-26',
#   'tipo': 'compilation',
#   'id': '1jUrKJ92gmAN9OuW7CFwYG'},
#  {'album': 'Pop! Goes the Piano: Let It Go',
#   'fecha': '2016-06-06',
#   'tipo': 'album',
#   'id': '1yCQq7asGwpK3q2XXCrCWl'},
#  {'album': 'Despacito (Versión Pop)',
#   'fecha': '2017-03-17',
#   'tipo': 'single',
#   'id': '7bX9PK9BzyHuGAe8kEkm8o'},
#  {'album': 'Cipri Popescu',
#   'fecha': '2020-05-22',
#   'tipo': 'album',
#   'id': '0IQzZgL3u8uAmyMutPuDrn'},
#  {'album': 'Shop: A Pop Opera',
#   'fecha': '2020-03-08',
#   'tipo': 'album',
#   'id': '1PzQlma9FcRRGwMDmJIUyX'},
#  {'album': 'Mary Poppins Returns (Original Motion Picture Soundtrack)',
#   'fecha': '2018-12-07',
#   'tipo': 'compilation',
#   'id': '4A5q8ZjS2S7kXoixcEU81B'},
#  {'album': 'FIXTAPE',
#   'fecha': '2020-08-07',
#   'tipo': 'album',
#   'id': '0fwiBiv1i0rJzdJGCaHVJi'},
#  {'album': 'Canciones Infantiles Populares',
#   'fecha': '2020-09-22',
#   'tipo': 'album',
#   'id': '44C66Lqezo9YbR86nUiwEb'},
#  {'album': 'Come Over (feat. Popcaan)',
#   'fecha': '2020-10-01',
#   'tipo': 'single',
#   'id': '6sYqQ3Pem0Ml376lKx545S'},
#  {'album': 'Ya No Vives en Mí (Versión Pop) (feat. Carlos Rivera)',
#   'fecha': '2018-03-23',
#   'tipo': 'single',
#   'id': '0LVHlONPmYwOA6jo73LphN'},
#  {'album': 'Piano Pop Covers',
#   'fecha': '2017-09-12',
#   'tipo': 'album',
#   'id': '3dSptSGsJ9JQL96xd7UCXq'},
#  {'album': 'Pop Radio Hits',
#   'fecha': '2020-06-12',
#   'tipo': 'compilation',
#   'id': '5RXLPN2xwdmjSQNiUgcu9a'},
#  {'album': 'MPR',
#   'fecha': '2019-06-28',
#   'tipo': 'single',
#   'id': '7wEkFJd7KaysobIVuxEYK6'},
#  {'album': 'War',
#   'fecha': '2019-10-04',
#   'tipo': 'single',
#   'id': '7rF0hkAw7bmas9Cd44F7tA'},
#  {'album': 'Meet The Woo (Deluxe Version)',
#   'fecha': '2019-09-13',
#   'tipo': 'album',
#   'id': '22py1IeIi51c0GBYEHQTsI'},
#  {'album': 'Forever',
#   'fecha': '2018-07-20',
#   'tipo': 'album',
#   'id': '0xAUnt43o2FfxIpVFusIOq'},
#  {'album': "90's Pop Tour (En Vivo) [Deluxe Edition]",
#   'fecha': '2017-07-07',
#   'tipo': 'compilation',
#   'id': '2l8I8czsY9vkIk1XiEKqYD'},
#  {'album': 'Chillout Pop inc. John Legend, Miley Cyrus & John Mayer',
#   'fecha': '2019-04-19',
#   'tipo': 'compilation',
#   'id': '5BdNKHK0QXHikKIBLTPn7P'},
#  {'album': 'We Got That Cool (feat. Afrojack & Icona Pop)',
#   'fecha': '2019-06-28',
#   'tipo': 'single',
#   'id': '1WowOfXnw3DlwgjyzlAU4Q'},
#  {'album': 'Poppin’on!',
#   'fecha': '2019-01-30',
#   'tipo': 'album',
#   'id': '0nZBP6rFExXXOWY1KS6Pp0'},
#  {'album': 'All The Things She Said',
#   'fecha': '2020-06-03',
#   'tipo': 'single',
#   'id': '2rlUn38lFbYiBZ7L43gezd'},
#  {'album': 'Violent Pop',
#   'fecha': '2020-03-06',
#   'tipo': 'album',
#   'id': '28Ea3E7Q5qCmmA9N5W1b6y'},
#  {'album': 'Piano Covers Vol.1 - Relaxing Piano Music - Best of Pop Hits and Classical Piano Masterpieces',
#   'fecha': '2019-11-24',
#   'tipo': 'compilation',
#   'id': '1tYjSzyYkyrH7bZksF94kk'},
#  {'album': 'Pop Corn e patatine',
#   'fecha': '2018-02-03',
#   'tipo': 'single',
#   'id': '6mPaoN4CuGmUJiKaC07tOA'},
#  {'album': 'POP RETRO',
#   'fecha': '2020-11-13',
#   'tipo': 'compilation',
#   'id': '3a2G1poas0eVM9n2mrcHLB'},
#  {'album': 'TrapStar Turnt PopStar',
#   'fecha': '2019-05-02',
#   'tipo': 'album',
#   'id': '3TaYhEM7MtqukeISKBV2cx'},
#  {'album': 'Slide (Remix) (feat. Pop Smoke, A Boogie Wit da Hoodie & Chris Brown) (feat. Pop Smoke)',
#   'fecha': '2020-01-17',
#   'tipo': 'single',
#   'id': '7LMJKPGcBZjZf6AEnTBS2t'},
#  {'album': 'Kids Pop',
#   'fecha': '2019-12-13',
#   'tipo': 'compilation',
#   'id': '1v8OP8prEC0luhaal9pnNp'},
#  {'album': 'Punk Goes Pop, Vol. 7',
#   'fecha': '2017-07-14',
#   'tipo': 'album',
#   'id': '3vpUxVKjm32bKN7c3LkNxU'},
#  {'album': 'Pop Star',
#   'fecha': '2018-01-27',
#   'tipo': 'single',
#   'id': '3fCSLSzf73ev11EexQCc1U'},
#  {'album': 'Pop en español 2000s',
#   'fecha': '2020-08-14',
#   'tipo': 'compilation',
#   'id': '43Ptsn8IU9OsX45mZfImh7'},
#  {'album': 'Bubblebath',
#   'fecha': '2016-06-10',
#   'tipo': 'single',
#   'id': '1LXJcgThDI0rAJRBkRk07s'},
#  {'album': '100k On A Coupe',
#   'fecha': '2019-12-13',
#   'tipo': 'single',
#   'id': '1RUkOaQD5teWHg7JmrVBGB'},
#  {'album': 'My Type',
#   'fecha': '2018-03-09',
#   'tipo': 'single',
#   'id': '2n9E00mcUGhx68j2dIMm2q'},
#  {'album': 'PTX Presents: Top Pop, Vol. I',
#   'fecha': '2018-04-13',
#   'tipo': 'album',
#   'id': '2viOlnLfhPLDgx7hvBqLwW'},
#  {'album': 'Candy Pop',
#   'fecha': '2018-01-12',
#   'tipo': 'single',
#   'id': '0dbDXtPkq4b4zViH3q9Lnt'},
#  {'album': 'Popcorn Monkey Tiger (Original Motion Picture Soundtrack)',
#   'fecha': '2020-02-27',
#   'tipo': 'single',
#   'id': '75ipHe75TC6oeu55f3i5HW'},
#  {'album': 'Evolution Pop_Vol. 1',
#   'fecha': '2016-09-26',
#   'tipo': 'compilation',
#   'id': '4aV8utpD8x5Oi6wjNXyTxb'},
#  {'album': 'Baby Yuh Tight',
#   'fecha': '2019-07-03',
#   'tipo': 'single',
#   'id': '3dbDhLa65ItnO8LaTQuStP'},
#  {'album': 'Mecánica Popular',
#   'fecha': '2019-12-20',
#   'tipo': 'album',
#   'id': '4Z1Q71sHLNHcnT5OpSZjtS'},
#  {'album': "90's Pop Tour, Vol. 3 (En Vivo)",
#   'fecha': '2019-03-29',
#   'tipo': 'compilation',
#   'id': '7tgRSKkKYFx5VLr47P8Dqa'},
#  {'album': 'Family',
#   'fecha': '2017-10-30',
#   'tipo': 'single',
#   'id': '09pESGCreuRO6zGh6Sfloy'}]

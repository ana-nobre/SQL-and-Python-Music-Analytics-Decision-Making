# %%
import requests
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="api.env")

api_key = os.getenv("API_KEY_LASTFM")  # Asegurate de que este nombre coincide con tu archivo .env

# %%
import json
import pandas as pd

# %%
import csv
with open('list_artist_jazz.csv', "r") as archivo:
    lector = csv.reader(archivo)
    lista = list(lector)

# %%
def stats(artist, api_key):
    url = 'http://ws.audioscrobbler.com/2.0/'
    params = {
        'method': 'artist.getinfo',
        'artist' : artist,
        'api_key':  api_key,
        'format': 'json',
        'lang': 'es'
        }

    response = requests.get(url, params=params)
    if response.status_code != 200:
        print(f"Da error")
    else:
        datos = response.json()
        info = datos['artist']['stats'] #extraer listeners y plays por separado
        info_artista = {
            'artista': artist, 
            'oyentes': info.get('listeners'),
            'reproducciones': info.get('playcount')}
        
    return info_artista

# %%
stats("Bach",api_key)
# Out:
# {'artista': 'Bach', 'oyentes': '15568', 'reproducciones': '252571'}

# %%
for i in lista:
    print(i)
# Out:
# ['Gari']
# ['Joan Colomo']
# ['Familia Caamagno']
# ['Los Negativos']
# ['Igor Paskual']
# ['Los Hermanos Cubero']
# ['Sergio Dalma']
# ['Loquillo']
# ['Petti']
# ['Lauroba']
# ['Altxatu']
# ['Bomba Estéreo']
# ['Jammin´ Dose']
# ['Los Rebeldes']
# ['Aerolineas Federales']
# ['Pep Sala']
# ['Arco']
# ['Nocturnos']
# ['Cybee']
# ['Comandante Twin']
# ['Physis Versus Nomos']
# ['Eskean Kristö']
# ['Rukula']
# ['Maki']
# ['Embusteros']
# ['Bantastic Fand']
# ['The Prussians']
# ['Bastille']
# ['Xiula']
# ['Bluestain']
# ['Eraso!']
# ['Oskorri']
# ['Atzembla']
# ['The Kleejoss Band']
# ['Os Resentidos']
# ['La Porta Dels Somnis']
# ['Track Dogs']
# ['The Oddballs']
# ['Young Forest']
# ['Tano!']
# ['Terratombats']
# ['Bely Basarte']
# ['Lildami']
# ['Salto']
# ['Bultz!']
# ['Pepet I Marieta']
# ['Correcaminos Rock and Roll Band']
# ['Pablo Valdés']
# ['Pelax']
# ['Rulo y la contrabanda']
# ['The Gift']
# ['La Terrasseta de Preixens']
# ['O Sonoro Maxín']
# ['Txapelpunk']
# ['Raimon']
# ['La Unión']
# ['The Sick Boys']
# ['Dixebra']
# ['Dio']
# ['El Mató a un Policía Motorizado']
# ['Lucas Masciano']
# ['Miquel Abras']
# ['Sidecars']
# ['Banda de Gaites Villa de Xixón']
# ['Quico El Célio, El Noi I El Mut De Ferreries']
# ['Cesk Freixas']
# ['El Chico Amperio']
# ['Juanes']
# ['Sherish']
# ['Isla Iglú']
# ['Hendrik Röver']
# ['Faith No More']
# ['Alex Ubago']
# ['Melange']
# ['Strombers']
# ['Joseba Tapia']
# ['Feliu Ventura']
# ['Astarot']
# ['Autumn Comets']
# ['Molina Molina']
# ['Animal']
# ['Roy Orbison']
# ['Camilo Séptimo']
# ['Efecto Pasillo']
# ['Robbie Williams']
# ['The Potes']
# ['Nat Simons']
# ['Álvaro Urquijo']
# ['Perlata']
# ['Caboverde']
# ['Minor Empires']
# ['Tregua']
# ['Nyandú']
# ['Ochobre']
# ['Koel']
# ['Mikel Laboa']
# ['Egurra Ta Kitto']
# ['Lluis Llach']
# ['MARLENA']
# ['La Trinca']
# ['Stai Zitto']
# ['Dinamita Pa Los Pollos']
# ['Gotelé']
# ['Quimi Portet']
# ['Tachenko']
# ['Xarim Aresté']
# ['Chelsea Boots']
# ['Dakidarria']
# ['Gimnástica']
# ['EraBatera']
# ['Duran Duran']
# ['Ñekü']
# ['Los Gatos del Gitano']
# ['Grises']
# ['ALIS']
# ['Los Retrovisores']
# ['Mujeres']
# ['ENMA FERNÁNDEZ']
# ['Da Igual']
# ['Kiko Veneno']
# ['Skama la rede']
# ['Itaca Band']
# ['Nixon']
# ['Qverno']
# ['Vaquero']
# ['Alejandro Conde']
# ['Barricada']
# ['Urtz']
# ['La Vil Canalla']
# ['Durango14']
# ['Ruxe Ruxe']
# ['Xabi Bandini']
# ['Ataque Escampe']
# ['Zona Oscura']
# ['Os Amigos dos Músicos']
# ['Miquel Gil']
# ['Melendi']
# ['The Cardigans']
# ['Wham!']
# ['Planet Funk']
# ['Jofre Bardagí']
# ['Ezpalak']
# ['Liher']
# ['Los Piratas']
# ['Sanjosex']
# ['Airbag']
# ['Nueva Vulcano']
# ['Mentah']
# ['Shinova']
# ['Mexican Institute Of Sound']
# ['Cobra']
# ['Miss Caffeina']
# ['Fito y Fitipaldis']
# ['Bestia Bebé']
# ['Keu Agirretxea']
# ['Habi']
# ['Los Marañones']
# ['Cris Juanico']
# ['Elbicho']
# ['CLAIM']
# ['El Belda i el Conjunt Badabadoc']
# ['Thee Braindrops']
# ['Triana']
# ['Marlon']
# ['Joan Miquel Oliver']
# ['Mägo de Oz']
# ['Jabier Muguruza']
# ['Toulouse']
# ['Pastora Soler']
# ['Los Delinqüentes']
# ['Los Secretos']
# ['Jarabe De Palo']
# ['Diego Martín']
# ['107 Faunos']
# ['Tomeu Penya']
# ['El Sueño de Morfeo']
# ['Lynyrd Skynyrd']
# ['Carmen 113']
# ['La Pegatina']
# ['Etxe']
# ['Txuma Murugarren']
# ['Javier Ojeda']
# ['Etsaiak']
# ['Izeberg']
# ['Brioles']
# ['Destino 48']
# ['Capsula']
# ['Huecco']
# ['Vinicio Capossela']
# ['Atencion Tsunami']
# ['El Diluvi']
# ['Pokers']
# ['Texxcoco']
# ['Adrià Puntí']
# ['Ivette Nadal']
# ["Jane's Addiction"]
# ['La Gossa Sorda']
# ['Roger Usart']
# ['Jacobo Serra']
# ['Kokein']
# ['Eneritz Furyak']
# ['Gatoperro']
# ['Isma Romero']
# ['Imperio Argentina']
# ['Rafa Rueda']
# ["L'Hereu Escampa"]
# ['Stormy Mondays']
# ['Sofa']
# ['Camela']
# ['Kadebostany']
# ['Vuit']
# ['La Caja De Pandora']
# ['OBESES']
# ['Amateur']
# ['Odolaren Mintzoa']
# ['Leiva']
# ['Corizonas']
# ['La Fuga']
# ['Los Rodriguez']
# ['Nunatak']
# ['Vera Fauna']
# ['Vaho']
# ['Hora de Joglar']
# ['Sylvia Pantoja']
# ['Mota Blues']
# ['Cuello']
# ['Iker Lauroba']
# ['Sartenazo Cerebral']
# ['Mario Cobo']
# ['Dionne Warwick']
# ['Yo Ciervo']
# ['Duncan Dhu']
# ['Willis Drummond']
# ['Merche']
# ['The Lákazans']
# ['Caso Omiso']
# ['Skasti']
# ['Disco Las Palmeras!']
# ['The Soulbreaker Company']
# ['M I C E']
# ['Laurel Aitken']
# ['Suso Díaz']
# ['The Steel Elms']
# ['F/E/A']
# ['Filippo Landini']
# ['Ramon Muntaner']
# ['Moris']
# ['Habitar La Mar']
# ['Fetus']
# ['Vanesa Martín']
# ['Ruiperez']
# ['Crudo Pimento']
# ['El Niño del Pegamento']
# ['Niko Etxart']
# ['Monna Bell']
# ['Laid']
# ['Joan Masdéu']
# ['Onki Xin']
# ['Karina']
# ['Bobby Freeman']
# ['Belen Arjona']
# ['Los eternos']
# ['Las Gipsy Rock']
# ['ChocQuibTown']
# ['Barón Rojo']
# ['We Are Standard']
# ['Maldita Nerea']
# ['Madee']
# ['Pitovnis']
# ['Jorge Drexler']
# ['Quique González']
# ['Hyedra']
# ['Siniestro Total']
# ['Kazzabe']
# ['Los Lobos']
# ['Germà Negre']
# ['Sisters of Mercy']
# ['Playa Cuberris']
# ['MARTIRES DEL COMPAS']
# ['Luback']
# ['Javiera Mena']
# ['Los Romanticos de Zacatecas']
# ['Desorden Público']
# ['Lion Heart']
# ['Zumbis Do Espaço']
# ['DeWolff']
# ['Piel Camaleón']
# ['Richie Furay']
# ['Hilma Nikolaisen']
# ['Terrier']
# ['Capitán Mandarina']
# ['Psiconautas']
# ['Don Middlebrook']
# ['Don Vilanova Botafogo']
# ['Guillermo Anderson']
# ['Óscar Chávez']
# ['Litto Nebbia']
# ['Kaela Kimura']
# ['Lo Straniero']
# ['Pile']
# ['1280 Almas']
# ['Desmond Dekker']
# ['Edca']
# ['Matrioska']
# ['Juanse']
# ['Johnny Thunders']
# ['Manfred Krug']
# ['Jetstream']
# ['Sine Frontera']
# ['Las Moskas']
# ['The Drifters']
# ['Foghat']
# ['Los Kahunas']
# ['Oysterband']
# ['Dúo Orquesta Regalizes']
# ['Raça']
# ['Will Hoge']
# ['The Tin Cans']
# ['The Rain']
# ['Widespread Panic']
# ['Niña ']
# ['Scarcéus']
# ['La Rondalla De Saltillo']
# ['Los Muecas']
# ['Chalk Dinosaur']
# ['Plutão Já Foi Planeta']
# ['Tenpel']
# ['Sundara Karma']
# ['Midway']
# ['Cowboys Espirituais']
# ['Faces']
# ['Neu Matter']
# ['Baltasar Comotto']
# ['Czarno-Czarni']
# ['Sons de Saturno']
# ['Cartel da Cevada']
# ['Buddy Guy']
# ['MAD3']
# ['Luke Bryan']
# ['MUGO']
# ['The Beau Brummels']
# ['Fus Delei']
# ['The Cavernarios']
# ['Lichis']
# ['Estrela Leminski']
# ['Super Furry Animals']
# ['Skapulario']
# ['Sound Bullet']
# ['The Cars']
# ['The Chuck Norris Experiment']
# ['Mad At The World']
# ['Colorstone']
# ['P.O.D.']
# ['Heavy Nopal']
# ['Baker Knight']
# ['The Hazzah']
# ['Bobby Rydell']
# ['The Velvet Underground']
# ['The Shadows Of Knight']
# ['Acústicos & Valvulados']
# ['Snareset']
# ['Hawkwind']
# ['Centavrvs']
# ['Bread']
# ['The Stooges']
# ['The Flying Burrito Brothers']
# ['The Wailers']
# ['La Scelta']
# ['Danilo Rudah']
# ['João Lopes']
# ['Urgatz']
# ['Pau Alabajos']
# ['Roger Mas']
# ['Foster The People']
# ['Radio Océano']
# ['Twanguero']
# ['La Oreja de Van Gogh']
# ['Carlos Madrid']
# ['Santiago Delgado y los Runaway Lovers']
# ['Bob Dylan']
# ['Jo Jet i Maria Ribot']
# ['Los Straitjackets']
# ['Fiona Apple']
# ['M-Clan']
# ['Alfredo González']
# ['Kitai']
# ['Amaral']
# ['Sutan']
# ['Las Aspiradoras']
# ['Pupil·les']
# ['Roberto Casalino']
# ['Ok Pirámides']
# ['Los Estramboticos']
# ['Supercobra']
# ['Señor Naranjo']
# ['The Blasters']
# ['Le Butcherettes']
# ['Ana Tijoux']
# ['Gustavo Kaly']
# ['Big John Bates']
# ['WHY@DOLL']
# ['Fresno']
# ['No More Lies']
# ['Justin Townes Earle']
# ['Renato Borghetti']
# ['Hungría']
# ['Jardim Soma']
# ['The Scaners']
# ['Rod Levario']
# ['Paulo Ricardo']
# ['Sublime With Rome']
# ['Smile And Burn']
# ['Ben E. King']
# ['The Short Fuses']
# ['Botellita De Jerez']
# ['Rheostatics']
# ['Courtney Marie Andrews']
# ['anorak.']
# ['Hillbilly Rawhide']
# ['JACK BORIS']
# ['The Red Lights Gang']
# ["Los Baby's"]
# ['Fuzzy, I']
# ['Showaddywaddy']
# ['Orient Pearl']
# ['Shandon']
# ['La veo venir']
# ['Same']
# ['Nils Lofgren']
# ['Bad Company']
# ['El Soldado']
# ["Los Freddy's"]
# ['Godzila Fu']
# ['Jackson Browne']
# ['Kate Miller-Heidke']
# ['Los Gliders']
# ['L7']
# ['UUBBUURRUU']
# ['Sloper']
# ['Edward H Dafis']
# ['Ramones']
# ['Gie']
# ['Olly Oxen']
# ['Rigo Tovar']
# ['Fubar']
# ['O BANDO DO VELHO JACK']
# ['Landau']
# ['Kid Abelha']
# ['Sam Sam']
# ['Phillip Phillips']
# ['Diandras']
# ['Hateen']
# ['Leonardo Gonçalves']
# ['Endank Soekamti']
# ['Machete Bomb']
# ['Iván García y Los Yonkis']
# ['Juice Newton']
# ['Three Souls In My Mind']
# ['Langhorne Slim']
# ['Brebaje Extraño']
# ['Drenna']
# ['Felipe El Hombre']
# ['hateyourmusic']
# ['Owen Gray']
# ['Preto Massa']
# ['The Clovers']
# ['Lloyd Price']
# ['The Galo Power']
# ["All You've Seen"]
# ['Mark Springer']
# ['Big Still River']
# ['Tunnel At The End Of The Light']
# ['The Sun Aesthetic']
# ['Dave Graney']
# ['Soulmate']
# ['Agregator']
# ['Cornell Campbell']
# ['Gerry & The Pacemakers']
# ['Jānis Bukums']
# ['Lista de Lily']
# ['Keimzeit']
# ['Asia']
# ['Un Dia']
# ['Marii']
# ['The In Crowd']
# ["Will's Jams"]
# ['TømrerClaus']
# ['Las Armas Bs. As.']
# ['Leteći Odred']
# ['Pinchers']
# ['Turbulence']
# ['Twin Peaks']
# ['The Heptones']
# ['Denise De Kalafe']
# ['Klink']
# ['Avalore']
# ['Jorge Reyes']
# ['Fatal Fusion']
# ['Toninho Crespo']
# ['Rostros Ocultos']
# ['Luciano Basso']
# ['World At Large']
# ['mountaintops.']
# ['Roger Clyne & The Peacemakers']
# ['Os Replicantes']
# ['Casa Das Máquinas']
# ['Celso Piña']
# ['Biquini Cavadão']
# ['SHIMA']
# ['Resgate']
# ['Blues Boys']
# ['/Rif']
# ['Damien Dempsey']
# ['Punkzilla!']
# ['Fade2Black']
# ['Igloo']
# ['ArtilhariA']
# ['Paradise Club']
# ['Атлас']
# ['Máquina del Amor']
# ['Brownsville Station']
# ['Titiman Flores']
# ['The Motern Media Holiday Singers']
# ['Hungarica']
# ['Circus Caravan']
# ['Dore Mear Beon']
# ['Deb and The Mentals']
# ['Ace Frehley']
# ['Soul Asylum']
# ['Buck Owens']
# ['Rock A Japonica']
# ['Grupo Porco']
# ['Brady Rymer and the Little Band That Could']
# ['Synesthesia']
# ['Alcatrazz']
# ['PAN']
# ['The Animals']
# ['SUBARASHIKA']
# ['Charlie Monttana']
# ['Jars']
# ['The Grasshopper Lies Heavy']
# ['Dokken']
# ['The Jukks']
# ['NO°RD']
# ['Ike & Tina Turner']
# ['Tequila Baby']
# ['Echo & the Bunnymen']
# ['Rota Temporis']
# ['Dapuntobeat']
# ['Autoramas']
# ['Bijou']
# ['Twin Tones']
# ['Gruppo Sportivo']
# ['The Desmonds']
# ['Skarimbó']
# ['SCACCIAPENSIERI']
# ['Los Simios Rojos']
# ['Koyi']
# ['Lê Almeida']
# ['Gigante']
# ['The Mission']
# ['Kinky']
# ['Jupiter Apple']
# ['Los Holmes']
# ['Billy Joe Royal']
# ['Brachmond']
# ['Gerry Rafferty']
# ['Plebe Rude']
# ['Sleepy LaBeef']
# ['Hemophilia']
# ['Callate Mark']
# ['Hengky Supit']
# ['Sueño Urbano']
# ['Eduardo Araujo']
# ['Pasos Sin Rumbo']
# ['Rosa Tattooada']
# ['Twiddle']
# ['Engrennagem']
# ['Codinome Winchester']
# ['Heather Findlay']
# ['Los Strwck']
# ['Dias de Truta']
# ['Cefa']
# ['Seu Pereira e Coletivo 401']
# ['Bula']
# ['Karatula']
# ['Los Korucos']
# ['Ritual Viviente']
# ['Sonora Maracaibo']
# ['Jim Gill']
# ['Black Days']
# ['Los Apson']
# ['Sí Señor']
# ['Banda Blindagem']
# ['Tex Tex']
# ['Future Womb']
# ['Yelo Molo']
# ['Star Arcana']
# ['Paola Iezzi']
# ['Mark Wynter']
# ['The Coasters']
# ['Chenoa']
# ['TOTALFAT']
# ['NARUDORA']
# ['Orleans']
# ['Disidente']
# ['Banda Taffo']
# ['The Kentucky Headhunters']
# ['Alfonso André']
# ['Cyro Sampaio']
# ['Titãs']
# ['Cavalier Band']
# ['Brenda Lee']
# ['Rollfast']
# ['Sonia Lopez']
# ['wander wildner']
# ['Merzbow']
# ['Fred Arrais']
# ['Mad Grinder']
# ['Lia Hide']
# ['Lakis Papadopoulos']
# ['Bebeto']
# ['King Biscuit']
# ['Cold Tropics']
# ['Have The Moskovik']
# ['Pay']
# ['Os Horácios']
# ['Garnett Silk']
# ['Socie Gck']
# ['Max Merritt']
# ['Victor Caesar']
# ['Ein Gutes Pferd']
# ['Sonny & Cher']
# ["Shakin' Stevens"]
# ["Laughin'Nose"]
# ['Joe Lynn Turner']
# ['Chris Spedding']
# ['Emmylou Harris']
# ['Dois na Janela']
# ['Dissonantes']
# ['Dede Fauzi']
# ['Tiffany']
# ['Sniglabandið']
# ['Sótão']
# ['In Corp Sanctis']
# ['Chelsea']
# ['Kirby Krackle']
# ['Udo Lindenberg']
# ['THE MODS']
# ['Odeville']
# ['Mercury Rev']
# ['Xiu Xiu']
# ['Jadranka Juras']
# ['Jorma Kaukonen']
# ['Xoo']
# ['Fiel A La Vega']
# ['Ventre']
# ['Matte Na’Marra']
# ['Yunus Dişkaya']
# ['Dallas Crane']
# ['Dynamic Hepnotics']
# ['Reverendo Frankenstein']
# ['Black Box Revelation']
# ['Anti-Sociales']
# ['Mean Jolene']
# ['Los Terricolas']
# ['441']
# ['Tommy Steele']
# ['Bent Shapes']
# ['Supernaut']
# ['Flesh For Lulu']
# ['The Dee Jays']
# ['The Shorts']
# ['Desperados']
# ['Nihil Piraye']
# ['Joe Grushecky and the Houserockers']
# ['Bruno Schulz']
# ['Rebel Machine']
# ['Folder']
# ['Mystigma']
# ['Anton Johansson']
# ['Nosfell']
# ['Lowest of the Low']
# ['waybee']
# ['Le Endrigo']
# ['Vlad V']
# ['Dona Cislene']
# ['Carbona']
# ['Babylon Zoo']
# ["Los Rockin' Devils"]
# ['Alannah Myles']
# ['Boxhead Ensemble']
# ['Tom Robinson Band']
# ['Lester']
# ['Ink Bomb']
# ['Dennis Brown']
# ['Split']
# ['Yerçekimi']
# ['DYNAMITE']
# ['Stash']
# ['Little Feat']
# ['Wolf Maahn']
# ['Pilot']
# ['Dalevuelta']
# ['NABOWA']
# ['Miki Jevremovic']
# ['The Bombers']
# ['Captain Americano']
# ['500mg']
# ['No Crowd Surfing']
# ['Indian Ocean']
# ['Cabeza De Vinil']
# ['Deceivers']
# ['Del Carmen']
# ['Ramayana Soul']
# ['BUGY CRAXONE']
# ['FULL POWER GIRLS R']
# ["Da'ville"]
# ['Swan Vestas']
# ['The Penguins']
# ['VUNK']
# ['THE BAWDIES']
# ['Fabrício Beck & Bando Alabama']
# ['Molho Negro']
# ['Penacho']
# ['R. Diaz']
# ['Beach Towels']
# ["The B-52's"]
# ['Metamorfose']
# ['Rachun']
# ['Alvaro Scaramelli']
# ['Smile Buffalo']
# ["Rollin' Chamas"]
# ['Forgotten North']
# ['The Scottish Enlightenment']
# ['Hawai']
# ['Haystacks Calhoon']
# ['Animatori']
# ['Bobby Darin']
# ['Joanatan Richard']
# ['Mais Valia']
# ['Red Yarn']
# ['Glen Ricks']
# ['Ignispace']
# ['E.S.T.']
# ['OSAKA☆SYUNKASYUTO']
# ['Mellt']
# ['Kris']
# ['Dandy and The Cosmic']
# ['Danny Weinkauf']
# ['Asteroides Trio']
# ['Duca Leindecker']
# ['Polar Suns']
# ['Forte Norte']
# ['Tùng Dương']
# ['Los Blancos']
# ['SHEENA & THE ROKKETS']
# ['Deer Tick']
# ['SHIP']
# ['Nei Van Soria']
# ['Linda Ronstadt']
# ['Wander']
# ['Ricky Diamond']
# ['Gregory Isaacs']
# ['Sketchquiet']
# ['Blind Faith']
# ['Papa Razzi and the Photogs']
# ['Chicago']
# ['Sanathoria']
# ['Edgar Winter']
# ['The Guy Who Sings Songs About Cities & Towns']
# ['The Sights']
# ['Malva Íris']
# ['Banana Child']
# ['Errol Dunkley']
# ['XO Planets']
# ['Frankie Avalon']
# ['Travalley']
# ['MilesExperience']
# ['JP Stingray']
# ['FLOWERS']
# ['Mapa de Bits']
# ['An Early Bird']
# ['SBRBS']
# ['ROKI']
# ['Paddy Casey']
# ['Zigi Zaga']
# ['Выход']
# ['Paolo Gerson']
# ['Maquiavelia']
# ['Mechanics']
# ['Sloan']
# ['O Rappa']
# ['The Odd Man Who Sings About Poop, Puke and Pee']
# ['Juan Hernández y Su Banda de Blues']
# ['Órbita Azul']
# ['David Garfield']
# ['COUT']
# ['SABOTEN']
# ['Bumbe Orchestra']
# ['Hot Tuna']
# ['Ultraconformist']
# ['The Byrds']
# ['The Learning Station']
# ['Spacehog']
# ['Mike Laure']
# ['Tatto Zhavals']
# ['Ayub Bachchu']
# ['The Yardbirds']
# ['Sussie 4']
# ['Grito']
# ['Crew Peligrosos']
# ['Yorka']
# ['Raghu Dixit']
# ['Vaya Futuro']
# ['Foreigner']
# ['Grateful Dead']
# ['Bob Karwin']
# ['Veldhuis & Kemper']
# ['Hello Seahorse!']
# ['Os Arrais']
# ['boom boom kid']
# ['Glen Washington']
# ['Octorama']
# ['Seals and Crofts']
# ['Marty Wilde']
# ['Los Chicanos']
# ['Visionários']
# ['Gabi Novak']
# ['Ríoseco']
# ['Pacemaker']
# ['Animal de Ciudad']
# ['Dr. John']
# ['KC & The Sunshine Band']
# ['Bora Barx']
# ['The Stranglers']
# ['Don Ricardo']
# ['El Mapache']
# ['Emile Ford & The Checkmates']
# ['Les Chats Sauvages']
# ['The Strange Man Who Sings About Dead Animals']
# ['Joe White']
# ['Tyla Gang']
# ['Video Store']
# ['Aa']
# ['UFO']
# ['Merciful Nuns']
# ['Derrick Morgan']
# ['Carola']
# ['The Big Bopper']
# ['Holy Life']
# ['Teniente Cooper']
# ['Familiars']
# ['Kino']
# ['Christian & the 2120´s']
# ['Ronco']
# ['Kingsmen']
# ['SWIM SWEET UNDER SHALLOW']
# ['Sporkz']
# ['Georges Brassens']
# ['Fetuttines']
# ['Фёдор Чистяков']
# ['Wasureranneyo']
# ['Loladéli']
# ['Caterpillars']
# ['The Receiver']
# ['Tito Pingolinis']
# ['SCOOBIE DO']
# ['Missing Takes']
# ['The Freeborn Brothers']
# ['Vía Dolorosa']
# ["Nol'"]
# ['Dwen']
# ['The Toilet Bowl Cleaners']
# ['Modern-Rock Ensemble']
# ['The Aggrovators']
# ['Whatever Happened to Baby Jane']
# ['John Clark']
# ['Wonderflu']
# ['Mëlmak 69']
# ['Alien She']
# ['This Lonely Crowd']
# ['Dirty Looks']
# ['The Barefoot Man']
# ['Vladimir Kuzmin']
# ['RUKI']
# ['Blinker Links']
# ['OYASUMI HOLOGRAM']
# ['Gustavo Telles & os Escolhidos']
# ['The Geeks']
# ['Macaco Véi']
# ['The Fauves']
# ['Eigensinn']
# ['Great Falls']
# ['Crash Ton Rock']
# ['Yanto Laitano']
# ['Tribal Tech']
# ['Human Drama']
# ['Greecelove']
# ['Grandfúria']
# ['Les Betteraves']
# ['Império da Lã']
# ['Jeden Tag Silvester']
# ['Nouveau Vélo']
# ['Audrey Hall']
# ['Julio Reny']
# ['Xmas Eileen']
# ['Theatre Of Hate']
# ['MAGIC']
# ['Bottles of Love']
# ['Dois Reis']
# ['Bella Morte']
# ['Tim Rogers']
# ['Miners']
# ['Lukie D']
# ['Cássia Novello']
# ['Evil Motor']
# ['Daleka Obala']
# ['Lola Tried']
# ['Underground Authority']
# ['Cólera']
# ['Gula']
# ['Noe Terceros']
# ['Alaska']
# ['Audic Empire']
# ['Francky Goes to Pointe à Pitre']
# ['Mr. Gyn']
# ['Pesadelo Brasileiro']
# ['Василий К.']
# ['The Cleftones']
# ['Fats Domino']
# ['Shileper High']
# ['Eero Koivistoinen']
# ['Stroke 9']
# ['Laura Branigan']
# ['Santi Mostaffa']
# ['Gavin Glass']
# ['Reece']
# ['Angry Hill']
# ['F3 - Fuck the Fucking Fuckers']
# ['The Chantels']
# ['elhombreanormal']
# ['Kurara']
# ['Tephrosis']
# ['Hootie & The Blowfish']
# ['Rotten Flies']
# ['Corazones Muertos']
# ['Brian Hyland']
# ['Gesman']
# ['Superfortress']
# ['Nevruz']
# ['Primal Scream']
# ['The Jesus and Mary Chain']
# ['In Rapture']
# ['Laura Mardon']
# ['Casa de Velho']
# ["Duke Reid's Group"]
# ['Midnite Johnny']
# ['Rick Steffen']
# ['Rick Danko']
# ['Firefall']
# ['Eddie Fontaine']
# ['Le capre a sonagli']
# ['Qalín']
# ['Punto de Fuga']
# ['Sun Junkies']
# ['Операция: Алмазное Бикини']
# ['William Harries Graham']
# ['Ghost Dance']
# ['Dramatic Alaska']
# ['UNICORN']
# ['Marky Ramone']
# ['Antefatti']
# ['Smokey Fingers']
# ['LaGambiaja']
# ['The Westernauts']
# ['Al Hendrix']
# ['George Jones']
# ['DÖDSÖGONBLICKET']
# ['Atlanta Rhythm Section']
# ['car10']
# ['Make A Rising']
# ['mr Quinn']
# ['Bull Control']
# ['Helen Shapiro']
# ['Deep Purple']
# ['Buddy Knox']
# ['Cinema Novo']
# ['Cecilia Toussaint']
# ['Waingro']
# ['The Naked Sweat Drips']
# ['Dino Fumaretto']
# ['Nazz']
# ['Billy Fury']
# ['Marcel et son Orchestre']
# ['Danny Adler']
# ['Tropical Worms']
# ['Sweet Empire']
# ['SoftAnimal']
# ['rhubiqs']
# ['Heat of Damage']
# ['Girlfriend Material']
# ['Talking Heads']
# ['Dennehy']
# ['Prader & knecht']
# ['Manuel Aspidi']
# ['ZZ Top']
# ['Hökartorget']
# ['Superglad']
# ['Lenny Kravitz']
# ['Cliff Richard']
# ['Featherstone']
# ['Turbocoopers']
# ['Buffalo Springfield']
# ['Michelle Branch']
# ['Her Neyse']
# ['Wes Loper']
# ['Eli Soares']
# ['Los Silver']
# ['The Clarks']
# ['Cidadão Quem']
# ['54-40']
# ['Heróis Da Resistência']
# ['フレンズ']
# ['Freddie King']
# ['Al Jarreau']
# ['Mark May Band']
# ['Blindside']
# ['Mackenzie Shrieve']
# ['Stereoscope']
# ['Humanfobia']
# ['Novos Baianos']
# ['The German Art Students']
# ['Ivo Mojzer']
# ['Dreams of Avalon']
# ['Donald Fagen']
# ['Meat Puppets']
# ['The Muggs']
# ['Bob Luman']
# ['La Sangre De Verónika']
# ['dpsmkr']
# ['The Stroj']
# ['Dasputnik']
# ['Senzafine']
# ['Frankie Laine']
# ['Mortal Hate']
# ['Muchileiros']
# ['IZZ']
# ['Agony of Choice']
# ['Mikko Alatalo']
# ['Baby Do Brasil']
# ['Gülden Karaböcek']
# ['Espoleta Blues']
# ['Yume Miru Adolescence']
# ['The Baggios']
# ['Floating In Space']
# ['Tone']
# ['Mikey Mason']
# ['Karne Krua']
# ['Domes of Silence']
# ['Lollipop']
# ['Andre Pettipas and the Giants']
# ['PBII']
# ['Sugar Minott']
# ['De Flamingo']
# ['25 Yard Screamer']
# ['Pesta']
# ['Roterfeld']
# ['The Union of Sinners and Saints']
# ['Freddie McGregor']
# ['Pray TV']
# ['Arsen Dedić']
# ['Gusha Katushkin']
# ['Calyx']
# ['Nordgarden']
# ['Abalone']
# ['Youthless']
# ['Grand Avenue']
# ['Bravi Tutti']
# ['Helmetheads']
# ['Hillbilly Hellcats']
# ['Grinding Reaction']
# ['Busic']
# ['Honey Boy Martin']
# ['Original Love']
# ['Walrus']
# ['Mick Clarke']
# ['Commander Cody and His Lost Planet Airmen']
# ['Alexander Rosenbaum']
# ['Rotten Garden']
# ['Slimboy']
# ['Delaney & Bonnie']
# ['Geier Sturzflug']
# ['Terry Knight']
# ['The Chapel Of Exquises Ardents Pears']
# ['Massimo Priviero']
# ['Jimi Pappas']
# ['Gun']
# ['Urcid & The Macizo']
# ['Locas In Love']
# ['SA']
# ['Alligator Jackson']
# ['SuperHiks']
# ['Andy Anderson']
# ['Mopho']
# ['Los Impacientes']
# ['Soulzera']
# ['GRAPEVINE']
# ['YAMAGUCHI KASSEI GAKUEN']
# ['Roz Vitalis']
# ['Woolly Wolstenholme']
# ['Middle Finger']
# ['Kid Lucifer']
# ['Colombina Parra']
# ['Desmond and the Tutus']
# ['Donny Brewer']
# ['John Holt']
# ['Brinsley Schwarz']
# ['Isla Tortuga']
# ['Planisphere']
# ['EDY']
# ['Captain Disko']
# ['Ema Stoned']
# ['BETAMENSCH']
# ['Khorus']
# ['Normie Rowe']
# ['Maude']
# ['Stay Away']
# ['Sys Malakian']
# ['Oh Mercy']
# ['Jimmy London']
# ['Tom Tom Club']
# ['Viles Vinyles']
# ['the Picturesque Episodes']
# ['Los Solitarios']
# ['Johnny Preston']
# ['Небо Здесь']
# ['Angrama']
# ['Ray Scott']
# ['The Cadillacs']
# ['Aqua-Play']
# ['La Vida Bohème']
# ['Los Moonlights']
# ['Glen Adams']
# ['Renegados Além dos Rótulos']
# ['Colonia de Vacaciones']
# ['Anaugh Conda']
# ['Bajaga & Instruktori']
# ['Flicts']
# ['BTR']
# ['Seahorses']
# ['Duane Eddy']
# ['Larry Williams']
# ['Slim Harpo']
# ['Aderiva']
# ['Chronicles of Khan']
# ['Home Brewed Universe']
# ['Orbit Service']
# ['The Residents']
# ['Lamebrain']
# ['Organizm']
# ['Bandina ié']
# ['Haiku Project']
# ['Skids']
# ['Bienvenido Granda']
# ['Tommy Roe']
# ['Jack Scott']
# ['Iwan Fals']
# ['Hermanos Carrion']
# ['Alrune Rod']
# ['Delroy Wilson']
# ['Mudhoney']
# ['Nem Liminha Ouviu']
# ['Naked Drivers']
# ['Blues Image']
# ['O Preço']
# ['Jamie Lenman']
# ['Flesh Panthers']
# ['The Reels']
# ['Mike Bloomfield']
# ['Oboyob']
# ['Noa Mal']
# ['Donna Maria']
# ['Geyster']
# ['Birth Order']
# ['Starship']
# ['Moon Taxi']
# ['Garrafa Vazia']
# ['Los Seven Days']
# ['Los Tecolines']
# ['Pure Prairie League']
# ['Fiolet']
# ['Juliette']
# ['The Ruiins']
# ['Rey Bala']
# ['Big Spin']
# ['Alan Davey']
# ['Crowder']
# ['DustRats']
# ['Зимовье Зверей']
# ['Cilla Black']
# ['Bijelo Dugme']
# ['Los Atascados']
# ['Os Mutantes']
# ['OPM']
# ['Pepe Willberg']
# ['Macumbazilla']
# ['Rodox']
# ['David Olney']
# ['Kommando Kant']
# ['Trampa']
# ['Mirrored Lips']
# ['Book Group']
# ['Veislakt']
# ['Lou Dalfin']
# ['Volage']
# ['Dona Iracema']
# ['Papa Don McMinn']
# ['CG Bros']
# ['Vadik Barron']
# ['Interpuesto']
# ['Duff']
# ['Ugory']
# ['ดวงดาว เดียวดาย']
# ['Numata']
# ['Blitz']
# ['FTISLAND']
# ['Glutton']
# ['Tired Tape Machine']
# ['The Bob Lanza Blues Band']
# ['Parásitus']
# ['Kemal Monteno']
# ['Octavio Suñé']
# ['Mega']
# ['Velvett Lipstick']
# ['Os Noctambulos']
# ['Aldemaro Romero']
# ['Zoob']
# ['The Krav Maga']
# ['7 Weeks']
# ['TH eROCKERS']
# ['Drive Blind']
# ['Wild Detroit Gang']
# ['Coco Montoya']
# ['Mišo Kovač']
# ['Ritmo Peligroso']
# ['Legrant']
# ['Canshaker Pi']
# ['STUPID BABIES GO MAD']
# ['Craig Douglas']
# ['St. Tropez']
# ['Hellorice']
# ['Johnny Clarke']
# ['Circus Dei']
# ['Hardinger Band']
# ['Peter Case']
# ['California Blues']
# ['THE ALFEE']
# ['Retrovisor']
# ['SOFAZ']
# ['BLACK CATS']
# ['__ (Underbar)']
# ['Marie Pierre']
# ["Herman's Hermits"]
# ['Homem Canibal']
# ['Roads']
# ['Hedersleben']
# ['Quadrilles']
# ['Flamen Dialis']
# ['Controlled Bleeding']
# ['Half Japanese']
# ['Ilydaen']
# ['The Ethiopians']
# ['Fleeting Circus']
# ['Ugly Papas']
# ['Henrik Palm']
# ['Add Carabao']
# ['January']
# ['S.O.L.E.']
# ['Canil']
# ['Sugar Kane']
# ['Marenna']
# ['Joseph Little Drop']
# ['Kripa']
# ['Jeff Beck']
# ['La macchina di von Neumann']
# ['Baranga']
# ['Issorock']
# ['Apartel']
# ['Platonick Dive']
# ['Darkparadise']
# ['Aedes Aegypti']
# ['Frank Ifield']
# ['Water Rats']
# ['The False']
# ['Mêlée']
# ['Joe Kowalski & The Sex Detectives']
# ['Fran Palermo']
# ['Разные Люди']
# ['Petri & Pettersson Brass']
# ['Madrugada']
# ['Roy Shirley']
# ['Black Light White Light']
# ['Junior Kelly']
# ['Burrito Panza']
# ['Perrosky']
# ['Muff Burn Grace']
# ['Microwaves']
# ['Dr. Hook']
# ['Пани Хида']
# ['Joan Isaac']
# ['Modus']
# ['Rough Cutt']
# ['Basilios']
# ['Love']
# ['The Fall']
# ['Gloria Gaynor']
# ['Facção Caipira']
# ['Rocket Science']
# ['Keele']
# ['Starlight Replica']
# ['Humble Grumble']
# ['Katherine Dines']
# ['Companero Asma']
# ['Laura Guevara']
# ['The Slow Readers Club']
# ['Metusa']
# ['Ritchie Valens']
# ['Yngwie Malmsteen']
# ['Summer Flake']
# ['Grupo Yndio']
# ['The Boat Drunks']
# ['TobyMac']
# ['Sioux 66']
# ['Lady Pank']
# ['Daniel Powter']
# ['David Castro']
# ['D’Angerous']
# ['Sibannac']
# ['Electric Lo Fi Seresta']
# ['Cat Scan']
# ['Hueco']
# ['The Paragons']
# ['Freddy Cannon']
# ['Jimmy Jones']
# ['Acmme Skateband']
# ['The Obsessed']
# ['Bulldog']
# ['John Anderson']
# ['Hudkreft']
# ['Rolas']
# ['Rouge Pompier']
# ['Silver Mammoth']
# ['Idyllen']
# ['Jonathan Edwards']
# ['George Nooks']
# ['Storm Warning']
# ['Filipe Alvim']
# ['The Del-Vikings']
# ['Ratt']
# ['Kushà']
# ['Tori Amos']
# ['Skoffín']
# ['Short Fictions']
# ['Talaget Elmawta']
# ['De Cujos']
# ['Ilithios']
# ['Trummer']
# ['Johan Hoogewijs']
# ['White Lion']
# ['bis']
# ['Jota Quest']
# ['Tamar Aphek']
# ['jewel ciel']
# ['Luan Bates']
# ['Adam Betts']
# ['Hiki']
# ["I'm Not a Blonde"]
# ['otomeshinto']
# ['D’MASIV']
# ['The Membranes']
# ['Sam Roberts Band']
# ['Kobranocka']
# ['Tristeza Urbana']
# ['Stippenlift']
# ['Ken Boothe']
# ['Jonnata Doll e os Garotos Solventes']
# ['Save Us from the Archon']
# ['REGULUS']
# ['NUMBER VOGEL']
# ['Bushman']
# ['Alleycats']
# ['Playmobille']
# ['Hladno Pivo']
# ['Karpatt']
# ['Nonsemble']
# ['The Foreign Films']
# ['Pyramidal']
# ['Gené Kruppa']
# ['Dedo Podre']
# ['Los Bribones']
# ['Poemas Elétricos']
# ['Eufohria']
# ['Sem Sair na Rolling Stone']
# ['Ас Вентура']
# ['Canto Cego']
# ['Dwight Yoakam']
# ['Liverina']
# ['The Celibate Rifles']
# ['Pessimi Elementi']
# ['Color It Red']
# ['Katteni Shiyagare']
# ['Trout Fishing in America']
# ['Carbayo']
# ['Songes']
# ['Pat Kelly']
# ['The Gothees']
# ['Edwin McCain']
# ['Josipa Lisac']
# ['General Degree']
# ['Outrageous Cherry']
# ['Nanook el Último Esquimal']
# ['LILI LIMIT']
# ['Mery Celeste']
# ['Rotentix']
# ['Alquímera']
# ['Supermansion']
# ['Yedê Şakirî']
# ['Ian Thomas']
# ['Me and My Kites']
# ['Cardiac Rock']
# ['Wooly Mammoth']
# ['Gang Of Four']
# ['Возвращение']
# ['Anders Johansson']
# ['Védett Férfiak']
# ['Malviaje']
# ['Barenaked Ladies']
# ['Rematte']
# ['Bright Light Bright Light']
# ['Novel Nature']
# ['Vug']
# ['Shipwreck Karpathos']
# ['Zen Arcade']
# ['Ytterbium']
# ["Mind's Doors"]
# ['HiGE']
# ['Alpargatos']
# ['Dorsey Burnette']
# ['Vortex']
# ['Capitão Perseu']
# ['Skid Row']
# ['Real Derek']
# ['Lowburn']
# ['Jason Becker']
# ['Concreto']
# ['Kroh']
# ["TV's Kyle"]
# ['The Mumps']
# ['Umberto Maria Giardini']
# ['Jose Fors']
# ['MC Lars']
# ['JPL']
# ['Nicolette Larson']
# ['Zander']
# ['Mad Men Convoy']
# ['Site Access']
# ['Helices']
# ['Third Eye Blind']
# ['Skabong']
# ['Don Vail']
# ['Riviera']
# ['Rolando Chaparro']
# ['ShadowParty']
# ['Camaleônia']
# ['Mawcore']
# ['Sanchez']
# ['Verdcel']
# ['Manfred Mann Chapter Three']
# ['Los Mil Jinetes']
# ['Impossíveis']
# ['Bad Detectives']
# ['Flying Kids']
# ['Novi Fosili']
# ['Edu Lombardo']
# ['Thedy Correa']
# ['Susana Félix']
# ['Constantina']
# ['McBain']
# ['SADJAY']
# ['Zeca Baleiro']
# ['folca']
# ['Ricardito :c']
# ['Wanderlust']
# ['Pastel de Miolos']
# ['Jet']
# ['Ángeles Del Infierno']
# ['Los Dandys']
# ['Manowar']
# ['Johnnie Ray']
# ['Benny']
# ['Pierre Vervloesem']
# ['Heavy Metal Kids']
# ['The Potions']
# ['Twisted Sister']
# ['French Cowboy & The One']
# ['Agressiva 69']
# ['Jack J Hutchinson']
# ['The Hubschrauber']
# ['Danny & The Juniors']
# ['Jordan Allen']
# ['Kidori Kidori']
# ['Girl']
# ['ULTRAS']
# ['Aaron Nigel Smith']
# ['Lucas Martí']
# ['Musa Híbrida']
# ['Leroy Smart']
# ['Landing']
# ['Nacional Riviera']
# ['Curlee Wurlee!']
# ['Kooba Tercu']
# ['The Memories']
# ['Tinnarose']
# ['Á Móti Sól']
# ['Androide Sem Par']
# ['Eksi Ekso']
# ['Bright Sight']
# ['LAVOLTA']
# ['Capo']
# ['Hymns for the Angels']
# ['Darvin']
# ['The Ians']
# ['Matt Dwyer']
# ['8m/s']
# ['Babyraids Japan']
# ['Battalions']
# ['Sick Instrumental']
# ['High Hi']
# ['Parthibo']
# ['Arbor Lights']
# ['Lobos De Calla']
# ['Kim Fowley']
# ['Ossos cruzados']
# ['Almost Famous Friends']
# ['Kamala']
# ['Thriller U']
# ['Pankrti']
# ['The Maytals']
# ['Sapin']
# ['Erick Endres']
# ['Fragments']
# ['Galants']
# ['Insane Ian']
# ['Delber Grady']
# ['I-Roy']
# ['Alkymenia']
# ['Ugly Blondes']
# ['DERIVA']
# ['The Pioneers']
# ['They Danced Like Programmed Angels']
# ['Components']
# ['Xombie']
# ['Snog']
# ['Tales Of Justine']
# ['The Arataca Stoned Farmers']
# ['A House']
# ['Trigger Thumb']
# ['Pessoal da Nasa']
# ['SANGUE']
# ['Incantatem']
# ['Diljen Roni']
# ['Anthony Phillips']
# ['パソコン音楽クラブ']
# ['Rebels and Sinners']
# ['Slimmy']
# ['David Gates']
# ['Johnny Burnette']
# ['Despite Everything']
# ['Pike Cavalero']
# ['Plafon']
# ['Classic Yellow']
# ['Devo Spice']
# ['The Grenadines']
# ['Artefacto']
# ['Honeybender']
# ['Tobny Houston']
# ['Christine Anu']
# ['Los Cuatro Soles']
# ['Intercity']
# ['Labirintite']
# ['Boar']
# ['Vlack Salzo']
# ['Loose Buttons']
# ['All Time Low']
# ['Matuto Moderno']
# ['Lofofora']
# ['Peter Jefferies']
# ['Los Flasheros']
# ['Colina']
# ['Alf Sá']
# ['Warren Zevon']
# ['Oldelaf']
# ['Próchno']
# ['Дмитрий Ревякин']
# ['The Whoops']
# ['Aldrian Risjad']
# ['Blackfeather']
# ['Dirty York']
# ['Сергей Маврин']
# ['Santos de Uma Esquina']
# ['Coma']
# ['THE NEW DEATH CULT']
# ['Bwncath']
# ['El Ayacha']
# ['Mickey Gilley']
# ['Cesar Costa']
# ['Die Sauna']
# ['Georgia Shine Band']
# ['Don Marco']
# ['Isabella Stefania']
# ['Mafiota']
# ['Igor Montenegro']
# ['Алмазный Фронт']
# ['B.J. Thomas']
# ['Bordines']
# ['Chocolate Starfish']
# ['Galgo']
# ['DEER FROM SPACE']
# ['Zrada']
# ['Electric Fantasy']
# ['Malcolm Yelvington']
# ['Elise Davis']
# ['Greta']
# ['Xcstacy']
# ['Michael Franks']
# ['Urban & 4']
# ['Cold Reading']
# ['Dens']
# ['Hitherto']
# ['Sierra León']
# ['Comunidade Nin-jitsu']
# ['Untitled With Drums']
# ['Zeke And The Popo']
# ['Oceania']
# ['Frejat']
# ['Mehmet Güreli']
# ['Dept']
# ['Luca Bassanese']
# ['Marillion']
# ['Angel NeBes']
# ['Eskiz']
# ['Projeto Rivera']
# ['Kirka']
# ['Eric Andersen']
# ['The Subways']
# ['Irán']
# ['Hali Hicks']

# %%
lista = [i[0] if isinstance(i, list) else i for i in lista]

# %%
statistics = []
limit = 200
for contador, nombre_artista in enumerate(lista):
    if contador >= limit:
        break
    statistics.append(stats(nombre_artista, api_key))

# %%
statistics
# Out:
# [{'artista': 'Astrio', 'oyentes': '876', 'reproducciones': '11512'},
#  {'artista': 'Jacky Terrasson',
#   'oyentes': '151426',
#   'reproducciones': '819634'},
#  {'artista': 'Jimmy Dorsey', 'oyentes': '87252', 'reproducciones': '409133'},
#  {'artista': 'Kin Garcia Trio', 'oyentes': '11', 'reproducciones': '26'},
#  {'artista': 'ORQUESTRA DE JAZZ DE GALICIA',
#   'oyentes': '22',
#   'reproducciones': '299'},
#  {'artista': 'Candy Dulfer', 'oyentes': '173052', 'reproducciones': '1934538'},
#  {'artista': 'Jimmy Dorsey', 'oyentes': '87252', 'reproducciones': '409133'},
#  {'artista': 'Oscar Peterson Trio',
#   'oyentes': '562660',
#   'reproducciones': '5843566'},
#  {'artista': 'Barry Likumahuwa',
#   'oyentes': '10928',
#   'reproducciones': '169836'},
#  {'artista': 'Maynard Ferguson',
#   'oyentes': '114636',
#   'reproducciones': '1026452'},
#  {'artista': 'Juliana Cortes', 'oyentes': '565', 'reproducciones': '7240'},
#  {'artista': 'Mezz Mezzrow', 'oyentes': '9478', 'reproducciones': '60143'},
#  {'artista': 'Beny Moré', 'oyentes': '132274', 'reproducciones': '783410'},
#  {'artista': 'Alice Lamb', 'oyentes': '9065', 'reproducciones': '35553'},
#  {'artista': 'Phil Woods', 'oyentes': '150805', 'reproducciones': '551144'},
#  {'artista': 'Massimo Faraò', 'oyentes': '71401', 'reproducciones': '267939'},
#  {'artista': 'Greg Walker', 'oyentes': '2934', 'reproducciones': '12096'},
#  {'artista': 'SaxoFOUR', 'oyentes': '238', 'reproducciones': '2017'},
#  {'artista': 'Snowboy', 'oyentes': '44249', 'reproducciones': '175782'},
#  {'artista': 'David "Fathead" Newman',
#   'oyentes': '18340',
#   'reproducciones': '98478'},
#  {'artista': 'Ole Amund Gjersvik',
#   'oyentes': '1606',
#   'reproducciones': '7594'},
#  {'artista': 'Jan Ptaszyn Wroblewski Sextet',
#   'oyentes': '523',
#   'reproducciones': '5835'},
#  {'artista': 'Raphael Wressnig', 'oyentes': '2323', 'reproducciones': '12063'},
#  {'artista': 'Scheen Jazzorkester',
#   'oyentes': '329',
#   'reproducciones': '1885'},
#  {'artista': 'Giulia Valle Trio', 'oyentes': '51', 'reproducciones': '279'},
#  {'artista': 'Woody Herman', 'oyentes': '163877', 'reproducciones': '935633'},
#  {'artista': 'Johnny "Hammond" Smith',
#   'oyentes': '50918',
#   'reproducciones': '262602'},
#  {'artista': 'Octavio Bugni', 'oyentes': '33', 'reproducciones': '89'},
#  {'artista': 'Glenn Weyant', 'oyentes': '280', 'reproducciones': '1183'},
#  {'artista': 'Enrico Intra', 'oyentes': '71077', 'reproducciones': '275786'},
#  {'artista': 'Eduardo Mendonça', 'oyentes': '408', 'reproducciones': '771'},
#  {'artista': 'Greekboy', 'oyentes': '7627', 'reproducciones': '39301'},
#  {'artista': 'Barney Kessel', 'oyentes': '108188', 'reproducciones': '786682'},
#  {'artista': 'Enrico Intra', 'oyentes': '71077', 'reproducciones': '275786'},
#  {'artista': 'Eric Bouvelle', 'oyentes': '2177', 'reproducciones': '9485'},
#  {'artista': 'Ivo Perelman', 'oyentes': '3412', 'reproducciones': '34126'},
#  {'artista': "Mark O'Connor", 'oyentes': '38531', 'reproducciones': '259591'},
#  {'artista': 'Jan Ptaszyn Wroblewski Sextet',
#   'oyentes': '523',
#   'reproducciones': '5835'},
#  {'artista': 'PAX JAPONICA GROOVE',
#   'oyentes': '4883',
#   'reproducciones': '132558'},
#  {'artista': 'Duke Ellington',
#   'oyentes': '1408375',
#   'reproducciones': '21312765'},
#  {'artista': 'Eddie "Cleanhead" Vinson',
#   'oyentes': '23061',
#   'reproducciones': '87352'},
#  {'artista': 'Monika Hoffman', 'oyentes': '359', 'reproducciones': '754'},
#  {'artista': 'Federico Casagrande',
#   'oyentes': '802',
#   'reproducciones': '2448'},
#  {'artista': 'Ruben Alves', 'oyentes': '368', 'reproducciones': '2186'},
#  {'artista': 'İlhan İrem', 'oyentes': '13101', 'reproducciones': '252684'},
#  {'artista': 'Christine Tobin', 'oyentes': '2319', 'reproducciones': '13724'},
#  {'artista': 'Eugene Williams', 'oyentes': '45', 'reproducciones': '461'},
#  {'artista': 'Lucky Thompson', 'oyentes': '24972', 'reproducciones': '173601'},
#  {'artista': 'SaxoFOUR', 'oyentes': '238', 'reproducciones': '2017'},
#  {'artista': 'Jimmy Forrest', 'oyentes': '37437', 'reproducciones': '137924'},
#  {'artista': 'James Butler', 'oyentes': '15597', 'reproducciones': '229231'},
#  {'artista': 'Greg Walker', 'oyentes': '2934', 'reproducciones': '12096'},
#  {'artista': 'James Butler', 'oyentes': '15597', 'reproducciones': '229231'},
#  {'artista': 'Greg Walker', 'oyentes': '2934', 'reproducciones': '12096'},
#  {'artista': 'Greg Walker', 'oyentes': '2934', 'reproducciones': '12096'},
#  {'artista': 'Martin Liege', 'oyentes': '10373', 'reproducciones': '103272'},
#  {'artista': 'James Butler', 'oyentes': '15597', 'reproducciones': '229231'},
#  {'artista': 'Martin Liege', 'oyentes': '10373', 'reproducciones': '103272'},
#  {'artista': 'Afro-Cuban All Stars',
#   'oyentes': '70414',
#   'reproducciones': '470673'},
#  {'artista': 'Jimmie Lunceford',
#   'oyentes': '122980',
#   'reproducciones': '700404'},
#  {'artista': 'Dexter', 'oyentes': '172485', 'reproducciones': '1768986'},
#  {'artista': 'Túlio Borges', 'oyentes': '2730', 'reproducciones': '35233'},
#  {'artista': 'Mah Kouyaté', 'oyentes': '626', 'reproducciones': '2887'},
#  {'artista': 'Shannon & Keast', 'oyentes': '10570', 'reproducciones': '62989'},
#  {'artista': 'Terry Dexter', 'oyentes': '3124', 'reproducciones': '21231'},
#  {'artista': 'Kika Sprangers', 'oyentes': '1603', 'reproducciones': '13164'},
#  {'artista': 'Wendell Brunious', 'oyentes': '702', 'reproducciones': '4072'},
#  {'artista': 'David Finck', 'oyentes': '21889', 'reproducciones': '45497'},
#  {'artista': 'Katie Noonan', 'oyentes': '18108', 'reproducciones': '171191'},
#  {'artista': 'Joshua Redman Quartet',
#   'oyentes': '45594',
#   'reproducciones': '244537'},
#  {'artista': 'Instrumental Jazz Music Ambient',
#   'oyentes': '10377',
#   'reproducciones': '137263'},
#  {'artista': 'Al Jolson', 'oyentes': '97674', 'reproducciones': '549065'},
#  {'artista': 'California Ramblers',
#   'oyentes': '7176',
#   'reproducciones': '34944'},
#  {'artista': 'Lina Nyberg', 'oyentes': '7142', 'reproducciones': '38191'},
#  {'artista': 'Peter Szendofi', 'oyentes': '534', 'reproducciones': '4481'},
#  {'artista': 'Roger Wolfe Kahn', 'oyentes': '4931', 'reproducciones': '19248'},
#  {'artista': 'The Jazz Crusaders',
#   'oyentes': '40389',
#   'reproducciones': '222682'},
#  {'artista': 'Alexey Kruglov', 'oyentes': '390', 'reproducciones': '2995'},
#  {'artista': 'Charles Mingus',
#   'oyentes': '971201',
#   'reproducciones': '16784562'},
#  {'artista': 'Monika Hoffman', 'oyentes': '359', 'reproducciones': '754'},
#  {'artista': 'Christian Garrick', 'oyentes': '282', 'reproducciones': '3859'},
#  {'artista': 'Andreas Tschopp', 'oyentes': '69', 'reproducciones': '517'},
#  {'artista': 'Emma Pask', 'oyentes': '1008', 'reproducciones': '8775'},
#  {'artista': 'Andrezz', 'oyentes': '5186', 'reproducciones': '22463'},
#  {'artista': 'Vangelis Katsoulis',
#   'oyentes': '6180',
#   'reproducciones': '48059'},
#  {'artista': 'Barre Phillips', 'oyentes': '16490', 'reproducciones': '97158'},
#  {'artista': 'J. C. Higginbotham', 'oyentes': '273', 'reproducciones': '1043'},
#  {'artista': 'Mari Nakamoto', 'oyentes': '1475', 'reproducciones': '14226'},
#  {'artista': 'Mala Traza', 'oyentes': '7', 'reproducciones': '11'},
#  {'artista': 'Hubert Deuringer', 'oyentes': '890', 'reproducciones': '6049'},
#  {'artista': 'Marilyn Scott', 'oyentes': '9216', 'reproducciones': '73698'},
#  {'artista': 'Monika Hoffman', 'oyentes': '359', 'reproducciones': '754'},
#  {'artista': 'Memphis Jazzers', 'oyentes': '110', 'reproducciones': '248'},
#  {'artista': 'Kirk Lightsey', 'oyentes': '2081', 'reproducciones': '8079'},
#  {'artista': 'Somewhere Off Jazz Street',
#   'oyentes': '30437',
#   'reproducciones': '437197'},
#  {'artista': 'David Hazeltine Trio',
#   'oyentes': '3591',
#   'reproducciones': '23289'},
#  {'artista': 'Steiger', 'oyentes': '2711', 'reproducciones': '15116'},
#  {'artista': 'Akiko Tsuruga', 'oyentes': '2074', 'reproducciones': '18105'},
#  {'artista': 'Claude Cozens Trio', 'oyentes': '22', 'reproducciones': '103'},
#  {'artista': 'Aga Zaryan', 'oyentes': '20334', 'reproducciones': '605493'},
#  {'artista': 'Ole Swing', 'oyentes': '450', 'reproducciones': '3560'},
#  {'artista': 'Herbie Mann', 'oyentes': '196552', 'reproducciones': '1252505'},
#  {'artista': 'Carme Canela', 'oyentes': '702', 'reproducciones': '4993'},
#  {'artista': 'Martin Liege', 'oyentes': '10373', 'reproducciones': '103272'},
#  {'artista': 'James Butler', 'oyentes': '15597', 'reproducciones': '229231'},
#  {'artista': 'Cab Calloway & His Orchestra',
#   'oyentes': '44676',
#   'reproducciones': '239343'},
#  {'artista': 'Earth, Wind & Fire',
#   'oyentes': '2740336',
#   'reproducciones': '43632328'},
#  {'artista': 'Alberto Tarin', 'oyentes': '2125', 'reproducciones': '9304'},
#  {'artista': 'Jeanette Lindström',
#   'oyentes': '14361',
#   'reproducciones': '98172'},
#  {'artista': 'Oscar Aleman', 'oyentes': '6179', 'reproducciones': '32235'},
#  {'artista': 'Michiel Borstlap',
#   'oyentes': '62497',
#   'reproducciones': '371589'},
#  {'artista': 'David Manuhutu', 'oyentes': '534', 'reproducciones': '1603'},
#  {'artista': 'Bebo Valdés', 'oyentes': '83519', 'reproducciones': '701637'},
#  {'artista': 'Oscar Aleman', 'oyentes': '6179', 'reproducciones': '32235'},
#  {'artista': 'Charles Schillings',
#   'oyentes': '42005',
#   'reproducciones': '183791'},
#  {'artista': 'Mani Deïz', 'oyentes': '6362', 'reproducciones': '68564'},
#  {'artista': 'IAMPAUL', 'oyentes': '19803', 'reproducciones': '78943'},
#  {'artista': 'The Tepping Trio', 'oyentes': '311', 'reproducciones': '814'},
#  {'artista': 'Fletcher Henderson & His Orchestra',
#   'oyentes': '9504',
#   'reproducciones': '34605'},
#  {'artista': 'Ahmad Jamal', 'oyentes': '383862', 'reproducciones': '4462027'},
#  {'artista': 'Desidério Lázaro', 'oyentes': '203', 'reproducciones': '1417'},
#  {'artista': 'Duoscience', 'oyentes': '13745', 'reproducciones': '104620'},
#  {'artista': 'Shelly Manne', 'oyentes': '30975', 'reproducciones': '179069'},
#  {'artista': 'Brian Tarquin', 'oyentes': '14694', 'reproducciones': '83406'},
#  {'artista': 'Ella Fitzgerald',
#   'oyentes': '2639320',
#   'reproducciones': '49443448'},
#  {'artista': 'Sumkali', 'oyentes': '39', 'reproducciones': '123'},
#  {'artista': 'The MaddGeek', 'oyentes': '4863', 'reproducciones': '18619'},
#  {'artista': 'TOKYO SHIOKOUJI', 'oyentes': '2654', 'reproducciones': '12481'},
#  {'artista': 'Stefano Di Battista',
#   'oyentes': '16925',
#   'reproducciones': '114842'},
#  {'artista': '¡Cubanismo!', 'oyentes': '49942', 'reproducciones': '244094'},
#  {'artista': 'Bunk Johnson', 'oyentes': '22926', 'reproducciones': '87211'},
#  {'artista': 'Edward Vesala Ensemble',
#   'oyentes': '65',
#   'reproducciones': '257'},
#  {'artista': 'Mat Mathews', 'oyentes': '567', 'reproducciones': '3278'},
#  {'artista': 'Susanne Regen', 'oyentes': '120', 'reproducciones': '269'},
#  {'artista': 'Pietro Tonolo', 'oyentes': '812', 'reproducciones': '6363'},
#  {'artista': 'Luiz Ayrao', 'oyentes': '27954', 'reproducciones': '141694'},
#  {'artista': 'TICO DE MORAES', 'oyentes': '3284', 'reproducciones': '11846'},
#  {'artista': 'Medeski, Martin & Wood',
#   'oyentes': '74395',
#   'reproducciones': '618006'},
#  {'artista': 'Arturo Sandoval',
#   'oyentes': '121102',
#   'reproducciones': '933286'},
#  {'artista': "B's Bees", 'oyentes': '29', 'reproducciones': '289'},
#  {'artista': 'Jackie McLean',
#   'oyentes': '181600',
#   'reproducciones': '1176946'},
#  {'artista': 'Jack Hylton & His Orchestra',
#   'oyentes': '29379',
#   'reproducciones': '145640'},
#  {'artista': 'Bora Çeliker', 'oyentes': '119', 'reproducciones': '551'},
#  {'artista': 'Ohmega Watts', 'oyentes': '50067', 'reproducciones': '543452'},
#  {'artista': 'YoYo the "Pianoman"',
#   'oyentes': '1264',
#   'reproducciones': '3517'},
#  {'artista': 'Kentaro Takizawa', 'oyentes': '6620', 'reproducciones': '48844'},
#  {'artista': 'Herbie Mann', 'oyentes': '196552', 'reproducciones': '1252505'},
#  {'artista': 'Mel Tormé', 'oyentes': '759913', 'reproducciones': '4337902'},
#  {'artista': 'Funkee Boy', 'oyentes': '2622', 'reproducciones': '12288'},
#  {'artista': 'Sugarwork', 'oyentes': '109', 'reproducciones': '365'},
#  {'artista': 'Denise King', 'oyentes': '18310', 'reproducciones': '82546'},
#  {'artista': 'Chano Dominguez', 'oyentes': '2491', 'reproducciones': '14082'},
#  {'artista': 'Javier Colina', 'oyentes': '4717', 'reproducciones': '39864'},
#  {'artista': 'Magalí Sare', 'oyentes': '2418', 'reproducciones': '12747'},
#  {'artista': 'Dani Nel·lo', 'oyentes': '699', 'reproducciones': '5789'},
#  {'artista': 'Chano Dominguez', 'oyentes': '2491', 'reproducciones': '14082'},
#  {'artista': 'Servando Rascón', 'oyentes': '99', 'reproducciones': '148'},
#  {'artista': 'Beny Moré', 'oyentes': '132274', 'reproducciones': '783410'},
#  {'artista': 'Orquesta Aragón',
#   'oyentes': '82756',
#   'reproducciones': '423727'},
#  {'artista': 'Wayne Gorbea', 'oyentes': '13204', 'reproducciones': '67165'},
#  {'artista': 'Joe Cuba', 'oyentes': '67013', 'reproducciones': '322791'},
#  {'artista': 'Joe Cuba', 'oyentes': '67013', 'reproducciones': '322791'},
#  {'artista': 'Gary Burton', 'oyentes': '161077', 'reproducciones': '1110238'},
#  {'artista': 'Bobby Darin',
#   'oyentes': '1207649',
#   'reproducciones': '10657264'},
#  {'artista': 'Jestofunk', 'oyentes': '99206', 'reproducciones': '653798'},
#  {'artista': 'Muff', 'oyentes': '3430', 'reproducciones': '29630'},
#  {'artista': 'Harry James', 'oyentes': '374282', 'reproducciones': '2490746'},
#  {'artista': 'Carlos Lyra', 'oyentes': '138718', 'reproducciones': '736695'},
#  {'artista': 'John Burnsby', 'oyentes': '938', 'reproducciones': '2754'},
#  {'artista': 'Henry "Red" Allen',
#   'oyentes': '17035',
#   'reproducciones': '82246'},
#  {'artista': 'Tito Rodriguez', 'oyentes': '60110', 'reproducciones': '299669'},
#  {'artista': 'Luciana Souza', 'oyentes': '92528', 'reproducciones': '464871'},
#  {'artista': 'Machito', 'oyentes': '64110', 'reproducciones': '362583'},
#  {'artista': 'Howard McGhee', 'oyentes': '15315', 'reproducciones': '82739'},
#  {'artista': 'Coffee House Jazz Club',
#   'oyentes': '983',
#   'reproducciones': '9914'},
#  {'artista': 'Dale Burbeck', 'oyentes': '2645', 'reproducciones': '7003'},
#  {'artista': 'Rob Burke', 'oyentes': '225', 'reproducciones': '1832'},
#  {'artista': 'Luigi Vitale', 'oyentes': '32', 'reproducciones': '147'},
#  {'artista': 'Beny Moré', 'oyentes': '132274', 'reproducciones': '783410'},
#  {'artista': 'Tubby Hayes', 'oyentes': '5228', 'reproducciones': '46932'},
#  {'artista': 'Kendraka', 'oyentes': '229', 'reproducciones': '917'},
#  {'artista': 'King Curtis', 'oyentes': '195452', 'reproducciones': '1118102'},
#  {'artista': 'Joel Lyssarides',
#   'oyentes': '139994',
#   'reproducciones': '721671'},
#  {'artista': 'Lemongrass', 'oyentes': '442686', 'reproducciones': '6256974'},
#  {'artista': 'Urbie Green', 'oyentes': '5682', 'reproducciones': '53001'},
#  {'artista': 'Miriam Makeba',
#   'oyentes': '254361',
#   'reproducciones': '2203945'},
#  {'artista': 'Billy Eckstine',
#   'oyentes': '215873',
#   'reproducciones': '887629'},
#  {'artista': 'Limid', 'oyentes': '772', 'reproducciones': '7635'},
#  {'artista': 'Luca Flores', 'oyentes': '754', 'reproducciones': '13168'},
#  {'artista': 'Illinois Jacquet',
#   'oyentes': '60345',
#   'reproducciones': '296040'},
#  {'artista': 'Living Room', 'oyentes': '346991', 'reproducciones': '3316995'},
#  {'artista': 'Mundell Lowe', 'oyentes': '4244', 'reproducciones': '29705'},
#  {'artista': 'Sarah Vaughan',
#   'oyentes': '1064948',
#   'reproducciones': '10887682'},
#  {'artista': 'Stefan Keller', 'oyentes': '46', 'reproducciones': '146'},
#  {'artista': 'Bola Sete', 'oyentes': '55261', 'reproducciones': '363758'},
#  {'artista': 'Mongo Santamaria',
#   'oyentes': '205504',
#   'reproducciones': '1145501'},
#  {'artista': 'Dale Burbeck', 'oyentes': '2645', 'reproducciones': '7003'},
#  {'artista': 'Thelonious Coltrane',
#   'oyentes': '96019',
#   'reproducciones': '407825'},
#  {'artista': 'Konstantin Klashtorni',
#   'oyentes': '6186',
#   'reproducciones': '71256'},
#  {'artista': 'James Butler', 'oyentes': '15597', 'reproducciones': '229231'}]

# %%
df.head()
# Out:
#             artista oyentes reproducciones
# 0              Gari    5008         102120
# 1       Joan Colomo    8589         219787
# 2  Familia Caamagno     924          19444
# 3     Los Negativos    2284          28506
# 4      Igor Paskual     910          13421

# %%
df = pd.DataFrame(statistics)
df.to_csv('stats_jazz.csv', index=False)

# %% [markdown]
# ------------------

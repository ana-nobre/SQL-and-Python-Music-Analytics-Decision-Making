# %%
import requests
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="api.env")

api_key = os.getenv("API_KEY_LASTFM")  # Asegurate de que este nombre coincide con tu archivo .env

# %%
import json
import pandas as pd

# %%
import csv
with open('list_artist_classical.csv', "r") as archivo:
    lector = csv.reader(archivo)
    lista = list(lector)

# %%
def stats(artist, api_key):
    url = 'http://ws.audioscrobbler.com/2.0/'
    params = {
        'method': 'artist.getinfo',
        'artist' : artist,
        'api_key':  api_key,
        'format': 'json',
        'lang': 'es'
        }

    response = requests.get(url, params=params)
    if response.status_code != 200:
        print(f"Da error")
    else:
        datos = response.json()
        info = datos['artist']['stats'] #extraer listeners y plays por separado
        info_artista = {
            'artista': artist, 
            'oyentes': info.get('listeners'),
            'reproducciones': info.get('playcount')}
        
    return info_artista

# %%
stats("Bach",api_key)
# Out:
# {'artista': 'Bach', 'oyentes': '15549', 'reproducciones': '252239'}

# %%
for i in lista:
    print(i)
# Out:
# ['Wim Mertens']
# ['Bohuslav Martinů']
# ['Johann Sebastian Bach']
# ['Ludwig van Beethoven']
# ['Joseph Haydn']
# ['Christoph Willibald Gluck']
# ['Wolfgang Amadeus Mozart']
# ['George Frideric Handel']
# ['Manuel de Falla']
# ['Julia Wolfe']
# ['Nithyasree Mahadevan']
# ['Richard Strauss']
# ['Fritz Kreisler']
# ['Tanburi Cemil Bey']
# ['Dimanche FR']
# ['Albert Roussel']
# ['Alban Berg']
# ['Tushar Dutta']
# ['Karol Szymanowski']
# ['Charles Koechlin']
# ['Murat Salim Tokac']
# ['Max Reger']
# ['Johannes Brahms']
# ['Pietro Locatelli']
# ['Richard Wagner']
# ['Ole Bull']
# ['Giuseppe Verdi']
# ['Stephen Dodgson']
# ['Pablo Sorozábal']
# ['Henri Dutilleux']
# ['Claude Debussy']
# ['Juan María Solare']
# ['Francois Devienne']
# ['Gustav Mahler']
# ['Simone Pedroni']
# ['Jean Françaix']
# ['Tom Johnson']
# ['Reinhold Glière']
# ['Evan Bogerd']
# ['Niels Rønsholdt']
# ['Alice Ping Yee Ho']
# ['Marcos Antonio Portugal']
# ['Dietrich Buxtehude']
# ['Koushik Bhattacharjee']
# ['Modest Mussorgsky']
# ['João Carlos Martins']
# ['Erik Satie']
# ['Dinos Constantinides']
# ['Giovanni Paisiello']
# ['Edvard Grieg']
# ['Benjamin Britten']
# ['Alfred Schnittke']
# ['André-Ernest-Modeste Grétry']
# ['Francois-Joseph Gossec']
# ['André Jolivet']
# ['Gerald Finzi']
# ['Gideon Klein']
# ['Giovanni Pierluigi da Palestrina']
# ['Antón García Abril']
# ['Luis de Pablo']
# ['Béla Bartók']
# ['Antonín Dvořák']
# ['Dominick Argento']
# ['Jean-Philippe Rameau']
# ['Enrique Granados']
# ['Antonio Vivaldi']
# ['Georg Philipp Telemann']
# ['Gabriel Fauré']
# ['Istvan Szekely']
# ['Bernat Vivancos']
# ['Sérgio de Vasconcellos Corrêa']
# ['Olena Yuriivna Shostko']
# ['Dmitri Shostakovich']
# ['Franz Liszt']
# ['An-Lun Huang']
# ['Herbert Howells']
# ['Carlos Gardel']
# ['Johann Nepomuk Hummel']
# ['Radamés Gnattali']
# ['Michael Gielen']
# ['Johann Baptist Vanhal']
# ['Ariel Ramírez']
# ['Hector Berlioz']
# ['Rahul Vellal']
# ['Matteo Carcassi']
# ['Roman Berger']
# ['Mario Castelnuovo-Tedesco']
# ['Jacqueline Fontyn']
# ['Jules Massenet']
# ['Ignaz Pleyel']
# ['Franz Danzi']
# ['Heitor Villa-Lobos']
# ['Carl Philipp Emanuel Bach']
# ['James Whitbourn']
# ['Charles-Marie Widor']
# ['Carl Heinrich Graun']
# ['Ottorino Respighi']
# ['Muzio Clementi']
# ['Gioachino Rossini']
# ['Tomás Bretón']
# ['Francesco Petrini']
# ['Antonio Soler']
# ['Jean Sibelius']
# ['Toru Takemitsu']
# ['Arcangelo Corelli']
# ['Bedřich Smetana']
# ['Viet Cuong']
# ['Carsten Bo Eriksen']
# ['Luigi Boccherini']
# ['Felix Mendelssohn']
# ['Claudio Monteverdi']
# ['Francisco Tárrega']
# ['Bundu Khan']
# ['Antonio Lauro']
# ['Arthur Moreira Lima']
# ['Fernando Sor']
# ['Alicia de Larrocha']
# ['Barkat Ali Khan']
# ['Vincent Persichetti']
# ['Allan Pettersson']
# ['Severin van Dijk']
# ['Matthew Welch']
# ['Nils Henrik Asheim']
# ['Kenneth Fuchs']
# ['Henryk Górecki']
# ['György Kurtág']
# ['Ian Venables']
# ['Hisako Hiseki']
# ['Richard Barrett']
# ['Alessandro Scarlatti']
# ['Jaromír Weinberger']
# ['Franz Schmidt']
# ['Virgil Thomson']
# ['Geoffrey Poole']
# ['Fridthjov Anderssen']
# ['Michael Finnissy']
# ['Andreas Jakob Romberg']
# ['Paul Hindemith']
# ['Danny Clay']
# ['Christopher Cerrone']
# ['Sebastian Morawietz']
# ['Ruperto Chapí']
# ['Carson Cooman']
# ['David Matthews']
# ['Exam Study Music Company']
# ['Marin Marais']
# ['Camille Saint-Saëns']
# ['Franz Schubert']
# ['Luigi Dallapiccola']
# ['Giovanni Battista Pergolesi']
# ['Marian Sawa']
# ['Dmitry Kabalevsky']
# ['Friedrich Kuhlau']
# ['Georges Bizet']
# ['Brenton Broadstock']
# ['Mieczysław Weinberg']
# ['Garreth Broke']
# ['Selim Palmgren']
# ['Tomás Marco']
# ['Mily Balakirev']
# ['Daan Janssens']
# ['Mikhail Glinka']
# ['Ann Millikan']
# ['Lennox Berkeley']
# ['York Bowen']
# ['Franco Margola']
# ['Michael Nyman']
# ['Luigi Cherubini']
# ['Edward Elgar']
# ['Francisco Mignone']
# ['Scott Joplin']
# ['Frank Martin']
# ['Anton Bruckner']
# ['Guy Bovet']
# ['Duke Ellington']
# ['Alan Weiss']
# ['Alcatrazz']
# ['Carl Friedrich Abel']
# ['T. Brinda']
# ['Hubert Parry']
# ['Vicente Martín Y Soler']
# ['Vissarion Shebalin']
# ['Bekah Simms']
# ['Michael Oesterle']
# ['Carl Nielsen']
# ['Classical Music Orchestra!']
# ['Erich Wolfgang Korngold']
# ['Miriam Hyde']
# ['John Corigliano']
# ['Berglind María Tómasdóttir']
# ['Daniel Ligorio']
# ['Kurt Atterberg']
# ['Karl-Erik Welin']
# ['Dionisio Aguado']
# ['Max Bruch']
# ['Alfred Cortot']
# ['Astor Piazzolla']
# ['Lori Laitman']
# ['Michael Torke']
# ['Michael Haydn']
# ['David Maslanka']
# ['Clemens Gadenstatter']
# ['Georg Joseph Vogler']
# ['Krzysztof Baculewski']
# ['Leoš Janáček']
# ['Domenico Scarlatti']
# ['Helge Iberg']
# ['Joe Cutler']
# ['Michael Gordon']
# ['Édouard Lalo']
# ['Girolamo Frescobaldi']
# ['Nikolai Tcherepnin']
# ['Kaikhosru Sorabji']
# ['György Ligeti']
# ['Piers Hellawell']
# ['Chisako Takashima']
# ['Ernst Krenek']
# ['Isaac Albéniz']
# ['Alexandre Guilmant']
# ['Leonardo Balada']
# ['Maurice Ravel']
# ['Alaturka Records']
# ['Ludomir Rózycki']
# ["Tarik O'Regan"]
# ['Klaus Florian Vogt']
# ['Morton Gould']
# ['Michael Droste']
# ['Nikolai Rimsky-Korsakov']
# ['Maija Einfelde']
# ['Floraleda Sacchi']
# ['Miguel Proença']
# ['Manuel Enríquez']
# ['Granville Bantock']
# ['Joseph Canteloube']
# ['Alexander Scriabin']
# ['Niccolò Jommelli']
# ['Igor Stravinsky']
# ['Enrico Chapela']
# ['Pregnancy Music Consort']
# ['Petr Eben']
# ['Johann Wenzel Kalliwoda']
# ['Franz Xaver Richter']
# ['Nikita Koshkin']
# ['Chromos Tuba Quartet']
# ['Alexander von Zemlinsky']
# ['Johann Simon Mayr']
# ['Julian Anderson']
# ['François Couperin']
# ['Dariusz Przybylski']
# ['Orontes Guitar Quartet']
# ['Marion Bauer']
# ['Dan Locklair']
# ['Philip Glass']
# ['Dieter Schnebel']
# ['Francesco Geminiani']
# ['Rodion Shchedrin']
# ['Bruno Giuffredi']
# ['Ladislav Kubik']
# ['Robert Groslot']
# ['Witold Lutosławski']
# ['Mark Anderson']
# ['Hans Werner Henze']
# ['Johann Georg Albrechtsberger']
# ['Guillaume Dufay']
# ['William Bolcom']
# ['Nicola Jappelli']
# ['Hilary Tann']
# ['Einojuhani Rautavaara']
# ['Charles Griffes']
# ['Alexander Glazunov']
# ['Olivier Messiaen']
# ['Mark John McEncroe']
# ['Naji Hakim']
# ['George Gershwin']
# ['Howard Ferguson']
# ['César Franck']
# ['Beniamino Gigli']
# ['Hiroaki Takaha']
# ['Elbtonal Percussion']
# ['Paul Reale']
# ['Michael Praetorius']
# ['Giuseppe Tartini']
# ['Irina Mejoueva']
# ['Chilly Gonzales']
# ['Hannah Lash']
# ['Bach Electronic']
# ['Benet Casablancas']
# ['Jakub Jan Ryba']
# ['Iván Erőd']
# ['Georgy Sviridov']
# ['Johan de Meij']
# ['Moritz Moszkowski']
# ['Daisuke Suzuki']
# ['Bezmârâ']
# ['Jochen Kowalski']
# ['Leonard Bernstein']
# ['Sigurd Lie']
# ['Clara Schumann']
# ['Armas Järnefelt']
# ['Paul Robeson']
# ['Ralph Vaughan Williams']
# ['Adrian Knight']
# ['Luciano Berio']
# ['Gregers Brinch']
# ['Casey Cangelosi']
# ['Sophie-Carmen Eckhardt-Gramatté']
# ['Carter Pann']
# ['Marcelo Kayath']
# ['Manel Camp']
# ['Franz Hummel']
# ['Roman Vlad']
# ['Giya Kancheli']
# ['Bob Chilcott']
# ['Shulamit Ran']
# ['Thea Musgrave']
# ['Elliott Carter']
# ['Peter Warlock']
# ['Johann Wilhelm Wilms']
# ['Lorenzo Ferrero']
# ['Darius Milhaud']
# ['Federico Moreno Torroba']
# ['Robin Holloway']
# ['Mauro Giuliani']
# ['Andrea Portera']
# ['Henry Purcell']
# ['Johann Adolf Hasse']
# ['Gaspare Spontini']
# ['Franz Anton Hoffmeister']
# ['Instrumental']
# ['Ørjan Matre']
# ['Ross Edwards']
# ['Mikis Theodorakis']
# ['Vernon Duke']
# ["Baby Can't Sleep"]
# ['Vladimir Krpan']
# ['Brain Power Collective']
# ['Judith Weir']
# ['Pablo de Sarasate']
# ['Baby Mozart Orchestra']
# ['Andre Caplet']
# ['Wilhelm Friedemann Bach']
# ['Karl-Birger Blomdahl']
# ['Charles Ives']
# ['Sanjay Subrahmanyan']
# ['Jean-Baptiste Krumpholtz']
# ['Liz Johnson']
# ['David Braid']
# ['Mátti Kovler']
# ['Giovanni Benedetto Platti']
# ['Academy of St. Martin in the Fields']
# ['Manuel Ponce']
# ['Leo Brouwer']
# ['Pietro Mascagni']
# ['John Cage']
# ['Sikkil Gurucharan']
# ['Daniel Roth']
# ['Johannes Wakolbinger']
# ['Arnold Schoenberg']
# ['Saverio Mercadante']
# ['Christian Sinding']
# ['Francis Poulenc']
# ['Malcolm Arnold']
# ['Lowell Liebermann']
# ['Federico Mompou']
# ['Joan Huang']
# ['Christopher Fox']
# ['August Freyer']
# ['Erkki Salmenhaara']
# ['Alberto Nepomuceno']
# ['Mario Lanza']
# ['David Hackbridge Johnson']
# ['Healey Willan']
# ['Ronald Corp']
# ['Lydia Kakabadse']
# ['Erwin Schulhoff']
# ['Gordon Crosse']
# ['Ronald Stevenson']
# ['Mikhail Kollontay']
# ['Mark Allaway']
# ['Camillo Togni']
# ['Richard Danielpour']
# ['Vincenzo Bellini']
# ['Stanisław Moniuszko']
# ['Egon Wellesz']
# ['John McCormack']
# ['Angèle David-Guillou']
# ['Carlos Gomes']
# ['Franz Benda']
# ['Louis Vierne']
# ['Kurt Schwertsik']
# ['Chiel Meijering']
# ['Soundnotation']
# ['Detlev Glanert']
# ['Hans Pfitzner']
# ['Edward W. Hardy']
# ['Mark Bowden']
# ['Conrad Susa']
# ['Diana Blom']
# ['Tangologia']
# ['Ferenc Farkas']
# ['Joaquín Rodrigo']
# ['May Howlett']
# ['Ghulam Mustafa Khan']
# ['The Hilliard Ensemble']
# ['Feliks Nowowiejski']
# ['Johan Helmich Roman']
# ['Ferruccio Busoni']
# ['Carl Reinecke']
# ['숙면 테라피']
# ['Terry Riley']
# ['Ganesh Del Vescovo']
# ['Haro Stepanian']
# ['Girija Devi']
# ['Josef Mysliveček']
# ['Mark Sirett']
# ['Sven-Erik Bäck']
# ['Dirk Herten']
# ['Guy Ropartz']
# ['Ernest Bloch']
# ['José Bragato']
# ['Josquin des Prez']
# ['Charles Gounod']
# ['Giacinto Scelsi']
# ['Arrigo Barnabé']
# ['Marcus Blunt']
# ['Ned Rorem']
# ['Vadim Chaimovich']
# ['Stratis Minakakis']
# ['Robert Fuchs']
# ['Louis-Gabriel Guillemain']
# ['Johann Bernhard Bach']
# ['Samuel Barber']
# ['Eero Hämeenniemi']
# ['Gunnar de Frumerie']
# ['Ödön Pártos']
# ['Claudio Ambrosini']
# ['Cherif Zârour']
# ['Emil Sjögren']
# ['Roman Palester']
# ['Elizabeth Maconchy']
# ['Tibor Harsanyi']
# ['Bop Station']
# ['Vítězslav Novák']
# ['Marcel Dupré']
# ['Zoltán Kodály']
# ['Heinrich Schütz']
# ['Frank Horvat']
# ['Zosha Di Castri']
# ['Hekel Tavares']
# ['Paolo Lazzarini']
# ['Hans Gál']
# ['Angel Ruediger']
# ['Sirkazhi Govindarajan']
# ['Charles-Valentin Alkan']
# ['George Crumb']
# ['Steven Mackey']
# ['Grażyna Bacewicz']
# ['Nicolas Tzortzis']
# ['René Wohlhauser']
# ['Sándor Balassa']
# ['Oded Zehavi']
# ['Johann Kaspar Mertz']
# ['Arthur Somervell']
# ['Germaine Tailleferre']
# ['O. S. Thyagarajan']
# ['Vyacheslav Artyomov']
# ['Julian Byzantine']
# ['Isaías Sávio']
# ['Peter Dickinson']
# ['Elmira Darvarova']
# ['Grigory Frid']
# ['Farida Khanum']
# ['Alessandra Celletti']
# ['Wu Han']
# ['Thomas Oboe Lee']
# ['Stephen Chatman']
# ['Ferdinand Hiller']
# ['Leopold Koželuch']
# ['Endre Szervánszky']
# ['Tadeusz Szeligowski']
# ['Harry Burleigh']
# ['Jaan Rääts']
# ['Roberto Gerhard']
# ['Laurence Crane']
# ['Ernest John Moeran']
# ['Dinu Lipatti']
# ['Bo Gunge']
# ['Samuel Adler']
# ['Roberto Sierra']
# ['Orlande de Lassus']
# ['Jaroslav Krcek']
# ['Amanda Rontgen-Maier']
# ['Kaija Saariaho']
# ['Pehr Henrik Nordgren']
# ['Roxanna Panufnik']
# ['Roman Maciejewski']
# ['Paweł Łukaszewski']
# ['John Beckwith']
# ['Jonathan Dove']
# ['Pärt Uusberg']
# ['Svend Westergaard']
# ['Lalgudi G. Jayaraman']
# ['Pancho Vladigerov']
# ['Steven Bryant']
# ['Benjamin Broening']
# ['Mieczysław Karłowicz']
# ['Julius Röntgen']
# ['BGM Teacher']
# ['Carl Czerny']
# ['Édith Canat de Chizy']
# ['Juan Gutiérrez de Padilla']
# ['Hans Krasa']
# ['Leopold Godowsky']
# ['Egil Hovland']
# ['Edmund Rubbra']
# ['Alberto Ginastera']
# ['Carlo Gesualdo']
# ['Jouko Harjanne']
# ['Rued Langgaard']
# ['Duo Aurore']
# ['Nikolai Medtner']
# ['Chiquinha Gonzaga']
# ['Mario Grigorov']
# ['Stephen Weber']
# ['Ernst von Dohnányi']
# ['Edward Cowie']
# ['Brian Ferneyhough']
# ['Kerry Turner']
# ['Dušan Bogdanović']
# ['Giacomo Meyerbeer']
# ['Claudio Santoro']
# ['Myroslav Skoryk']
# ['Ferde Grofé']
# ['Cristina Spinei']
# ['Emile Naoumoff']
# ['태교 마을']
# ['Carl Friedrich Zelter']
# ['Emilia Zakrzewska']
# ['Carl Maria von Weber']
# ['Milosz Bembinow']
# ['Jehan Alain']
# ['Mambalam Sisters']
# ['Smart Baby Lullaby']
# ['Giuseppe Torelli']
# ['Michael Jarrell']
# ['Joaquín Turina']
# ['Domenico Cimarosa']
# ['Emanuel Kania']
# ['Luigi Legnani']
# ['John Ireland']
# ['Niccolò Paganini']
# ['Manuel Blancafort']
# ['London Symphony Orchestra']
# ['Gregory Spears']
# ['Louis James Alfred Lefébure-Wély']
# ['Marc-Antoine Charpentier']
# ['Agata Zubel']
# ['Kurt Weill']
# ['Tim Frederiksen']
# ['Anders Eliasson']
# ['Daron Hagen']
# ['Majella Cullagh']
# ['Ernst Wilhelm Wolf']
# ['Paul Chihara']
# ['Jordan Munson']
# ['Classical Chillout Masters 101']
# ['Elisabeth Lutyens']
# ['Riccardo Muti']
# ['Svante Henryson']
# ['Walter Gieseking']
# ['Kozaburo Hirai']
# ['Gustav Holst']
# ['Charles Villiers Stanford']
# ['Alexandre Tansman']
# ['David Hernando Vitores']
# ['Louis Spohr']
# ['Laszlo Baranyay']
# ['Sleeping Little Lions']
# ['Norman Dello Joio']
# ['Mario Ruiz Armengol']
# ['Lars Jakob Rudjord']
# ['Xhei Hajro']
# ['Anne LeBaron']
# ['Adam Johnson']
# ['Gabriel Pierné']
# ['Carlos Guastavino']
# ['Volker David Kirchner']
# ['Lullabyes']
# ['Otto Mortensen']
# ['Rainer Sauer']
# ['Jean-François Michel']
# ['Ursula Mamlok']
# ['Alexandre Danilevski']
# ['Trombastic']
# ['Peter Scott Lewis']
# ['Lou Harrison']
# ['Kjell Habbestad']
# ['Arno Babadjanian']
# ['Nikolai Roslavets']
# ['Fredrik Sixten']
# ['Cyril Scott']
# ["Eugen d'Albert"]
# ['Randall Thompson']
# ['Sigfrid Karg-Elert']
# ['Guillaume de Machaut']
# ['Antoine Reicha']
# ['Camargo Guarnieri']
# ['Igor Shamo']
# ['Carlo Domeniconi']
# ['Hadj Mohamed Tahar Fergani']
# ['César Cui']
# ['Klaas de Vries']
# ['Kenneth Hesketh']
# ['Mario Gangi']
# ['Maxim Shalygin']
# ['Jan Ladislav Dussek']
# ['John McLeod']
# ['Classical Meditation Players']
# ['Simon Mulligan']
# ['Sandeep Bhagwati']
# ['Friedrich Wilhelm Rust']
# ['Filippa Möres-Busch']
# ['João Domingos Bomtempo']
# ['Arturo Márquez']
# ['Milana Zilnik']
# ['Jacques Ibert']
# ['Komitas']
# ['Sir Clifford Curzon']
# ['Geirr Tveitt']
# ['Nedunuri Krishnamurthy']
# ['Kosaku Yamada']
# ['William Sabatier']
# ['Harold Truscott']
# ['Antoinette Tredanary']
# ['Zygmunt Stojowski']
# ['Pierre Boulez']
# ['Percy Whitlock']
# ['Michael Daugherty']
# ['Nikolai Obukhov']
# ['Sunleif Rasmussen']
# ['Arnold Rosner']
# ['John Dowland']
# ['Aaron Copland']
# ['Laurel Zucker']
# ['Celso Garrido-Lecca']
# ['Çiğdem Yarkın']
# ['Bedtime Baby']
# ['Juan de Lienas']
# ['Manfred Gurlitt']
# ['Ali Ufki']
# ['Fabian Müller']
# ['José Luis Greco']
# ['Duncan Honeybourne']
# ['Alexander Arutiunian']
# ['Henrik Strindberg']
# ['Jordan Dykstra']
# ['Tomás Garbizu']
# ['Derek Bermel']
# ['Violeta Dinescu']
# ['Tomaso Albinoni']
# ['Sally Beamish']
# ['Alfred Hill']
# ['Peter Ruzicka']
# ['Bruce Paine']
# ['Artur Schnabel']
# ['Peter Racine Fricker']
# ['Gan-Ru Ge']
# ['Hyderabad Brothers']
# ['William Ogmundson']
# ['Salvatore Sciarrino']
# ['Botticelli Trio']
# ['Christoph Ernst Friedrich Weyse']
# ['Mariano Mores']
# ['Gaspar Cassadó']
# ['John Rutter']
# ['Nadanmusic']
# ['Jeroen van Veen']
# ['Gabriel Jackson']
# ['Augusta Read Thomas']
# ['Jason Baker']
# ['Daniel Schnyder']
# ['Aribert Reimann']
# ['Nicolai Gedda']
# ['Pat Muchmore']
# ['Johann Gottlieb Graun']
# ['Nikolaus Brass']
# ['Arthur Honegger']
# ['Lera Auerbach']
# ['Tarun Bhattacharya']
# ['Per Nørgård']
# ['Les Arts Florissants']
# ['John Joubert']
# ['Napoléon Coste']
# ['Theodore Antoniou']
# ['Violina Petrychenko']
# ['Gabriele Mirabassi']
# ['Ludovico Einaudi']
# ['John Field']
# ['Rajhesh Vaidhya']
# ['Milosz Magin']
# ['Ralph Gustafsson']
# ['Giovanni Battista Viotti']
# ['Maximo Diego Pujol']
# ['Emmanuel Chabrier']
# ['Jeremy Menuhin']
# ['Brian Current']
# ['Philippe Gaubert']
# ['Johann Wilhelm Hertel']
# ['Joachim Raff']
# ['Sahan Arzruni']
# ['Vincent Beer-Demander']
# ['Jacques Hétu']
# ['Leo Sowerby']
# ['Fumio Hayasaka']
# ['Carl Ditters von Dittersdorf']
# ['Aram Khachaturian']
# ['Anton Webern']
# ['Joachim Andersen']
# ['Gian Francesco Malipiero']
# ['Henning Christiansen']
# ['Ruben Liljefors']
# ['Sultan Khan']
# ['Nicholas Maw']

# %%
limit = 200
contador = 0
for i in lista:
    if contador >= limit:
        break
    stats(i, api_key)
    contador += 1
    statistics = print(stats(i, api_key))
# Out:
# {'artista': ['Wim Mertens'], 'oyentes': '251430', 'reproducciones': '3082541'}
# {'artista': ['Bohuslav Martinů'], 'oyentes': '47129', 'reproducciones': '335072'}
# {'artista': ['Johann Sebastian Bach'], 'oyentes': '2406517', 'reproducciones': '93134188'}
# {'artista': ['Ludwig van Beethoven'], 'oyentes': '2740026', 'reproducciones': '57282562'}
# {'artista': ['Joseph Haydn'], 'oyentes': '148543', 'reproducciones': '1481606'}
# {'artista': ['Christoph Willibald Gluck'], 'oyentes': '389864', 'reproducciones': '1978949'}
# {'artista': ['Wolfgang Amadeus Mozart'], 'oyentes': '2413391', 'reproducciones': '68952420'}
# {'artista': ['George Frideric Handel'], 'oyentes': '476166', 'reproducciones': '5882095'}
# {'artista': ['Manuel de Falla'], 'oyentes': '151728', 'reproducciones': '750329'}
# {'artista': ['Julia Wolfe'], 'oyentes': '24326', 'reproducciones': '94159'}
# {'artista': ['Nithyasree Mahadevan'], 'oyentes': '2529', 'reproducciones': '14869'}
# {'artista': ['Richard Strauss'], 'oyentes': '522220', 'reproducciones': '4016803'}
# {'artista': ['Fritz Kreisler'], 'oyentes': '204296', 'reproducciones': '1243073'}
# {'artista': ['Tanburi Cemil Bey'], 'oyentes': '7560', 'reproducciones': '57320'}
# {'artista': ['Dimanche FR'], 'oyentes': '348', 'reproducciones': '1344'}
# {'artista': ['Albert Roussel'], 'oyentes': '8199', 'reproducciones': '67433'}
# {'artista': ['Alban Berg'], 'oyentes': '100324', 'reproducciones': '794761'}
# {'artista': ['Tushar Dutta'], 'oyentes': '303', 'reproducciones': '2017'}
# {'artista': ['Karol Szymanowski'], 'oyentes': '76324', 'reproducciones': '521105'}
# {'artista': ['Charles Koechlin'], 'oyentes': '35091', 'reproducciones': '181408'}
# {'artista': ['Murat Salim Tokac'], 'oyentes': '1930', 'reproducciones': '17167'}
# {'artista': ['Max Reger'], 'oyentes': '50724', 'reproducciones': '285822'}
# {'artista': ['Johannes Brahms'], 'oyentes': '1449806', 'reproducciones': '18458919'}
# {'artista': ['Pietro Locatelli'], 'oyentes': '39114', 'reproducciones': '267276'}
# {'artista': ['Richard Wagner'], 'oyentes': '850178', 'reproducciones': '10064365'}
# {'artista': ['Ole Bull'], 'oyentes': '15092', 'reproducciones': '42618'}
# {'artista': ['Giuseppe Verdi'], 'oyentes': '865087', 'reproducciones': '9447742'}
# {'artista': ['Stephen Dodgson'], 'oyentes': '1159', 'reproducciones': '4020'}
# {'artista': ['Pablo Sorozábal'], 'oyentes': '1714', 'reproducciones': '7145'}
# {'artista': ['Henri Dutilleux'], 'oyentes': '26103', 'reproducciones': '183694'}
# {'artista': ['Claude Debussy'], 'oyentes': '1893216', 'reproducciones': '35864617'}
# {'artista': ['Juan María Solare'], 'oyentes': '12648', 'reproducciones': '508307'}
# {'artista': ['Francois Devienne'], 'oyentes': '2091', 'reproducciones': '12665'}
# {'artista': ['Gustav Mahler'], 'oyentes': '720907', 'reproducciones': '7995719'}
# {'artista': ['Simone Pedroni'], 'oyentes': '731', 'reproducciones': '5928'}
# {'artista': ['Jean Françaix'], 'oyentes': '8652', 'reproducciones': '66675'}
# {'artista': ['Tom Johnson'], 'oyentes': '3033', 'reproducciones': '20442'}
# {'artista': ['Reinhold Glière'], 'oyentes': '23315', 'reproducciones': '112650'}
# {'artista': ['Evan Bogerd'], 'oyentes': '24', 'reproducciones': '596'}
# {'artista': ['Niels Rønsholdt'], 'oyentes': '104', 'reproducciones': '1859'}
# {'artista': ['Alice Ping Yee Ho'], 'oyentes': '93', 'reproducciones': '252'}
# {'artista': ['Marcos Antonio Portugal'], 'oyentes': '240', 'reproducciones': '1561'}
# {'artista': ['Dietrich Buxtehude'], 'oyentes': '141981', 'reproducciones': '1255048'}
# {'artista': ['Koushik Bhattacharjee'], 'oyentes': '11', 'reproducciones': '76'}
# {'artista': ['Modest Mussorgsky'], 'oyentes': '200068', 'reproducciones': '1486962'}
# {'artista': ['João Carlos Martins'], 'oyentes': '2073', 'reproducciones': '19053'}
# {'artista': ['Erik Satie'], 'oyentes': '1680415', 'reproducciones': '35159692'}
# {'artista': ['Dinos Constantinides'], 'oyentes': '124', 'reproducciones': '1302'}
# {'artista': ['Giovanni Paisiello'], 'oyentes': '25151', 'reproducciones': '93517'}
# {'artista': ['Edvard Grieg'], 'oyentes': '1278760', 'reproducciones': '13585884'}
# {'artista': ['Benjamin Britten'], 'oyentes': '283269', 'reproducciones': '2429312'}
# {'artista': ['Alfred Schnittke'], 'oyentes': '120666', 'reproducciones': '1267438'}
# {'artista': ['André-Ernest-Modeste Grétry'], 'oyentes': '2304', 'reproducciones': '23595'}
# {'artista': ['Francois-Joseph Gossec'], 'oyentes': '22391', 'reproducciones': '99207'}
# {'artista': ['André Jolivet'], 'oyentes': '4794', 'reproducciones': '43317'}
# {'artista': ['Gerald Finzi'], 'oyentes': '83982', 'reproducciones': '386845'}
# {'artista': ['Gideon Klein'], 'oyentes': '710', 'reproducciones': '3682'}
# {'artista': ['Giovanni Pierluigi da Palestrina'], 'oyentes': '98262', 'reproducciones': '1114231'}
# {'artista': ['Antón García Abril'], 'oyentes': '3837', 'reproducciones': '18260'}
# {'artista': ['Luis de Pablo'], 'oyentes': '629', 'reproducciones': '4011'}
# {'artista': ['Béla Bartók'], 'oyentes': '480427', 'reproducciones': '4804421'}
# {'artista': ['Antonín Dvořák'], 'oyentes': '1171776', 'reproducciones': '12209932'}
# {'artista': ['Dominick Argento'], 'oyentes': '774', 'reproducciones': '7720'}
# {'artista': ['Jean-Philippe Rameau'], 'oyentes': '348948', 'reproducciones': '2871990'}
# {'artista': ['Enrique Granados'], 'oyentes': '107757', 'reproducciones': '579091'}
# {'artista': ['Antonio Vivaldi'], 'oyentes': '1885872', 'reproducciones': '40615816'}
# {'artista': ['Georg Philipp Telemann'], 'oyentes': '407635', 'reproducciones': '4237137'}
# {'artista': ['Gabriel Fauré'], 'oyentes': '907241', 'reproducciones': '7643677'}
# {'artista': ['Istvan Szekely'], 'oyentes': '4605', 'reproducciones': '39482'}
# {'artista': ['Bernat Vivancos'], 'oyentes': '2968', 'reproducciones': '13817'}
# {'artista': ['Sérgio de Vasconcellos Corrêa'], 'oyentes': '4', 'reproducciones': '8'}
# {'artista': ['Olena Yuriivna Shostko'], 'oyentes': '1', 'reproducciones': '1'}
# {'artista': ['Dmitri Shostakovich'], 'oyentes': '980160', 'reproducciones': '11382701'}
# {'artista': ['Franz Liszt'], 'oyentes': '1283353', 'reproducciones': '15398825'}
# {'artista': ['An-Lun Huang'], 'oyentes': '214', 'reproducciones': '598'}
# {'artista': ['Herbert Howells'], 'oyentes': '33170', 'reproducciones': '167125'}
# {'artista': ['Carlos Gardel'], 'oyentes': '229935', 'reproducciones': '2483652'}
# {'artista': ['Johann Nepomuk Hummel'], 'oyentes': '84190', 'reproducciones': '430702'}
# {'artista': ['Radamés Gnattali'], 'oyentes': '4750', 'reproducciones': '34423'}
# {'artista': ['Michael Gielen'], 'oyentes': '1308', 'reproducciones': '9120'}
# {'artista': ['Johann Baptist Vanhal'], 'oyentes': '22379', 'reproducciones': '141080'}
# {'artista': ['Ariel Ramírez'], 'oyentes': '13148', 'reproducciones': '117518'}
# {'artista': ['Hector Berlioz'], 'oyentes': '442556', 'reproducciones': '2595222'}
# {'artista': ['Rahul Vellal'], 'oyentes': '483', 'reproducciones': '3388'}
# {'artista': ['Matteo Carcassi'], 'oyentes': '9615', 'reproducciones': '85289'}
# {'artista': ['Roman Berger'], 'oyentes': '113', 'reproducciones': '330'}
# {'artista': ['Mario Castelnuovo-Tedesco'], 'oyentes': '20137', 'reproducciones': '117215'}
# {'artista': ['Jacqueline Fontyn'], 'oyentes': '152', 'reproducciones': '1061'}
# {'artista': ['Jules Massenet'], 'oyentes': '384143', 'reproducciones': '1636911'}
# {'artista': ['Ignaz Pleyel'], 'oyentes': '3620', 'reproducciones': '26052'}
# {'artista': ['Franz Danzi'], 'oyentes': '15243', 'reproducciones': '66492'}
# {'artista': ['Heitor Villa-Lobos'], 'oyentes': '161968', 'reproducciones': '1683911'}
# {'artista': ['Carl Philipp Emanuel Bach'], 'oyentes': '475278', 'reproducciones': '3064685'}
# {'artista': ['James Whitbourn'], 'oyentes': '16984', 'reproducciones': '91576'}
# {'artista': ['Charles-Marie Widor'], 'oyentes': '14819', 'reproducciones': '101295'}
# {'artista': ['Carl Heinrich Graun'], 'oyentes': '3561', 'reproducciones': '28450'}
# {'artista': ['Ottorino Respighi'], 'oyentes': '314394', 'reproducciones': '2205436'}
# {'artista': ['Muzio Clementi'], 'oyentes': '113865', 'reproducciones': '592915'}
# {'artista': ['Gioachino Rossini'], 'oyentes': '197751', 'reproducciones': '1307164'}
# {'artista': ['Tomás Bretón'], 'oyentes': '1277', 'reproducciones': '8023'}
# {'artista': ['Francesco Petrini'], 'oyentes': '275', 'reproducciones': '1094'}
# {'artista': ['Antonio Soler'], 'oyentes': '14897', 'reproducciones': '98453'}
# {'artista': ['Jean Sibelius'], 'oyentes': '882948', 'reproducciones': '8175989'}
# {'artista': ['Toru Takemitsu'], 'oyentes': '47788', 'reproducciones': '259932'}
# {'artista': ['Arcangelo Corelli'], 'oyentes': '351537', 'reproducciones': '3790257'}
# {'artista': ['Bedřich Smetana'], 'oyentes': '442292', 'reproducciones': '2390900'}
# {'artista': ['Viet Cuong'], 'oyentes': '1281', 'reproducciones': '8373'}
# {'artista': ['Carsten Bo Eriksen'], 'oyentes': '616', 'reproducciones': '2033'}
# {'artista': ['Luigi Boccherini'], 'oyentes': '473165', 'reproducciones': '2694009'}
# {'artista': ['Felix Mendelssohn'], 'oyentes': '1042449', 'reproducciones': '10165637'}
# {'artista': ['Claudio Monteverdi'], 'oyentes': '253382', 'reproducciones': '2665202'}
# {'artista': ['Francisco Tárrega'], 'oyentes': '184035', 'reproducciones': '1500996'}
# {'artista': ['Bundu Khan'], 'oyentes': '226', 'reproducciones': '1112'}
# {'artista': ['Antonio Lauro'], 'oyentes': '33338', 'reproducciones': '252480'}
# {'artista': ['Arthur Moreira Lima'], 'oyentes': '4499', 'reproducciones': '49107'}
# {'artista': ['Fernando Sor'], 'oyentes': '90429', 'reproducciones': '668345'}
# {'artista': ['Alicia de Larrocha'], 'oyentes': '40926', 'reproducciones': '302799'}
# {'artista': ['Barkat Ali Khan'], 'oyentes': '146', 'reproducciones': '639'}
# {'artista': ['Vincent Persichetti'], 'oyentes': '7017', 'reproducciones': '40926'}
# {'artista': ['Allan Pettersson'], 'oyentes': '4828', 'reproducciones': '49615'}
# {'artista': ['Severin van Dijk'], 'oyentes': '38', 'reproducciones': '204'}
# {'artista': ['Matthew Welch'], 'oyentes': '635', 'reproducciones': '6056'}
# {'artista': ['Nils Henrik Asheim'], 'oyentes': '415', 'reproducciones': '3123'}
# {'artista': ['Kenneth Fuchs'], 'oyentes': '2438', 'reproducciones': '9086'}
# {'artista': ['Henryk Górecki'], 'oyentes': '206477', 'reproducciones': '1463316'}
# {'artista': ['György Kurtág'], 'oyentes': '41471', 'reproducciones': '373101'}
# {'artista': ['Ian Venables'], 'oyentes': '284', 'reproducciones': '2008'}
# {'artista': ['Hisako Hiseki'], 'oyentes': '235', 'reproducciones': '1624'}
# {'artista': ['Richard Barrett'], 'oyentes': '2499', 'reproducciones': '15127'}
# {'artista': ['Alessandro Scarlatti'], 'oyentes': '111936', 'reproducciones': '793038'}
# {'artista': ['Jaromír Weinberger'], 'oyentes': '1146', 'reproducciones': '3504'}
# {'artista': ['Franz Schmidt'], 'oyentes': '7084', 'reproducciones': '35795'}
# {'artista': ['Virgil Thomson'], 'oyentes': '4320', 'reproducciones': '22945'}
# {'artista': ['Geoffrey Poole'], 'oyentes': '208', 'reproducciones': '753'}
# {'artista': ['Fridthjov Anderssen'], 'oyentes': '23', 'reproducciones': '172'}
# {'artista': ['Michael Finnissy'], 'oyentes': '8905', 'reproducciones': '47578'}
# {'artista': ['Andreas Jakob Romberg'], 'oyentes': '473', 'reproducciones': '2125'}
# {'artista': ['Paul Hindemith'], 'oyentes': '98141', 'reproducciones': '684582'}
# {'artista': ['Danny Clay'], 'oyentes': '2621', 'reproducciones': '34041'}
# {'artista': ['Christopher Cerrone'], 'oyentes': '2089', 'reproducciones': '16627'}
# {'artista': ['Sebastian Morawietz'], 'oyentes': '3261', 'reproducciones': '18370'}
# {'artista': ['Ruperto Chapí'], 'oyentes': '1190', 'reproducciones': '5965'}
# {'artista': ['Carson Cooman'], 'oyentes': '645', 'reproducciones': '6051'}
# {'artista': ['David Matthews'], 'oyentes': '53609', 'reproducciones': '293843'}
# {'artista': ['Exam Study Music Company'], 'oyentes': '16', 'reproducciones': '91'}
# {'artista': ['Marin Marais'], 'oyentes': '121906', 'reproducciones': '1122004'}
# {'artista': ['Camille Saint-Saëns'], 'oyentes': '1342982', 'reproducciones': '14987296'}
# {'artista': ['Franz Schubert'], 'oyentes': '1400722', 'reproducciones': '17098380'}
# {'artista': ['Luigi Dallapiccola'], 'oyentes': '6002', 'reproducciones': '58749'}
# {'artista': ['Giovanni Battista Pergolesi'], 'oyentes': '210304', 'reproducciones': '1710973'}
# {'artista': ['Marian Sawa'], 'oyentes': '175', 'reproducciones': '4923'}
# {'artista': ['Dmitry Kabalevsky'], 'oyentes': '21199', 'reproducciones': '111555'}
# {'artista': ['Friedrich Kuhlau'], 'oyentes': '14523', 'reproducciones': '72564'}
# {'artista': ['Georges Bizet'], 'oyentes': '839990', 'reproducciones': '6623236'}
# {'artista': ['Brenton Broadstock'], 'oyentes': '91', 'reproducciones': '535'}
# {'artista': ['Mieczysław Weinberg'], 'oyentes': '15116', 'reproducciones': '137308'}
# {'artista': ['Garreth Broke'], 'oyentes': '57182', 'reproducciones': '193429'}
# {'artista': ['Selim Palmgren'], 'oyentes': '11236', 'reproducciones': '41038'}
# {'artista': ['Tomás Marco'], 'oyentes': '731', 'reproducciones': '3924'}
# {'artista': ['Mily Balakirev'], 'oyentes': '29111', 'reproducciones': '137499'}
# {'artista': ['Daan Janssens'], 'oyentes': '28', 'reproducciones': '110'}
# {'artista': ['Mikhail Glinka'], 'oyentes': '58680', 'reproducciones': '220654'}
# {'artista': ['Ann Millikan'], 'oyentes': '74', 'reproducciones': '265'}
# {'artista': ['Lennox Berkeley'], 'oyentes': '4719', 'reproducciones': '23868'}
# {'artista': ['York Bowen'], 'oyentes': '2776', 'reproducciones': '22006'}
# {'artista': ['Franco Margola'], 'oyentes': '308', 'reproducciones': '2515'}
# {'artista': ['Michael Nyman'], 'oyentes': '732080', 'reproducciones': '11408205'}
# {'artista': ['Luigi Cherubini'], 'oyentes': '41799', 'reproducciones': '211095'}
# {'artista': ['Edward Elgar'], 'oyentes': '327441', 'reproducciones': '2459718'}
# {'artista': ['Francisco Mignone'], 'oyentes': '19558', 'reproducciones': '69181'}
# {'artista': ['Scott Joplin'], 'oyentes': '227558', 'reproducciones': '1709315'}
# {'artista': ['Frank Martin'], 'oyentes': '9411', 'reproducciones': '68509'}
# {'artista': ['Anton Bruckner'], 'oyentes': '292732', 'reproducciones': '1966100'}
# {'artista': ['Guy Bovet'], 'oyentes': '412', 'reproducciones': '1942'}
# {'artista': ['Duke Ellington'], 'oyentes': '1407498', 'reproducciones': '21297949'}
# {'artista': ['Alan Weiss'], 'oyentes': '353', 'reproducciones': '2680'}
# {'artista': ['Alcatrazz'], 'oyentes': '89175', 'reproducciones': '1066081'}
# {'artista': ['Carl Friedrich Abel'], 'oyentes': '18238', 'reproducciones': '121480'}
# {'artista': ['T. Brinda'], 'oyentes': '50', 'reproducciones': '157'}
# {'artista': ['Hubert Parry'], 'oyentes': '39619', 'reproducciones': '192518'}
# {'artista': ['Vicente Martín Y Soler'], 'oyentes': '353', 'reproducciones': '8462'}
# {'artista': ['Vissarion Shebalin'], 'oyentes': '1200', 'reproducciones': '5527'}
# {'artista': ['Bekah Simms'], 'oyentes': '143', 'reproducciones': '432'}
# {'artista': ['Michael Oesterle'], 'oyentes': '141', 'reproducciones': '609'}
# {'artista': ['Carl Nielsen'], 'oyentes': '113305', 'reproducciones': '583766'}
# {'artista': ['Classical Music Orchestra!'], 'oyentes': '181', 'reproducciones': '1201'}
# {'artista': ['Erich Wolfgang Korngold'], 'oyentes': '66451', 'reproducciones': '327343'}
# {'artista': ['Miriam Hyde'], 'oyentes': '984', 'reproducciones': '6989'}
# {'artista': ['John Corigliano'], 'oyentes': '48666', 'reproducciones': '262551'}
# {'artista': ['Berglind María Tómasdóttir'], 'oyentes': '187', 'reproducciones': '405'}
# {'artista': ['Daniel Ligorio'], 'oyentes': '184', 'reproducciones': '922'}
# {'artista': ['Kurt Atterberg'], 'oyentes': '11304', 'reproducciones': '75885'}
# {'artista': ['Karl-Erik Welin'], 'oyentes': '184', 'reproducciones': '493'}
# {'artista': ['Dionisio Aguado'], 'oyentes': '4815', 'reproducciones': '26960'}
# {'artista': ['Max Bruch'], 'oyentes': '269792', 'reproducciones': '1320910'}
# {'artista': ['Alfred Cortot'], 'oyentes': '14335', 'reproducciones': '185040'}
# {'artista': ['Astor Piazzolla'], 'oyentes': '415824', 'reproducciones': '6705030'}
# {'artista': ['Lori Laitman'], 'oyentes': '624', 'reproducciones': '4321'}
# {'artista': ['Michael Torke'], 'oyentes': '6403', 'reproducciones': '40948'}
# {'artista': ['Michael Haydn'], 'oyentes': '51873', 'reproducciones': '294489'}

# %%
df = pd.DataFrame(statistics)
df.to_csv('stats_classical.csv', index=False)

# %% [markdown]
# ------------------

# %%
import os
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import pandas as pd

# %%
import os
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Specify the path to your .env file
env_path = '/Users/ananobre/Adalab_Bootcamp/Projetos Pessoais para Git/SQL-and-Python-Music-Analytics-Decision-Making/api.env'
load_dotenv(dotenv_path=env_path)

CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')

if not CLIENT_ID or not CLIENT_SECRET:
    raise ValueError("CLIENT_ID or CLIENT_SECRET not found in environment variables. "
                     "Please check your api.env file and path.")

auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

print("Successfully authenticated with Spotify!")
# Out:
# Successfully authenticated with Spotify!

# %%
def album(genre):
    resultados_album = []

    for offset in range(0, 500, 50):  # hasta 500 resultados (Spotify limita a 1000 máx)
        datos = sp.search(q=f'{genre}', type='album', limit=50, offset=offset)

        for album in datos['albums']['items']:
            release_date = album.get('release_date', '')
            for year in range(2016, 2021):  # años 2016 a 2020
                if release_date.startswith(str(year)):
                    info = {
                        'album': album['name'],
                        'fecha': release_date,
                        'tipo': album['album_type'],
                        'id': album['id']  # puedes eliminar esto si no lo necesitas
                    }
                    print("El nombre del álbum es:", info['album'])
                    print("La fecha de lanzamiento es:", info['fecha'])
                    print("Tipo:", info['tipo'])
                    print("..........")
                    
                    resultados_album.append(info)
                    break

    return resultados_album

# %%
album("pop")
# Out:
# El nombre del álbum es: Pop Hits 2012-2015
# La fecha de lanzamiento es: 2019-08-09
# Tipo: compilation
# ..........
# El nombre del álbum es: Popular Monster
# La fecha de lanzamiento es: 2019-11-20
# Tipo: single
# ..........
# El nombre del álbum es: POPSTAR (feat. Drake)
# La fecha de lanzamiento es: 2020-07-17
# Tipo: single
# ..........
# El nombre del álbum es: Pop 2
# La fecha de lanzamiento es: 2017-12-15
# Tipo: album
# ..........
# El nombre del álbum es: Pop Food
# La fecha de lanzamiento es: 2017-03-25
# Tipo: album
# ..........
# El nombre del álbum es: Meet The Woo
# La fecha de lanzamiento es: 2019-07-26
# Tipo: album
# ..........
# El nombre del álbum es: City Pop
# La fecha de lanzamiento es: 2019-02-15
# Tipo: album
# ..........
# El nombre del álbum es: Meet The Woo 2
# La fecha de lanzamiento es: 2020-02-07
# Tipo: album
# ..........
# El nombre del álbum es: Shoot For The Stars Aim For The Moon
# La fecha de lanzamiento es: 2020-07-03
# Tipo: album
# ..........
# El nombre del álbum es: POP
# La fecha de lanzamiento es: 2020-05-29
# Tipo: album
# ..........
# El nombre del álbum es: Shoot For The Stars Aim For The Moon (Deluxe)
# La fecha de lanzamiento es: 2020-07-20
# Tipo: album
# ..........
# El nombre del álbum es: POP
# La fecha de lanzamiento es: 2018-12-14
# Tipo: album
# ..........
# El nombre del álbum es: Pop
# La fecha de lanzamiento es: 2017-08-30
# Tipo: single
# ..........
# El nombre del álbum es: POP
# La fecha de lanzamiento es: 2019-06-28
# Tipo: single
# ..........
# El nombre del álbum es: pop
# La fecha de lanzamiento es: 2018-10-01
# Tipo: album
# ..........
# El nombre del álbum es: Pop
# La fecha de lanzamiento es: 2016-10-07
# Tipo: single
# ..........
# El nombre del álbum es: Popstar: Never Stop Never Stopping
# La fecha de lanzamiento es: 2016-06-03
# Tipo: album
# ..........
# El nombre del álbum es: Piano Pop Covers
# La fecha de lanzamiento es: 2019-11-22
# Tipo: album
# ..........
# El nombre del álbum es: La Popi
# La fecha de lanzamiento es: 2020-04-24
# Tipo: single
# ..........
# El nombre del álbum es: El Templo del Pop, Vol. 2
# La fecha de lanzamiento es: 2016-09-23
# Tipo: album
# ..........
# El nombre del álbum es: POP
# La fecha de lanzamiento es: 2017-03-24
# Tipo: single
# ..........
# El nombre del álbum es: Popotão Grandão
# La fecha de lanzamiento es: 2018-01-03
# Tipo: single
# ..........
# El nombre del álbum es: I Disagree
# La fecha de lanzamiento es: 2020-01-10
# Tipo: album
# ..........
# El nombre del álbum es: Popopop
# La fecha de lanzamiento es: 2019-10-04
# Tipo: single
# ..........
# El nombre del álbum es: Afro Pop, Vol. 1
# La fecha de lanzamiento es: 2020-08-21
# Tipo: album
# ..........
# El nombre del álbum es: Paranoia Pop
# La fecha de lanzamiento es: 2020-01-01
# Tipo: album
# ..........
# El nombre del álbum es: Baladas Pop Para Bebés
# La fecha de lanzamiento es: 2017-02-10
# Tipo: album
# ..........
# El nombre del álbum es: POP VIRUS
# La fecha de lanzamiento es: 2018-12-19
# Tipo: album
# ..........
# El nombre del álbum es: Shop: A Pop Opera
# La fecha de lanzamiento es: 2020-03-08
# Tipo: album
# ..........
# El nombre del álbum es: WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) [Remix]
# La fecha de lanzamiento es: 2020-06-24
# Tipo: single
# ..........
# El nombre del álbum es: Golden Years Of Dutch Pop Music
# La fecha de lanzamiento es: 2016-04-08
# Tipo: album
# ..........
# El nombre del álbum es: Meet The Woo 2 (Deluxe)
# La fecha de lanzamiento es: 2020-02-12
# Tipo: album
# ..........
# El nombre del álbum es: La Voz Popular de América
# La fecha de lanzamiento es: 2017-12-01
# Tipo: album
# ..........
# El nombre del álbum es: Azulejos
# La fecha de lanzamiento es: 2017-06-09
# Tipo: album
# ..........
# El nombre del álbum es: Mary Poppins Returns (Original Motion Picture Soundtrack)
# La fecha de lanzamiento es: 2018-12-07
# Tipo: compilation
# ..........
# El nombre del álbum es: Poppin’on!
# La fecha de lanzamiento es: 2019-01-30
# Tipo: album
# ..........
# El nombre del álbum es: Pop Heart
# La fecha de lanzamiento es: 2018-11-16
# Tipo: album
# ..........
# El nombre del álbum es: Cipri Popescu
# La fecha de lanzamiento es: 2020-05-22
# Tipo: album
# ..........
# El nombre del álbum es: FIXTAPE
# La fecha de lanzamiento es: 2020-08-07
# Tipo: album
# ..........
# El nombre del álbum es: Flexin'
# La fecha de lanzamiento es: 2019-06-28
# Tipo: single
# ..........
# El nombre del álbum es: Ya No Vives en Mí (Versión Pop) (feat. Carlos Rivera)
# La fecha de lanzamiento es: 2018-03-23
# Tipo: single
# ..........
# El nombre del álbum es: POP RETRO
# La fecha de lanzamiento es: 2020-11-13
# Tipo: compilation
# ..........
# El nombre del álbum es: Pop Corn e patatine
# La fecha de lanzamiento es: 2018-02-03
# Tipo: single
# ..........
# El nombre del álbum es: 90's Pop Tour (En Vivo) [Deluxe Edition]
# La fecha de lanzamiento es: 2017-07-07
# Tipo: compilation
# ..........
# El nombre del álbum es: Pop Star
# La fecha de lanzamiento es: 2018-01-27
# Tipo: single
# ..........
# El nombre del álbum es: Forever
# La fecha de lanzamiento es: 2018-07-20
# Tipo: album
# ..........
# El nombre del álbum es: Pophits für Babys im Spieluhrensound
# La fecha de lanzamiento es: 2020-01-10
# Tipo: album
# ..........
# El nombre del álbum es: La Tripleta Popular, Vol. 4
# La fecha de lanzamiento es: 2017-11-11
# Tipo: album
# ..........
# El nombre del álbum es: Come Over (feat. Popcaan)
# La fecha de lanzamiento es: 2020-10-01
# Tipo: single
# ..........
# El nombre del álbum es: Chillout Pop inc. John Legend, Miley Cyrus & John Mayer
# La fecha de lanzamiento es: 2019-04-19
# Tipo: compilation
# ..........
# El nombre del álbum es: Piano Covers Vol.1 - Relaxing Piano Music - Best of Pop Hits and Classical Piano Masterpieces
# La fecha de lanzamiento es: 2019-11-24
# Tipo: compilation
# ..........
# El nombre del álbum es: MPR
# La fecha de lanzamiento es: 2019-06-28
# Tipo: single
# ..........
# El nombre del álbum es: Pop en español 2000s
# La fecha de lanzamiento es: 2020-08-14
# Tipo: compilation
# ..........
# El nombre del álbum es: Popsi Og Krelles Godnatsange - 9 Sange Til At Falde I Søvn På
# La fecha de lanzamiento es: 2019-11-21
# Tipo: album
# ..........
# El nombre del álbum es: Violent Pop
# La fecha de lanzamiento es: 2020-03-06
# Tipo: album
# ..........
# El nombre del álbum es: Candy Pop
# La fecha de lanzamiento es: 2018-01-12
# Tipo: single
# ..........
# El nombre del álbum es: TrapStar Turnt PopStar
# La fecha de lanzamiento es: 2019-05-02
# Tipo: album
# ..........
# El nombre del álbum es: My Type
# La fecha de lanzamiento es: 2018-03-09
# Tipo: single
# ..........
# El nombre del álbum es: Slide (Remix) (feat. Pop Smoke, A Boogie Wit da Hoodie & Chris Brown) (feat. Pop Smoke)
# La fecha de lanzamiento es: 2020-01-17
# Tipo: single
# ..........
# El nombre del álbum es: Like It on Top
# La fecha de lanzamiento es: 2018-09-14
# Tipo: album
# ..........
# El nombre del álbum es: Pop Machine: Minsan
# La fecha de lanzamiento es: 2019-10-04
# Tipo: single
# ..........
# El nombre del álbum es: Pop Tracks
# La fecha de lanzamiento es: 2016-09-29
# Tipo: album
# ..........
# El nombre del álbum es: Popopop (Frapcore Remix)
# La fecha de lanzamiento es: 2019-11-13
# Tipo: single
# ..........
# El nombre del álbum es: Ova Dweet - Single
# La fecha de lanzamiento es: 2016-04-28
# Tipo: single
# ..........
# El nombre del álbum es: Addicted (Produced by Anju Blaxx)
# La fecha de lanzamiento es: 2017-10-20
# Tipo: single
# ..........
# El nombre del álbum es: 90's Pop Tour, Vol. 3 (En Vivo)
# La fecha de lanzamiento es: 2019-03-29
# Tipo: compilation
# ..........
# El nombre del álbum es: Baby Yuh Tight
# La fecha de lanzamiento es: 2019-07-03
# Tipo: single
# ..........
# El nombre del álbum es: Family
# La fecha de lanzamiento es: 2017-10-30
# Tipo: single
# ..........
# El nombre del álbum es: Sing With Me A Kids Pop Music Adventure
# La fecha de lanzamiento es: 2018-10-08
# Tipo: album
# ..........
# El nombre del álbum es: Rockstar (Popstar Edition)
# La fecha de lanzamiento es: 2018-12-07
# Tipo: album
# ..........
# El nombre del álbum es: De 60 meest populaire kinderliedjes
# La fecha de lanzamiento es: 2016-04-14
# Tipo: album
# ..........
# El nombre del álbum es: Risky
# La fecha de lanzamiento es: 2019-10-23
# Tipo: single
# ..........
# El nombre del álbum es: Pop Latino 00´s
# La fecha de lanzamiento es: 2020-08-21
# Tipo: compilation
# ..........
# El nombre del álbum es: Mecánica Popular
# La fecha de lanzamiento es: 2019-12-20
# Tipo: album
# ..........
# El nombre del álbum es: Hjulene På Bussen – 20 Af De Bedste Børnesange
# La fecha de lanzamiento es: 2017-11-15
# Tipo: album
# ..........
# El nombre del álbum es: Breakthrough!
# La fecha de lanzamiento es: 2020-06-24
# Tipo: album
# ..........
# El nombre del álbum es: Feel Good
# La fecha de lanzamiento es: 2016-02-14
# Tipo: single
# ..........
# El nombre del álbum es: Populiariausios Vaikiškos Dainelės Ir Žaidimai
# La fecha de lanzamiento es: 2018-03-07
# Tipo: album
# ..........
# El nombre del álbum es: Popular Covers - Saregama & Pehchan Music, Vol. 1
# La fecha de lanzamiento es: 2019-08-28
# Tipo: compilation
# ..........
# El nombre del álbum es: Popkorni
# La fecha de lanzamiento es: 2017-08-28
# Tipo: album
# ..........
# El nombre del álbum es: Pop Noir
# La fecha de lanzamiento es: 2018-06-05
# Tipo: compilation
# ..........
# El nombre del álbum es: Brasil Encanta - Brazilian Pop
# La fecha de lanzamiento es: 2016-07-29
# Tipo: compilation
# ..........
# El nombre del álbum es: 不能說的秘密 "Secret" & Pop - Piano Collection
# La fecha de lanzamiento es: 2016-01-08
# Tipo: album
# ..........
# El nombre del álbum es: Friends (with BloodPop®)
# La fecha de lanzamiento es: 2017-08-17
# Tipo: single
# ..........
# El nombre del álbum es: Romántico Pop
# La fecha de lanzamiento es: 2019-06-07
# Tipo: compilation
# ..........
# El nombre del álbum es: Caucas Pop 2016
# La fecha de lanzamiento es: 2016-10-03
# Tipo: album
# ..........
# El nombre del álbum es: Vanquish
# La fecha de lanzamiento es: 2019-12-20
# Tipo: album
# ..........
# El nombre del álbum es: Hopia Mani Popcorn, Vol. 2
# La fecha de lanzamiento es: 2019-04-02
# Tipo: compilation
# ..........
# El nombre del álbum es: Biraz Pop Biraz Sezen
# La fecha de lanzamiento es: 2017-01-23
# Tipo: album
# ..........
# El nombre del álbum es: Rataria Popular Brasileira
# La fecha de lanzamiento es: 2019-11-21
# Tipo: album
# ..........
# El nombre del álbum es: Inviolable - Single
# La fecha de lanzamiento es: 2018-03-09
# Tipo: single
# ..........
# El nombre del álbum es: Lullabies: Most Popular Tunes and Nursery Rhymes for Babies
# La fecha de lanzamiento es: 2016-12-07
# Tipo: album
# ..........
# El nombre del álbum es: Pop Art
# La fecha de lanzamiento es: 2017-06-18
# Tipo: album
# ..........
# El nombre del álbum es: POP.
# La fecha de lanzamiento es: 2017-03-17
# Tipo: album
# ..........
# El nombre del álbum es: More Than You Know
# La fecha de lanzamiento es: 2017-07-28
# Tipo: album
# ..........
# [{'album': 'Pop Hits 2012-2015',
#   'fecha': '2019-08-09',
#   'tipo': 'compilation',
#   'id': '51Z21bW6Pc6JRx9Iob7gno'},
#  {'album': 'Popular Monster',
#   'fecha': '2019-11-20',
#   'tipo': 'single',
#   'id': '4gxFqhVYU4wp1XDH1KiIo4'},
#  {'album': 'POPSTAR (feat. Drake)',
#   'fecha': '2020-07-17',
#   'tipo': 'single',
#   'id': '5nNtpPsSUgb9Hlb3dF1gXa'},
#  {'album': 'Pop 2',
#   'fecha': '2017-12-15',
#   'tipo': 'album',
#   'id': '2HIwUmdxEl7SeWa1ndH5wC'},
#  {'album': 'Pop Food',
#   'fecha': '2017-03-25',
#   'tipo': 'album',
#   'id': '1RHa1VdX6lsLbeedgsV1cb'},
#  {'album': 'Meet The Woo',
#   'fecha': '2019-07-26',
#   'tipo': 'album',
#   'id': '6d1vGZsr6Uy3h9IigBpPAf'},
#  {'album': 'City Pop',
#   'fecha': '2019-02-15',
#   'tipo': 'album',
#   'id': '249z3MS2m8SeEeDuoDVjWB'},
#  {'album': 'Meet The Woo 2',
#   'fecha': '2020-02-07',
#   'tipo': 'album',
#   'id': '4MZnolldq7ciKKlbVDzLm5'},
#  {'album': 'Shoot For The Stars Aim For The Moon',
#   'fecha': '2020-07-03',
#   'tipo': 'album',
#   'id': '7e7t0MCrNDcJZsPwUKjmOc'},
#  {'album': 'POP',
#   'fecha': '2020-05-29',
#   'tipo': 'album',
#   'id': '78qD6T34x0zDcg3PFyh4zl'},
#  {'album': 'Shoot For The Stars Aim For The Moon (Deluxe)',
#   'fecha': '2020-07-20',
#   'tipo': 'album',
#   'id': '2MDU46hcBn3u94s46BOSdv'},
#  {'album': 'POP',
#   'fecha': '2018-12-14',
#   'tipo': 'album',
#   'id': '0szC3aA7V8qdBFRbHZwlX6'},
#  {'album': 'Pop',
#   'fecha': '2017-08-30',
#   'tipo': 'single',
#   'id': '223iwdcpZPEO9xnXJtrZMo'},
#  {'album': 'POP',
#   'fecha': '2019-06-28',
#   'tipo': 'single',
#   'id': '1VrLTUE5ivuWa49Cd63MSx'},
#  {'album': 'pop',
#   'fecha': '2018-10-01',
#   'tipo': 'album',
#   'id': '01NJZ9IvH2w0291m9atK96'},
#  {'album': 'Pop',
#   'fecha': '2016-10-07',
#   'tipo': 'single',
#   'id': '7D7qUgx5iAYJ0TaGsuQqTv'},
#  {'album': 'Popstar: Never Stop Never Stopping',
#   'fecha': '2016-06-03',
#   'tipo': 'album',
#   'id': '07fcZXkBS0y4Y80GT60PZq'},
#  {'album': 'Piano Pop Covers',
#   'fecha': '2019-11-22',
#   'tipo': 'album',
#   'id': '1KQhp9DHKaTIHws6iwgtyd'},
#  {'album': 'La Popi',
#   'fecha': '2020-04-24',
#   'tipo': 'single',
#   'id': '1RhIzoLC3C9dyDu4E2X0Sg'},
#  {'album': 'El Templo del Pop, Vol. 2',
#   'fecha': '2016-09-23',
#   'tipo': 'album',
#   'id': '7hfkdtulZht6MCFAvvXEGl'},
#  {'album': 'POP',
#   'fecha': '2017-03-24',
#   'tipo': 'single',
#   'id': '1l7q5CXuXdKs2rmYMEBSiS'},
#  {'album': 'Popotão Grandão',
#   'fecha': '2018-01-03',
#   'tipo': 'single',
#   'id': '0DWDEZ0R8mkCVvVZJXOIcN'},
#  {'album': 'I Disagree',
#   'fecha': '2020-01-10',
#   'tipo': 'album',
#   'id': '4uTce2w80loIu3oLnW0irN'},
#  {'album': 'Popopop',
#   'fecha': '2019-10-04',
#   'tipo': 'single',
#   'id': '0JJoNDGjK0N0SolzcDQpbX'},
#  {'album': 'Afro Pop, Vol. 1',
#   'fecha': '2020-08-21',
#   'tipo': 'album',
#   'id': '6GHHoK6LC0Y36nYsouK8qR'},
#  {'album': 'Paranoia Pop',
#   'fecha': '2020-01-01',
#   'tipo': 'album',
#   'id': '7uBGiYnTpzMqcyQtxaYgIy'},
#  {'album': 'Baladas Pop Para Bebés',
#   'fecha': '2017-02-10',
#   'tipo': 'album',
#   'id': '7xDscOkU9g17j2358RSdsz'},
#  {'album': 'POP VIRUS',
#   'fecha': '2018-12-19',
#   'tipo': 'album',
#   'id': '7oFLY1YL5bBI32UHsmQO6q'},
#  {'album': 'Shop: A Pop Opera',
#   'fecha': '2020-03-08',
#   'tipo': 'album',
#   'id': '1PzQlma9FcRRGwMDmJIUyX'},
#  {'album': 'WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) [Remix]',
#   'fecha': '2020-06-24',
#   'tipo': 'single',
#   'id': '36jrqYRpGVpJqztuqCii22'},
#  {'album': 'Golden Years Of Dutch Pop Music',
#   'fecha': '2016-04-08',
#   'tipo': 'album',
#   'id': '5YKFdp4rB34KOsF8RlvhaI'},
#  {'album': 'Meet The Woo 2 (Deluxe)',
#   'fecha': '2020-02-12',
#   'tipo': 'album',
#   'id': '5NTOvCGu7HT4DgJGLXtKUU'},
#  {'album': 'La Voz Popular de América',
#   'fecha': '2017-12-01',
#   'tipo': 'album',
#   'id': '6ymFtmeQp25jwk5KOOZ5qZ'},
#  {'album': 'Azulejos',
#   'fecha': '2017-06-09',
#   'tipo': 'album',
#   'id': '1hpTHSEosXRl8z47mcRL2J'},
#  {'album': 'Mary Poppins Returns (Original Motion Picture Soundtrack)',
#   'fecha': '2018-12-07',
#   'tipo': 'compilation',
#   'id': '4A5q8ZjS2S7kXoixcEU81B'},
#  {'album': 'Poppin’on!',
#   'fecha': '2019-01-30',
#   'tipo': 'album',
#   'id': '0nZBP6rFExXXOWY1KS6Pp0'},
#  {'album': 'Pop Heart',
#   'fecha': '2018-11-16',
#   'tipo': 'album',
#   'id': '3QdnfBO9mFeajNbJt9Kc9R'},
#  {'album': 'Cipri Popescu',
#   'fecha': '2020-05-22',
#   'tipo': 'album',
#   'id': '0IQzZgL3u8uAmyMutPuDrn'},
#  {'album': 'FIXTAPE',
#   'fecha': '2020-08-07',
#   'tipo': 'album',
#   'id': '0fwiBiv1i0rJzdJGCaHVJi'},
#  {'album': "Flexin'",
#   'fecha': '2019-06-28',
#   'tipo': 'single',
#   'id': '5jSifSNBzx4irk78gafWld'},
#  {'album': 'Ya No Vives en Mí (Versión Pop) (feat. Carlos Rivera)',
#   'fecha': '2018-03-23',
#   'tipo': 'single',
#   'id': '0LVHlONPmYwOA6jo73LphN'},
#  {'album': 'POP RETRO',
#   'fecha': '2020-11-13',
#   'tipo': 'compilation',
#   'id': '3a2G1poas0eVM9n2mrcHLB'},
#  {'album': 'Pop Corn e patatine',
#   'fecha': '2018-02-03',
#   'tipo': 'single',
#   'id': '6mPaoN4CuGmUJiKaC07tOA'},
#  {'album': "90's Pop Tour (En Vivo) [Deluxe Edition]",
#   'fecha': '2017-07-07',
#   'tipo': 'compilation',
#   'id': '2l8I8czsY9vkIk1XiEKqYD'},
#  {'album': 'Pop Star',
#   'fecha': '2018-01-27',
#   'tipo': 'single',
#   'id': '3fCSLSzf73ev11EexQCc1U'},
#  {'album': 'Forever',
#   'fecha': '2018-07-20',
#   'tipo': 'album',
#   'id': '0xAUnt43o2FfxIpVFusIOq'},
#  {'album': 'Pophits für Babys im Spieluhrensound',
#   'fecha': '2020-01-10',
#   'tipo': 'album',
#   'id': '0rRw0P2IzPq56LmhiHAa4Z'},
#  {'album': 'La Tripleta Popular, Vol. 4',
#   'fecha': '2017-11-11',
#   'tipo': 'album',
#   'id': '6ITta9qppzixtMsl8FEgsR'},
#  {'album': 'Come Over (feat. Popcaan)',
#   'fecha': '2020-10-01',
#   'tipo': 'single',
#   'id': '6sYqQ3Pem0Ml376lKx545S'},
#  {'album': 'Chillout Pop inc. John Legend, Miley Cyrus & John Mayer',
#   'fecha': '2019-04-19',
#   'tipo': 'compilation',
#   'id': '5BdNKHK0QXHikKIBLTPn7P'},
#  {'album': 'Piano Covers Vol.1 - Relaxing Piano Music - Best of Pop Hits and Classical Piano Masterpieces',
#   'fecha': '2019-11-24',
#   'tipo': 'compilation',
#   'id': '1tYjSzyYkyrH7bZksF94kk'},
#  {'album': 'MPR',
#   'fecha': '2019-06-28',
#   'tipo': 'single',
#   'id': '7wEkFJd7KaysobIVuxEYK6'},
#  {'album': 'Pop en español 2000s',
#   'fecha': '2020-08-14',
#   'tipo': 'compilation',
#   'id': '43Ptsn8IU9OsX45mZfImh7'},
#  {'album': 'Popsi Og Krelles Godnatsange - 9 Sange Til At Falde I Søvn På',
#   'fecha': '2019-11-21',
#   'tipo': 'album',
#   'id': '1lGSkYOi50RUXvu5dRJ3KA'},
#  {'album': 'Violent Pop',
#   'fecha': '2020-03-06',
#   'tipo': 'album',
#   'id': '28Ea3E7Q5qCmmA9N5W1b6y'},
#  {'album': 'Candy Pop',
#   'fecha': '2018-01-12',
#   'tipo': 'single',
#   'id': '0dbDXtPkq4b4zViH3q9Lnt'},
#  {'album': 'TrapStar Turnt PopStar',
#   'fecha': '2019-05-02',
#   'tipo': 'album',
#   'id': '3TaYhEM7MtqukeISKBV2cx'},
#  {'album': 'My Type',
#   'fecha': '2018-03-09',
#   'tipo': 'single',
#   'id': '2n9E00mcUGhx68j2dIMm2q'},
#  {'album': 'Slide (Remix) (feat. Pop Smoke, A Boogie Wit da Hoodie & Chris Brown) (feat. Pop Smoke)',
#   'fecha': '2020-01-17',
#   'tipo': 'single',
#   'id': '7LMJKPGcBZjZf6AEnTBS2t'},
#  {'album': 'Like It on Top',
#   'fecha': '2018-09-14',
#   'tipo': 'album',
#   'id': '26lGPtKtc4SneVwBh67pW8'},
#  {'album': 'Pop Machine: Minsan',
#   'fecha': '2019-10-04',
#   'tipo': 'single',
#   'id': '0uKck0ZzuERlshPfuiVHMv'},
#  {'album': 'Pop Tracks',
#   'fecha': '2016-09-29',
#   'tipo': 'album',
#   'id': '3s4cgbxkJgfvesQs0Jdb5U'},
#  {'album': 'Popopop (Frapcore Remix)',
#   'fecha': '2019-11-13',
#   'tipo': 'single',
#   'id': '3rdV5ZOtKfKZtDHGWTfnS5'},
#  {'album': 'Ova Dweet - Single',
#   'fecha': '2016-04-28',
#   'tipo': 'single',
#   'id': '3I6muahdIVAN75q0k1Cpc5'},
#  {'album': 'Addicted (Produced by Anju Blaxx)',
#   'fecha': '2017-10-20',
#   'tipo': 'single',
#   'id': '1UbdmudgwwywNsh7pv2nsD'},
#  {'album': "90's Pop Tour, Vol. 3 (En Vivo)",
#   'fecha': '2019-03-29',
#   'tipo': 'compilation',
#   'id': '7tgRSKkKYFx5VLr47P8Dqa'},
#  {'album': 'Baby Yuh Tight',
#   'fecha': '2019-07-03',
#   'tipo': 'single',
#   'id': '3dbDhLa65ItnO8LaTQuStP'},
#  {'album': 'Family',
#   'fecha': '2017-10-30',
#   'tipo': 'single',
#   'id': '09pESGCreuRO6zGh6Sfloy'},
#  {'album': 'Sing With Me A Kids Pop Music Adventure',
#   'fecha': '2018-10-08',
#   'tipo': 'album',
#   'id': '1tMcN7EzOQQOKxNTfWF1vO'},
#  {'album': 'Rockstar (Popstar Edition)',
#   'fecha': '2018-12-07',
#   'tipo': 'album',
#   'id': '1GiaZbKJYEeUuD8hTqp3qS'},
#  {'album': 'De 60 meest populaire kinderliedjes',
#   'fecha': '2016-04-14',
#   'tipo': 'album',
#   'id': '0P1y1rea7i8DrsG2ltksyi'},
#  {'album': 'Risky',
#   'fecha': '2019-10-23',
#   'tipo': 'single',
#   'id': '5xqH5tZFoMLLJL8NbmTFBu'},
#  {'album': 'Pop Latino 00´s',
#   'fecha': '2020-08-21',
#   'tipo': 'compilation',
#   'id': '7vZpvq3ceLNUJ7i4HmR27z'},
#  {'album': 'Mecánica Popular',
#   'fecha': '2019-12-20',
#   'tipo': 'album',
#   'id': '4Z1Q71sHLNHcnT5OpSZjtS'},
#  {'album': 'Hjulene På Bussen – 20 Af De Bedste Børnesange',
#   'fecha': '2017-11-15',
#   'tipo': 'album',
#   'id': '4cVinuyHcLiJJby9k27qQS'},
#  {'album': 'Breakthrough!',
#   'fecha': '2020-06-24',
#   'tipo': 'album',
#   'id': '58ljHdOYaORRQdqcz4TaHl'},
#  {'album': 'Feel Good',
#   'fecha': '2016-02-14',
#   'tipo': 'single',
#   'id': '7z8VyDbq9Bv32oUezvDEE7'},
#  {'album': 'Populiariausios Vaikiškos Dainelės Ir Žaidimai',
#   'fecha': '2018-03-07',
#   'tipo': 'album',
#   'id': '1SiWqbpDHMNTF0JjLGCW46'},
#  {'album': 'Popular Covers - Saregama & Pehchan Music, Vol. 1',
#   'fecha': '2019-08-28',
#   'tipo': 'compilation',
#   'id': '2WPZ35gOE8Kn2AcnmsXI1e'},
#  {'album': 'Popkorni',
#   'fecha': '2017-08-28',
#   'tipo': 'album',
#   'id': '2FD2pWS8T6SS9UaCTSNKww'},
#  {'album': 'Pop Noir',
#   'fecha': '2018-06-05',
#   'tipo': 'compilation',
#   'id': '65cDNwkqR9ueaTe9lT5r3e'},
#  {'album': 'Brasil Encanta - Brazilian Pop',
#   'fecha': '2016-07-29',
#   'tipo': 'compilation',
#   'id': '30ubeJjbvggD5Ko2BfagLY'},
#  {'album': '不能說的秘密 "Secret" & Pop - Piano Collection',
#   'fecha': '2016-01-08',
#   'tipo': 'album',
#   'id': '5RUAG4bgmRE6i0lQSh3wjd'},
#  {'album': 'Friends (with BloodPop®)',
#   'fecha': '2017-08-17',
#   'tipo': 'single',
#   'id': '7huML9zDbY4thKH0xSuZTP'},
#  {'album': 'Romántico Pop',
#   'fecha': '2019-06-07',
#   'tipo': 'compilation',
#   'id': '3GJXUDQKX2kPShqSVxuqrL'},
#  {'album': 'Caucas Pop 2016',
#   'fecha': '2016-10-03',
#   'tipo': 'album',
#   'id': '4dYZ9QDRQTzQW7t2EstUzH'},
#  {'album': 'Vanquish',
#   'fecha': '2019-12-20',
#   'tipo': 'album',
#   'id': '05h84nlrmNAjh083dnULzt'},
#  {'album': 'Hopia Mani Popcorn, Vol. 2',
#   'fecha': '2019-04-02',
#   'tipo': 'compilation',
#   'id': '12t5uypDU6wqlZyjzcuTqc'},
#  {'album': 'Biraz Pop Biraz Sezen',
#   'fecha': '2017-01-23',
#   'tipo': 'album',
#   'id': '1ASZNCBMPPt60WdPJvMtue'},
#  {'album': 'Rataria Popular Brasileira',
#   'fecha': '2019-11-21',
#   'tipo': 'album',
#   'id': '6RsZXnolUCMjZAcdVlaD0l'},
#  {'album': 'Inviolable - Single',
#   'fecha': '2018-03-09',
#   'tipo': 'single',
#   'id': '6z39xjBaUA9Naa0mOO0dEE'},
#  {'album': 'Lullabies: Most Popular Tunes and Nursery Rhymes for Babies',
#   'fecha': '2016-12-07',
#   'tipo': 'album',
#   'id': '2TpJ6Ly7GOEmd4hrLRcoZj'},
#  {'album': 'Pop Art',
#   'fecha': '2017-06-18',
#   'tipo': 'album',
#   'id': '6EOyCoZBWb72mGknv8py1z'},
#  {'album': 'POP.',
#   'fecha': '2017-03-17',
#   'tipo': 'album',
#   'id': '7IOHQxe8MqdfjQ34JQbWav'},
#  {'album': 'More Than You Know',
#   'fecha': '2017-07-28',
#   'tipo': 'album',
#   'id': '6Ei5WWek37m1x9AjpSXTcJ'}]

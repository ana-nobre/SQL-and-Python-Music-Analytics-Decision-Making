# %%
import requests
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="api.env")

api_key = os.getenv("API_KEY_LASTFM")  # Asegurate de que este nombre coincide con tu archivo .env
print("Tu API Key es:", api_key)
# Out:
# Tu API Key es: 6611acf9b4cea4106ef56a4f3db1eb86

# %%
import json
import pandas as pd

# %%
import csv
with open('list_artist_rock.csv', "r") as archivo:
    lector = csv.reader(archivo)
    lista_artistas = list(lector)

# %%
for i in lista_artistas:
    print(i)
# Out:
# ['Rocío Dúrcal']
# ['Sombra y Luz']
# ['Fleur East']
# ['Tino Casal']
# ['JENCARLOS']
# ['DJ Antoine']
# ['Sergio Dalma']
# ['Loquillo']
# ['El Palacio de Linares']
# ['Marco Mengoni']
# ['Bomba Estéreo']
# ['Rosana']
# ['Los Rebeldes']
# ['Felix Jaehn']
# ['Pablo Alborán']
# ['Juventud Juché']
# ['Kañasur']
# ['Sigala']
# ['KSHMR']
# ['Nada Surf']
# ['Sweet California']
# ['Varry Brava']
# ['John Newman']
# ['Extraperlo']
# ['Baby K']
# ['Bastille']
# ['Maki']
# ['Nyno Vargas']
# ['Cristian Guerrero']
# ['Paty Cantú']
# ['David Barrull']
# ['Soraya']
# ['Neleonard']
# ['Fernando Castro']
# ['DMEI']
# ['Duo Dinamico']
# ['Rulo y la contrabanda']
# ['Scotty']
# ['Monoir']
# ['Texxcoco']
# ['Pablo Und Destruktion']
# ['Fernando Caro']
# ['Pablo López']
# ['Dimitri Vegas & Like Mike']
# ['Tasmin Archer']
# ['Murciano Total']
# ['Luis Fonsi']
# ['Manuel Medrano']
# ['La Unión']
# ['DNCE']
# ['Joe Crepúsculo']
# ['Juan Magán']
# ['Rasel']
# ['Kiko y Shara']
# ['Lucas Masciano']
# ['The New Raemon']
# ['Sidecars']
# ['3LAU']
# ['Juanes']
# ['Alex Ubago']
# ['Mikel Erentxun']
# ['Marta Quintero']
# ['Bordon-4']
# ['Celia Gamez']
# ['Paulina Rubio']
# ['Marta Soto']
# ['Capitán Sunrise']
# ['Kylie Minogue']
# ['Armin van Buuren']
# ['Tony Ronald']
# ['Depressing Claim']
# ['Jarabe De Palo']
# ['Vainica Doble']
# ['Elena']
# ['Nuevos Hobbies']
# ['Umberto Tozzi']
# ['Camela']
# ['Ivan Ferreiro']
# ['Grises']
# ['Corizonas']
# ['Poupie']
# ['Makarines']
# ['Justin Timberlake']
# ['Aitana']
# ['Efecto Pasillo']
# ['Miguel Bosé']
# ['Radio Futura']
# ['Alesso']
# ['Betacam']
# ['MARLENA']
# ['George Ezra']
# ['Liam Payne']
# ['Kokoshca']
# ['Sia']
# ['The Civil Wars']
# ['Sebastian Yatra']
# ['Sexy Sadie']
# ['Paco Candela']
# ['Antonio José']
# ['Duran Duran']
# ['Marisol']
# ['Kungs']
# ['Tequila']
# ['Tachenko']
# ['Lola Indigo']
# ['Sylvia Pantoja']
# ['Ana Guerra']
# ['Leiva']
# ['Veintiuno']
# ['Hans Laguna']
# ['a-ha']
# ['Loquillo Y Los Trogloditas']
# ['Cuello']
# ['Meghan Trainor']
# ['Oblique']
# ['Karina']
# ['Los Chanela']
# ['Cosmo K']
# ['Mujeres']
# ['Fangoria']
# ['Da Igual']
# ['P!nk']
# ['Carlos Baute']
# ['Post Malone']
# ['Noelia']
# ['VINAI']
# ['Manuel Carrasco']
# ['Chaqueta de Chándal']
# ['Leif Garrett']
# ['Dani Fernández']
# ['Miley Cyrus']
# ['No Me Pises Que Llevo Chanclas']
# ['Los Yakis']
# ['Blas Cantó']
# ['Carlos Berlanga']
# ['Diego Martín']
# ['The Cardigans']
# ['El Arrebato']
# ['MEDUZA']
# ['Swing Out Sister']
# ['Vanesa Martín']
# ['Pyllo Cortes']
# ['Kenny Man']
# ['Emilia, Pardo y Bazán']
# ['Potito']
# ['Greeicy']
# ['MARÍA TOLEDO']
# ['Rayo']
# ['Álvaro De Luna']
# ['Avicii']
# ['Los Piratas']
# ['Airbag']
# ['Nueva Vulcano']
# ['Diamante Negro']
# ['Shinova']
# ['Fito y Fitipaldis']
# ['Pablo Prisma y las Pirámides']
# ['Melenas']
# ['Massiel']
# ['Miss Caffeina']
# ['David DeMaría']
# ['Nolasco']
# ['Elbicho']
# ['Marlon']
# ['from']
# ['Antonio Orozco']
# ['Pitingo']
# ['Pitovnis']
# ['Alexie Divello']
# ['Sinay']
# ['Barroso']
# ['El Sueño de Morfeo']
# ['Detergente Líquido']
# ['El Grajo']
# ['Feedbacks']
# ['The Reflectors']
# ['Bravo Fisher!']
# ['Ghost Town']
# ['Merche']
# ['Belako']
# ['Pastora Soler']
# ['Parade']
# ['Huecco']
# ['Depedro']
# ['José El Francés']
# ['La Barbería Del Sur']
# ['Nicky Romero']
# ['Vinicio Capossela']
# ['Atencion Tsunami']
# ['Manta Ray']
# ['Pastor Lopez Y Su Combo']
# ['José Parra']
# ['Los Flechazos']
# ['Cristóbal Jiménez']
# ['Roberto Bueno']
# ['W&W']
# ['Terrier']
# ['Montse Cortés']
# ['Diana Navarro']
# ['Javier Ojeda']
# ['Gorgon City']
# ['Cherezade']
# ['Fuel Fandango']
# ['Roser']
# ['Los Xey']
# ['espiritusanto']
# ['Galantis']
# ['Ousanousava']
# ['Dolly Parton']
# ['Midnite String Quartet']
# ["Cupid's Carnival"]
# ['El Charrito Negro']
# ['Henry Mendez']
# ['Maronda']
# ['Natalia']
# ['JEANS']
# ['Amateur']
# ['Las Ruinas']
# ['Sr. Chinarro']
# ['David Deseo']
# ['Juan Miguel']
# ['James Arthur']
# ['La Fuga']
# ['Alazan']
# ['Full']
# ['La Caja De Pandora']
# ['La Scelta']
# ['Alan Ramirez']
# ['Zebra Hunt']
# ['Jairo']
# ['Bryan Lanning']
# ['Sean McConnell']
# ['Sofia']
# ['Juan Huertas']
# ['Octavio Mesa']
# ['Sammy Moore']
# ['CM Chahal']
# ['Sarah Belkner']
# ['Jorge Ariza']
# ['Super Combo Los Tropicales']
# ['Gina Lobrista']
# ['John Legend']
# ['Bernardo']
# ['Alfred García']
# ['Sonny & Cher']
# ['Raya Real']
# ['Rafael Medina']
# ['Ecos del Rocío']
# ['Alejandro Fernández']
# ['Disco Las Palmeras!']
# ['Axwell /\\ Ingrosso']
# ['Mike Candys']
# ['Sade']
# ['Duncan Dhu']
# ['L.A.']
# ['MAGIC!']
# ['Tom Odell']
# ['Cabas']
# ['La Oreja de Van Gogh']
# ['Axel']
# ['Fiona Apple']
# ['Hazte lapón']
# ['Río Arga']
# ['Sten & Stanley']
# ['Dvicio']
# ['M-Clan']
# ['OBK']
# ['Khalid']
# ['Los Directivos']
# ['Ole Ole']
# ['Melendi']
# ['Tom Walker']
# ['Antonio Vega']
# ['Morat']
# ['Jonas Brothers']
# ['Belen Arjona']
# ['Jesse Baez']
# ['Son Del Barrio']
# ['Los Delinqüentes']
# ['Klaus & Kinski']
# ['María Artés']
# ['ChocQuibTown']
# ['Maria Carrasco']
# ['Amaral']
# ['Conchita']
# ['Whitney Houston']
# ['Reik']
# ['Backstreet Boys']
# ['Nena Daconte']
# ['Estopa']
# ['Koala Liu']
# ['Dharmacide']
# ['Quique González']
# ['Maldita Nerea']
# ['Amistades Peligrosas']
# ['Los Secretos']
# ['Miqui Puig']
# ['Autoescuela']
# ['Chucho']
# ['De Kermisklanten']
# ['Leroy Van Dyke']
# ['Love of Lesbian']
# ['David Otero']
# ['Kazzabe']
# ['ALMAR']
# ['Los Raros']
# ['Claudio Villa']
# ['Los Relicarios']
# ['Javiera Mena']
# ['Fausto']
# ['Uriel Henao']
# ['Sekouba Kandia Kouyaté']
# ['JACK BORIS']
# ['Ryuichi Kawamura']
# ['Fernando & Sorocaba']
# ['Kaela Kimura']
# ['Sofia Källgren']
# ['Fanicko']
# ['Paola Iezzi']
# ['Will Hoge']
# ['João Bosco & Vinicius']
# ['Akram Mag']
# ['Hernan Gómez']
# ['Silvan Galvão']
# ['Elams']
# ['Luis Felipe Gonzalez']
# ['Montu Moni Saikia']
# ['Jignesh Barot']
# ['Pawan Roy']
# ['Havinhell']
# ['Jignesh Kaviraj']
# ['Johnny Jack Mesclado']
# ['Dj Dirty Fingerz']
# ['Koes Plus']
# ['Anand Shinde']
# ["Rollies '98"]
# ['Hoolahoop']
# ['Indu Sonali']
# ['Alka Chandrakar']
# ['Putri Alin']
# ['Thanchuilu Gangmei']
# ['T-Matt']
# ['GEMS CHONGTHAM']
# ['Gajendra Rana']
# ['Shyam Paliwal']
# ['Michael Sullivan']
# ['Vreegu Kashyap']
# ['Kinjal Dave']
# ['Udit Narayan']
# ['The Rain']
# ['Junior Lacrosse']
# ['Lilis Suryani']
# ['Bonzai']
# ['Vesta Lugg']
# ['Ayoho']
# ['Fus Delei']
# ['BoybandPH']
# ['The Cars']
# ["Dargen D'Amico"]
# ['Tiziano Ferro']
# ['Acústicos & Valvulados']
# ['Luc Steeno']
# ['Franktony']
# ['Mah Kouyaté']
# ['Curiosity Killed The Cat']
# ['Bobby Rydell']
# ['Joaquin Bedoya Y Su Conjunto']
# ['Lalrindiki Khiangte Daduhi']
# ['Boi Bumbá Caprichoso']
# ['Mohan Rathod']
# ['Abhijit Majumdar']
# ['Amelinha']
# ['Boi Bumbá Garantido']
# ['Jasraj Joshi']
# ['Biquini Cavadão']
# ['Yuni Shara']
# ['Kirtidan Gadhvi']
# ['PH e Michel']
# ['Pushparani Huidrom']
# ['Banda Xeiro Verde']
# ['L.N. Shastri']
# ['Sirazee']
# ['CHONGTHAM VIVEK ALY']
# ['Satish Das']
# ['Vanny Vabiola']
# ['A.T.I']
# ['Vivek - Mervin']
# ['Ranghon Karbir']
# ['Carreiro & Capataz']
# ['Fade2Black']
# ['Gustavo Moura & Rafael']
# ['Hateen']
# ['Jil Jilala']
# ['Baby Naznin']
# ['Dario Moreno']
# ['Tetsuya Komuro']
# ['GAO']
# ['Luis Aguile']
# ['Valkirya']
# ['Eneas Perdomo']
# ['The Haermorrhoids']
# ['Juan Carlos Zarabanda']
# ['MAIOLE']
# ['Eric Hutchinson']
# ['THE BEAT GARDEN']
# ['Young Ellens']
# ['Patrícia & Adriana']
# ['Aminu Ladan Alan Waka']
# ['El Combo De Las Estrellas']
# ['Billy Joe Royal']
# ['Nechivile']
# ['Spandau Ballet']
# ['Dueto De Antaño']
# ['Koloma']
# ['Geeta Goswami']
# ['Zubeen Garg']
# ['Suresh Wadkar']
# ['Navv Inder']
# ['Clayton & Romário']
# ['Pawan Singh']
# ['Medision Debbarma']
# ['Ryan Foret And Foret Tradition']
# ['Arraial Do Pavulagem']
# ['Keith Frank']
# ['Gunjan Singh']
# ['Wham!']
# ['Pitbull']
# ['Ketito']
# ['Eladio y Los Seres Queridos']
# ['Mariah Carey']
# ['Georgina']
# ['Roberto Casalino']
# ['Cheb Mami']
# ['Gabriel Arriaga']
# ['Luisa Lacerda']
# ['Yuri']
# ['Aries']
# ['Joan As Police Woman']
# ['Al Rangone']
# ['MINOS']
# ["Los Ayer's"]
# ['Roto']
# ['WHY@DOLL']
# ['Gunz']
# ['Banda Warilou']
# ['Ciudadano Toto']
# ['Cacio & Marcos']
# ['Nelson Henriquez']
# ['Bowen y Villafuerte']
# ['Hermanas Villareal']
# ['Luciano y Concholon']
# ['BYOR']
# ['Fresno']
# ['Simone & Simaria']
# ['Sofiano']
# ['Flor de Mururé']
# ['Bouba Menguè']
# ['Waldick Soriano']
# ['Luigi Tenco']
# ['Czecho No Republic']
# ['Tiësto']
# ['Cali Y El Dandee']
# ['一口甜']
# ['Diego & Victor Hugo']
# ['Uni Boys']
# ['João Neto & Frederico']
# ['Whity Matimal']
# ['Takana Zion']
# ['El Dipy']
# ['Lakis Tzorntanelli']
# ['Miss Pooja']
# ['Riccobellis']
# ['Ny Ainga']
# ['Fruto Sensual']
# ['Kate Miller-Heidke']
# ['Los Cuyitos']
# ['Jose Miguel Class']
# ['Cheb Rayan']
# ['Kulwinder Billa']
# ['AJIMAL']
# ['Rahima']
# ['Manezinho Do Sax']
# ['OP Dewangan']
# ['Sarbeswar Kardong']
# ['Citra Irani']
# ['Waldo Cesar']
# ['Pramod Premi Yadav']
# ['Matheus & Kauan']
# ['Inder Jeet']
# ['Kalpana Patowary']
# ['kolme']
# ['Antti Tuisku']
# ['Lam Truong']
# ['Arthur Espíndola']
# ['Prakash Mali Mehandwas']
# ['Harbhajan Mann']
# ['Nazia Iqbal']
# ['TSAR']
# ['Looee Arreak']
# ['Babiluzion']
# ['崔健']
# ['Hồng Nhung']
# ['Poopy']
# ['Zubaida Khanum']
# ['Manoj Sahri']
# ['Southguns']
# ['Kasper Winding']
# ['Mike Lucazz']
# ['Achurjya Barpatra']
# ['Tatsuya Ishii']
# ['Güneri Tecer']
# ['Verse Simmonds']
# ['Antoine Henaut']
# ['Đàm Vĩnh Hưng']
# ['Rob Dekay']
# ['Neelkamal Singh']
# ['NERVO']
# ['Stephen Kasolo']
# ['Mic Flammez']
# ['Anmol Sayal']
# ['Tito Cortes']
# ['Arvind Akela Kallu Ji']
# ['Rick & Nogueira']
# ['King Melodies']
# ['D’MASIV']
# ['Khesari Lal Yadav']
# ['London Pops Orchestra']
# ['Hossam Gharieb']
# ['El Caballero Gaucho']
# ['Alessia']
# ['Carole King']
# ['譚炳文']
# ['李采霞']
# ['Ita Purnamasari']
# ['Yasser Desai']
# ['Tim Sameke']
# ['Credo']
# ['Haunted Disco']
# ['Bonsoir Catin']
# ['Ajay Warriar']
# ['Gino Paoli']
# ['Talis e Welinton']
# ['Raymond Scott']
# ['Giorgos Xylouris']
# ['Jay Frog']
# ['Frankie Valli & The Four Seasons']
# ['Captivate']
# ['Stelios Kazantzidis']
# ['Agun']
# ['Attaullah Khan Esakhelvi']
# ['De Straatzangers']
# ['Lepai']
# ['Sakal Balamua']
# ['Vicky Dhillon']
# ['Satyajeet Pradhan']
# ['AUTOMAT']
# ['Dablio & Phillipe']
# ['Kumar Bishwajit']
# ['Babyraids Japan']
# ['Codeko']
# ['DJ Devil']
# ['Alice B']
# ['Vijay Varma']
# ['Debi Makhsoospuri']
# ['Oto Pestner']
# ['Manu Lafer']
# ['Sqb']
# ['Wilma De Angelis']
# ['Richard Ragnvald']
# ['Ipank']
# ['Noam Banai']
# ['Stella Mengele']
# ['Javed Ali']
# ['TOM LARI']
# ['Mousam Gogoi']
# ['ROBERT OEKA']
# ['Bemti']
# ['LISTER SERUM']
# ['Israel Paulain']
# ['Engrennagem']
# ['Kid $wami']
# ['Sourin Bhatt']
# ['Gedix Atege']
# ['Sharry Mann']
# ['Rabo de Vaca']
# ['Babu']
# ['Ranjit Bawa']
# ["Fishermen's Project"]
# ['Angsa & Serigala']
# ['Anuj Sharma']
# ['Banda Rabo de Vaca']
# ['Carlos & Jader']
# ['Raj Mawer']
# ['Kayla Diamond']
# ['Los Caballeros Del Tango']
# ['Alberto Bianco']
# ['Sindicato dos Artistas Carentes']
# ['KUNG-FU GIRL']
# ['Darío Gómez']
# ['Gildardo Montoya']
# ['Andro Skrt']
# ['Elymar Santos']
# ['João Fernando & Gabriel']
# ['Pankaj']
# ['Bhargav Ojapali']
# ['Rajiv Sinha']
# ['Surma Chanu']
# ['Martin Mkrtchyan']
# ['Kalpana Hansda']
# ['Swayam Padhi']
# ['Paulo e Nathan']
# ['UMAKANT BARIK']
# ['Lucie']
# ['Devi']
# ['Raju Rawal']
# ['Sound Of Monkey']
# ['Renan e Rafael']
# ['Celso Adolfo']
# ['Rajender Singh Kharkiya']
# ['Sunil Soni']
# ['Dreamhunter']
# ['Sundaramurthy K.S.']
# ['Mithu Marshal']
# ['Kaboy Kamakili']
# ['Mirele']
# ['Prakash Jal']
# ['Vishnu']
# ['Bashir Ansari']
# ['Ashish Verma']
# ['Fernando Brant']
# ['Humane Sagar']
# ['Johnny Sablan']
# ['Ankush Raja']
# ['Ramkumar Maluni']
# ['Riyan Raj']
# ['Labh Heera']
# ['Titãs']
# ['Nilakshi Neog']
# ['Moacyr Franco']
# ['Hugo & Tiago']
# ['Shilpa Bidawat']
# ['Dj Kuchi']
# ['Sannidhya Bhuyan']
# ['Hugo Matta']
# ['Bruninho & Davi']
# ['Kid Abelha']
# ['Somos 3']
# ['Endank Soekamti']
# ['ROYALcomfort']
# ['Ki Jlawdohtir']
# ['Gazza']
# ['The Kentucky Headhunters']
# ['Rama Aiphama']
# ['Minakshi Kalita']
# ['Jiya Negi, Akshay Negi']
# ['Jitendra Tomkyal']
# ['Lavan Abhishek']
# ['Nunes Filho']
# ['Kaustubh Gaikwad']
# ['Luiz Guilherme']
# ['Debolina Nandy']
# ['B Maisnam']
# ['Revolución Total']
# ['Suicide Syndicate']
# ['Kuldeep Sharma']
# ['Girishh G']
# ['Sash']
# ['Irena Starošaitė']
# ['ฟรีเบิร์ดส']
# ['Thanh Thúy']
# ['Caitlin Hart']
# ['Rudolf Cortés']
# ['Benji & Fede']
# ['Johanis Reinosa']
# ['Leonard']
# ['Oscar Makamu na Majuvani Sisters']
# ['Runa Laila']
# ['Lý Hải']
# ['BADSISTA']
# ['Char']
# ['Novi Fosili']
# ['譚婉鈴']
# ['Deepak Dildar']
# ['Juan Diego']
# ['ONE☆DRAFT']
# ['Nour Ireksousi']
# ['The Copper Street Brass Quintet']
# ['Віктор Павлік']
# ['MALIII']
# ['Ernie Halter']
# ['Sabina Babayeva']
# ['Tritonal']
# ['Deorro']
# ['Enrique Rodriguez']
# ['Breno Ruiz']
# ['Sandro e Cícero']
# ['The Transgressions']
# ['Blue Jeans']
# ['Džentlmeni']
# ['Raj Verma']
# ['Michael Carpenter']
# ['凌波']
# ['Fortunate Ones']
# ['Andimon']
# ['Lopamudra Mitra']
# ['Ningmuanching']
# ['Marek Dyjak']
# ['Roumadyval']
# ['Dueto Remembranzas']
# ['Diamant Noir']
# ['Natasza Zylska']
# ['Akash Nibir']
# ['Shafqat Amanat Ali']
# ['Edw!N']
# ['Kuldeep Ojha']
# ['La Fouine']
# ['YANIN X CASINOTONE']
# ['Cornelis Vreeswijk']
# ['Souljah']
# ['Jeden Tag Silvester']
# ['Dev Kumar Deva']
# ['Liza Tania']
# ['Styl-Plus']
# ['Nguyễn Phi Hùng']
# ['Petr Kotvald']
# ['Ramesh']
# ['Восток']
# ['Deepak Dhillon']
# ['Molly Jenson']
# ['Марет Алиханова']
# ['Friend Roulette']
# ['Tani']
# ['Richpal Dhaliwal']
# ['Gabriel Nandes']
# ['Omid Hajili']
# ['Natalino Otto']
# ['BISHNU MOHAN KABI']
# ['Bobby Solo']
# ['Partha Barua']
# ['Shake Some Action!']
# ['Pradeep']
# ['Luciano Kikão']
# ['Shital Thakor']
# ['Champe Khan']
# ['White Rose']
# ['Avinash Vishwajeet']
# ['Garbo']
# ['Dev Bhatt']
# ['Sahir Ali Bagga']
# ['Iyaz']
# ['Jot Harjot']
# ['Zbigniew Kurtycz']
# ['Khagen Mahanta']
# ['Madison Mars']
# ['Maiara & Maraisa']
# ['PARIM']
# ['Irwin']
# ['Normunds Rutulis']
# ['KUNI SOUNDS']
# ['SANITO']
# ['Dilip Shadangi']
# ['Jaap Valkhoff']
# ['El Codigo Kirkao']
# ['Debbie Gibson']
# ['MRM Masri']
# ['Jiří Suchý']
# ['Joe Brown']
# ['R. S. Kumar']
# ['Dikshu']
# ['Pawan']
# ['Md. Aziz']
# ['Rohit Thakor']
# ['Aakangkhya Das']
# ['Conrado & Aleksandro']
# ['Alok Kumar']
# ['Faisal Ashoor']
# ['The Gospellers']
# ['Ritesh Pandey']
# ['The John Dank Show']
# ['Sudam Majhi']
# ['Hugo Henrique']
# ['Namita Agrawal']
# ['Trina']
# ['Domenico Modugno']
# ['Markku Aro']
# ['Ajungi']
# ['Lado Madheshiya']
# ['Silver X']
# ['Luciano Tajoli']
# ['Kim Yuna']
# ['David Carroll']
# ['Gopal Gurjar']
# ['Liesbeth']
# ["The Arizona's"]
# ['Porter Wagoner']
# ['Analaga']
# ['BATTLE BOYS']
# ['Mohini Pandey Priti']
# ['TOTALFAT']
# ['The Stone Ramos']
# ['Seguimos Perdiendo']
# ['Singrai Soren']
# ['Beata Kozidrak']
# ['Donna Lewis']
# ['Miguel Islas']
# ['Amit Thapliyal']
# ['Ovhi Firsty']
# ['Riley Green']
# ['Poba Gourab']
# ['Earl Thomas Conley']
# ['Santanu']
# ['Salim Shekhawas']
# ['Petra Sihombing']
# ['Walter Manglona']
# ['Sarita Kharwal']
# ['Daniel De Leon Guerrero']
# ['MynameiS']
# ['Marileyda']
# ['Nitumoni Pegu']
# ['Jitrz']
# ['Subhan Negi']
# ['Najim Arshad']
# ['Juice Newton']
# ['สวลี ผกาพันธุ์']
# ['Thakur Dass Rathi']
# ['Shaylen']
# ['ShiningStars']
# ['Ravi Raj']
# ['Diego & Arnaldo']
# ['Johnny Hoes']
# ['Ric Manrique Jr.']
# ['Remixing Mohit RM']
# ['Gavi']
# ['Los Bacanes del Sur']
# ['Neel Akash']
# ['Mathilde Santing']
# ['Asha Vaishnav']
# ['29:11 Worship']
# ['Lio']
# ['Hà Trần']
# ['Trío Siboney']
# ['Zemlyane']
# ['Jacques Houdek']
# ['Juan Erasmo Mochi']
# ['Noor Jehan']
# ['Gareth Emery']
# ['Jeronimo']
# ['D Kurt']
# ['Panda Transport']
# ['Eva De Roovere']
# ['Diego Zamboni']
# ['Niels Midjord']
# ['Steinar Jøraandstad']
# ['Giuni Russo']
# ['Urszula Sipinska']
# ['Harsh Mali']
# ['Mudasir Ali']
# ['Dirotta Su Cuba']
# ['Faiq Ağayev']
# ['Infiniti']
# ['Nomadi']
# ['Monika Mundu']
# ['Sven Olof Sandberg']
# ['Odeville']
# ['Rosenstolz']
# ['Pilotox']
# ['Đình Văn']
# ['Melissa']
# ['Mirla Castellanos']
# ['2Kija']
# ['Ghibran']
# ['Radojka Sverko']
# ['Pohlmann.']
# ['Joelma Kláudia']
# ['Qilichbek Madaliyev']
# ['Анвар Нургалиев']
# ['Rahat Fateh Ali Khan']
# ['srimati mandi']
# ['Jorge Luis Hortúa']
# ['ポセイドン・石川']
# ['Drazen Zecic']
# ['Meri Cetinic']
# ['DTM']
# ['Trio America']
# ['Arif Lohar']
# ['Lalitya Munshaw']
# ['Charodey Jeddy']
# ['Buddy Cole']
# ['Debabrata Biswas']
# ['Frances Yip']
# ['黄晓君']
# ['The Everly Brothers']
# ['w-inds.']
# ['jan SEVEN dettwyler']
# ['Rompasso']
# ['Idol Mckol']
# ['Viktor Korolev']
# ['The Rokes']
# ['Rika Sumalia']
# ['Anthem for Maria']
# ['Quinteto Dalmar']
# ['Simon Boudreau']
# ['Fatima Marques']
# ['Lieutenant Pigeon']
# ['Khushboo Jain']
# ['Klthsom']
# ['Naseebo Lal']
# ['Niclas Timmerby']
# ['Giulia']
# ['Ciranda Flor Matizada']
# ['Ira Mohanty']
# ['Sunaree Rartseema']
# ['Roberto Villar']
# ['Urban Outfielders']
# ['Mr. Wilson']
# ['ดาวใจ ไพจิตร']
# ['PORTRAIT']
# ['Sanju Mohanty']
# ['Hoài Nam']
# ['En Vogue']
# ['Faron Young']
# ['Alex & Echoes']
# ['Rokia Koné']
# ['Anupam Roy']
# ['Vaishali Samant']
# ['Mase']
# ['TICO DE MORAES']
# ['Sani Aliyu Dandawo']
# ['Khởi My']
# ['Willy Paul']
# ['Vivek Nayak']
# ['ayazkardes']
# ['BASICS OF SABAMA GOSPEL SINGERS']
# ['Eddie Japan']
# ['Cheekychizzy']
# ['นิตยา บุญสูงเนิน']
# ['Maiko']
# ['Chuy Luviano']
# ['Sunil Mouar']
# ['Déric']
# ['Tulio & Gabriel']
# ['Kamlesh Barot']
# ['Olivia Hime']
# ['Dimix Staya']
# ['Ali Ashabi']
# ['Salim Seghers']
# ['Legendboy']
# ['Luca Kaminski']
# ['André Popp']
# ['Mario Castelnuovo']
# ['Hari Supiko']
# ['Лэйна']
# ['Masoom Sharma']
# ['Mario Battaini']
# ['Locosounds']
# ['Ria and the Funny Boys']
# ['Betty Curtis']
# ['Alireza Roozegar']
# ['Jose Muñoz']
# ['Blaudzun']
# ['The Brothers Steve']
# ['Rai Jujhar']
# ['Dr JB']
# ['Dinesh Lal Yadav']
# ['Caio Cesar e Thiago']
# ['Raju Punjabi']
# ['Pequeña Ciudad']
# ['Guto Lima']
# ['Kleo Dibah']
# ['Stephan Tudu']
# ['Netherfriends']
# ['Gamla Pengar']
# ['純情のアフィリア']
# ['Subash Dash']
# ['Desmond Rimaki Sunn']
# ['Chinar Music']
# ['VaVa']
# ['Rajal Barot']
# ['Vesvas']
# ['Microchild']
# ['Azad Ansari']
# ['曲肖冰']
# ['Айдар Галимов']
# ['Andrew Gold']
# ['Turkmen Mukamlary']
# ['Robert Wells']
# ['Yelle']
# ['Harvy Sandhu']
# ['Aseema Panda']
# ['Chhote Baba']
# ['MANOJ TIWARI']
# ['Lefteris Pantazis']
# ['Fabolous']
# ['Fiesta']
# ['Twinkle Vaishnav']
# ['Vipul Susra']
# ['Pelé MilFlows']
# ['Ayub Bachchu']
# ['Erol Şahin']
# ['SHINE FILM PRODUCTION']
# ['Pradeep Sharma']
# ['Näbelli Kompozitor']
# ['魏新雨']
# ['Genial Au Japon']
# ['Kaku Ram Thakur']
# ['Agnaldo Timoteo']
# ['Kuldev Kaushal']
# ['Kavita Yadav']
# ['Mangal Singh']
# ['Balkar Sidhu']
# ['Freestyle']
# ['Hello Seahorse!']
# ['Mohan Rathore']
# ['วงตาวัน']
# ['Royal Company']
# ['Casulo']
# ['Sérgio Rossi']
# ['Nagendra Ujala']
# ['Fell']
# ['Numata']
# ['Dinesh Mali']
# ['CRLN']
# ['Joyeux urbains']
# ['Ridho Ramon']
# ['Titu Remix']
# ['Rani Hazarika']
# ['Wavy M']
# ['CUBERS']
# ["Dato' Sudirman"]
# ['Luxley']
# ['Opus V84']
# ['Naghma']
# ['Suzanne Prentice']
# ['Pedrinho Callado']
# ['Ivana Kindl']
# ['Valeriy Syutkin']
# ['郭炳堅']
# ['Ice Prince']
# ['Laisa Ahmed Lisa']
# ['Dyro']
# ['Razmik Amyan']
# ['Jens Book-Jenssen']
# ['Salma Agha']
# ['SiGRÚN']
# ['Tonny Brasil']
# ["Dilso'z"]
# ['FTISLAND']
# ['Rafeah Buang']
# ['Melanie']
# ['Sara Jackson-Holman']
# ['Los Estanques']
# ['Шоколадный Торт']
# ['Dueto Riobamba']
# ['Kenny Rogers']
# ['Sillaturrahmi']
# ['Brian Lanzelotta']
# ['KEITA']
# ['Bigwilz']
# ['Madhushree']
# ['Leo Hainer']
# ['Dilly D']
# ['Rita Thyagarajan']
# ['Ratu Sikumbang']
# ['Max Moura & Cristiano']
# ['Emanny']
# ['Gokul Sharma']
# ['Better Than Ezra']
# ['Verica Serifovic']
# ['Enrique Calvetty']
# ['Lever']
# ['Grethe Sønck']
# ['Aleksandr Lominskiy']
# ['Rapperiya Baalam']
# ['Lucca e Mateus']
# ['Teddy Reno']
# ['Ngọc Huyền']
# ['Trond-Viggo Torgersen']
# ['HOLLIE MAEA']
# ['Jennifer Love Hewitt']
# ["O'CHAWANZ"]
# ['Рустем Закиров']
# ['Concrete Knives']
# ['Valley Lodge']
# ['Steve Lahui']
# ['Semicolon']
# ['Gour Roy']
# ['Kelechi Africana']
# ['Wild Child']
# ['Smokey Punch']
# ['Hương Lan']
# ['Sunset Radio']
# ['Vinai Phanturak']
# ['Marembo']
# ['Santhosh Hariharan']
# ['Mỹ Tâm']
# ['Jette Torp']
# ['Adamu Hassan Nagudu']
# ['Chelip']
# ['Amit Saagar']
# ['Just Fern']
# ['Hu Xia']
# ['Simone Almeida']
# ['KARWAN XABATI']
# ['I Me Mine']
# ['Zetterstrøm & Kristoffersen']
# ['Antonella Ruggiero']
# ['WEBER']
# ['ปั่น ไพบูลย์เกียรติ เขียวแก้ว']
# ['Laurenz']
# ['Dave Maclean']
# ['Maxi Tolosa']
# ['Mauricio Reis']
# ['Le Larve']
# ['Roza Selvia']
# ['Sqweez Animal']
# ['Skypeace']
# ['FxckMr']
# ['Azad Amedê']
# ['IMFACT']
# ['Coque Malla']
# ['Ades Sadewa']
# ['Angela Groothuizen']
# ['GEO']
# ['Yuvraj Mewadi']
# ['Sloan']
# ['Gula']
# ['Sessões Selo Sesc']
# ['Balkar Ankhila']
# ['Crushing Grief']
# ['Quebrada Queer']
# ['Single Mothers']
# ['Bossy Love']
# ['Abdul Rashid Hafiz']
# ['Simona Quaranta']
# ['tuunnvvx']
# ['Jendral Kantjil']
# ['Bablu Ankiya']
# ['Justin Tweito']
# ['Chris Webby']
# ['Vyacheslav Malezhik']
# ['Yash Rathore']
# ['De Stemmingmakers']
# ['Marcos & Belutti']
# ['Shinda Shonki']
# ['BANQUET']
# ['Glen Campbell']
# ["L's town"]
# ['Mrityunjoy Kakati']
# ['Rajeev Sharma']
# ['Balraj']
# ['Masha Ali']
# ['Santhosh Narayanan']
# ['Manish Rajgire']
# ['Raghu Dixit']
# ['Sarla Dangi']
# ['Bigg Robb']
# ['Sankalp Khetwal']
# ['Birthe Wilke']
# ['Paritosh Mahata']
# ['TAIY AKARD']
# ['Bruno & Marrone']
# ['Vinu Gaur']
# ['Well Whale']
# ['Bruno & Barretto']
# ['Milt Buckner']
# ['Toyah']
# ['Bhikari Bal']
# ['Lucho Barrios']
# ['Jaskaran Riarr']
# ['Renuka Panwar']
# ['Kedar Negi']
# ['Diamine']
# ['Farzana Naaz']
# ['Oscar Blesson']
# ['イケてるハーツ']
# ['Gert Hollander']
# ['Ahmad Solo']
# ['Lola']
# ['Kirsten Siggaard']
# ['Mai Thanh Sơn']
# ['Ari Jónsson']
# ['José Ricardo Williams']
# ['Ray Columbus']
# ['Soda Fountain Rag']
# ['Jorge Luis Jasso']
# ['Hripsime Hakobyan']
# ['Black Vanilla']
# ['Natural Gang']
# ['Full Of Harmony']
# ['Sahab Singh Ramola']
# ['Pravin Luni']
# ['Arsen Dedić']
# ['Haimanti Sukla']
# ['Marie']
# ['Rodolfo Aicardi']
# ['Arlindo Junior']
# ['Chris Hawkey']
# ['Dorothée']
# ['AB Syndrom']
# ['Remo Germani']
# ['Rakesh Mishra']
# ['D-51']
# ['Har-Di-Har']
# ['Alice Og Rita']
# ['Lâm Vũ']
# ['Humera Channa']
# ['Say Ocean']
# ['Azam Khan']
# ['美黛']
# ['Atomic']
# ['Diana Pequeno']
# ['Monir Khan']
# ['Hamira Ram Raika']
# ['Johnny Lee']
# ['Viola Valentino']
# ['Sethlo']
# ['Pietro Galassi']
# ['fudanjuku']
# ['Higor Rocha']
# ['Dr Malinga']
# ['Lenny Kuhr']
# ['Lynn Anderson']
# ['Maki Ohguro']
# ['Closehead']
# ['Iwona Loranc']
# ['VJ Awax']
# ['Calixto Ochoa']
# ['Natália Matos']
# ['Cristiano Malgioglio']
# ['Rani']
# ['Elder Effe']
# ['John Terra']
# ['Disco Fries']
# ['CNBLUE']
# ['Janusz Radek']
# ['Naveen Pathak']
# ['Priyanka Barve']
# ['Millind Gaba']
# ['Pedro Paulo & Alex']
# ['Jaya Sri']
# ['Yoshiyuki Osawa']
# ['Mary Ann']
# ['African China']
# ['Umar M Sharif']
# ['Shuri']
# ['T-sean']
# ['Thủy Tiên']
# ['Swapnil Bandodkar']
# ['Strangers']
# ['Saria Al Sawas']
# ['ONEONE']
# ['DEJAYS']
# ['The Chantels']
# ['Johan Untung']
# ['Outstep']
# ['Rani Rangili']
# ['Capitán Jack!']
# ['Fresh L.']
# ['Manu Manzo']
# ['Negra Li']
# ['Rocío Quiroz']
# ['NMB48']
# ['Fati Nijar']
# ['Lee Eun Mi']
# ['LEFTOVERS BAND']
# ['Kazi Shuvo']
# ['Jordan Fisher']
# ['Sadi Sidi Sharifai']
# ['Walter Losi']
# ['Zidra']
# ['Davi e Fernando']
# ['Heidi Mortenson']
# ['Enme']
# ['Chethan Naik']
# ['Ghulam Ali']
# ['Héctor Cabrera']
# ['Surendra Perera']
# ['Мальвина Аюбова']
# ['Dev Das']
# ['Tipu Sultan']
# ['Samar Singh']
# ['RAKOVICKY']
# ['Emily King']
# ['Tamboerijn']
# ['シロクロミーアキャット']
# ['Stefanie Schrank']
# ['Louis Davids']
# ['Maurício & Eduardo']
# ['Odair Jose']
# ['João Lucas & Diogo']
# ['Akshara Singh']
# ['Anu Dubey']
# ['Monu Albela']
# ['Black Gold AK']
# ['Ernest Tubb']
# ['Akes']
# ['Jimmy Dee']
# ['Summer Heights']
# ['Joe Inoue']
# ['Burrito Panza']
# ['King James']
# ['Ağadadaş Ağayev']
# ['George Japa']
# ['Oscar Carboni']
# ['Nippu Nepewala']
# ['Roopa Kotwal']
# ['All Ok']
# ['Kevin Johnson']
# ['Benaissa']
# ['Jayh']
# ['Vinod Ranta']
# ['Raj']
# ['John Anderson']
# ['Friends with Instruments']
# ['Suman Gupta']
# ['Amrita Virk']
# ['Maycon e Vinicius']
# ['Mansoor Ali Malangi']
# ['Poul Bundgaard']
# ['Pravesh Lal Yadav']
# ['Maxter Warjri and The Band']
# ['Somvir Kathurwal']
# ['Poirei Thokchom']
# ['Uyên Trang']
# ['Naveen Madhav']
# ['Adarsh Shinde']
# ['Nura M. Inuwa']
# ['B.A.D']
# ['Kuldeep Pattnaik']
# ['Nelly van Orsouw']
# ['Wanderley Andrade']
# ['Amrita Dixit']
# ['Nils Landgren']
# ['Sam Roberts Band']
# ['Colleen Green']
# ['Deep Money']
# ['Sofia Oportot']
# ['Kosla']
# ['Orchestra la storia di Romagna']
# ['genCAB']
# ['TARABAROVA']
# ['Marching Band']
# ['Siamak Abbasi']
# ['Karlis Lacis']
# ['Ədalət Şükürov']
# ['Valery Obodzinsky']
# ['Doris Dragović']
# ['BrisB']
# ['Kristine Xiong']
# ['Giao Linh']
# ['José Carbajal "El Sabalero"']
# ['Andrew Kishore']
# ['Cousin']
# ['Christian Delagrange']
# ['Anil']
# ['Philipp Kirkorov']
# ['Ulla Billquist']
# ['Kamal Khan']
# ['Emii']
# ['Salmo']
# ['Antoni Muracki']
# ['Burning Years']
# ["N'we Jinan Artists"]
# ['Sandro Lucio']
# ['Margie Segers']
# ['As Baías']
# ['R.Wan']
# ['MAG!C☆PRINCE']
# ['Happy Raikoti']
# ['3B junior']
# ['S Beater']
# ['Johane']
# ['Ras Sheehama']
# ['Suzy & Los Quattro']
# ['Gene Kasidit']
# ['Nasty Nesta']
# ['Gopal Rai']
# ['Klapa Cambi (Kaštel Kambelovac)']
# ['Fun As Thirty']
# ['Baryalai Samadi']
# ['Viky Moscholiou']
# ['Florin Chilian']
# ["Cheatin' at Solitaire"]
# ['Yang Soo Kyung']
# ['Jimmy C. Newman']
# ['Rezwana Choudhury Bannya']
# ['Roberto']
# ['Young LT']
# ['Yogendra Pushpam']
# ['Baru']
# ['Dexys Midnight Runners']
# ['Bark Bark Disco']
# ['Pino Villa']
# ['Bu TesLa']
# ['Kombi']
# ['Lefty Frizzell']
# ['Mahmeet Syed']
# ['Quang Dũng']
# ['Yung6ix']
# ['Fafá de Belém']
# ['Willie Tropu']
# ['Gana Bala']
# ['LEONARD KANIA']
# ['丸子']
# ['Lệ Thu']
# ['Linas Adomaitis']
# ['MABU']
# ['WITHDOM']
# ['Sardar Ali Takkar']
# ['Ibbe']
# ['Roberts Pētersons']
# ['TMP']
# ['Banex']
# ['발라드가수들']
# ['Moe Jidai Densetsu']
# ['Naiara Azevedo']
# ['Gabriele Parisi']
# ['ธานินทร์ อินทรเทพ']
# ['Silla and Rise']
# ['DI PANDA']
# ['eTunes']
# ['SuddenRush']
# ['片想い']
# ['Toni Soares']
# ['Larissa Luz']
# ['lvca']
# ['Mamraj Mamu']
# ['SAVI']
# ['Timoria']
# ['Noé Willer']
# ['Priyanka Singh']
# ['Vader Abraham']
# ['Chip Charlez']
# ['Tommy Roe']
# ['خميس ناجي']
# ['Damaris Elaine']
# ['Alberto Gomez']
# ['Sandeep Surila']
# ['Bastiram Lalariya']
# ['Gary Lewis & The Playboys']
# ['Vitor e Vanuti']
# ['Vander Lee']
# ['Supercombo']
# ['Habib Khan']
# ['Jefferson Moraes']
# ['the oto factory']
# ['Marta Bijan']
# ['Sam C.S.']
# ['Edson & Hudson']
# ['Sandhy Sondoro']
# ['Narender Ranjan']
# ['Pretenders']
# ['Angelica Vila']
# ['Kahitna']
# ['Alma Cogan']
# ['Neha Rajpal']
# ['Cristiano Araújo']
# ['Lakhwinder Wadali']
# ['Monika Verma']
# ['I Giocattoli']
# ['Aygün Səmədzadə']
# ['Ambar Malik']
# ['Real Numbers']
# ['Franka']
# ['Ko Htett']
# ['Nienke Plas']
# ['UMIE']
# ['Romey Maan']
# ['Ignacio Redard']
# ['Kishan Mahipal']
# ['TOKTAK ACE']
# ['Dhaval Kothari']
# ['Ethos']
# ['Golu Raja']
# ['ARTY']
# ['Chitapata Karnakar']
# ['Kumar Pritam']
# ['Emile S. Praja']
# ['Anti-Sociales']
# ['Rita Guerra']
# ['Agrupamento Musical Diapasão']
# ['Silva Hakobyan']
# ['Lawrence P Dsouza']
# ['Utain Prommin']
# ['DC DaVinci']
# ['UP UP GIRLS kakko KARI']
# ['Amy Obenski']
# ['Gibonni']
# ['Jonas Bergsten']
# ['Kai Winding']
# ['September Girls']
# ['Anastasia Prikhodko']
# ['Rico Dalasam']
# ['Forever']
# ['Juniper Moon']
# ['Leteći Odred']
# ['Ali Okapov']
# ['Trío Guadalajara']
# ['Remo']
# ['Mišo Kovač']
# ['Ильмира Нагимова']
# ['Adult Fur']
# ['Elohim']
# ['Farah Lal']
# ['No Monster Club']
# ['Esteban Klísich']
# ['Thin Lear']
# ['Mishon']
# ['Manjit Rupowalia']
# ['Riccardo Fogli']
# ['Kenny Fife']
# ['Louka']
# ['Daniel Peixoto']
# ['BAER']
# ['Todd Rundgren']
# ['Dan Black']
# ['Velmurugan']
# ['Jean Tan']
# ['Richhpal Dhaliwal']
# ['Horrible']
# ['Šaban Šaulić']
# ['La Fuente']
# ['Tóc Tiên']
# ['Zabala y Barrera']
# ['Александр Солодуха']
# ['Niggunei Satmar']
# ['Mi Mascota Leila']
# ['King Shaolin']
# ['Enzo Jannacci']
# ['Canto Cego']
# ['Guy2Bezbar']
# ['Sunrise In My Attache Case']
# ['Rafael Quadros']
# ['Consuelo Schuster']
# ['KC & The Sunshine Band']
# ['Dias Ablayev']
# ['街道办GDC']
# ['Skaldowie']
# ['Дервиши']
# ['Monsieur Lune']
# ['Frenéticas']
# ['Sandy Nelson']
# ["Trio Me' Bumba"]
# ['Alkawi']
# ['Michoel Schnitzler']
# ['Augusto Canário & Amigos']
# ['Chiddy Bang']
# ['PARAMANA STRANGERS']
# ['Holms']
# ['BEMINOR']
# ['Thanh Lam']
# ['Хавани Хажиева']
# ['Shatta Wale']
# ['Rahman Asadollahi']
# ['Yakubu Muhammad']
# ['Anh Khoa']
# ['Peronet e Izurieta']
# ['New Trolls']
# ['La Habitación Roja']
# ['D. Imman']
# ['Durazno']
# ['Lumaraa']
# ['Ruku Suna']
# ['Pretty Ricky']
# ['Harish Raghavendra']
# ['Captain Disko']
# ['Keshia Chanté']
# ['Me and Reas']
# ['Edu Krieger']
# ['Sailabhama']
# ['Manami Konishi']
# ['Sound Sultan']
# ['Wess']
# ['Cassette']
# ['Tami Aulia']
# ['Manke Nelis']
# ['Alice Guél']
# ['Angela Maria']
# ['Nursaç Doğanışık']
# ['Wizdom']
# ['Gian Pieretti']
# ['มหัศจรรย์ธรรมดา']
# ['De Marlets']
# ['Mats Paulson']
# ['Hiphop Tamizha']
# ['Güzide Kasacı']
# ['Frances White']
# ['Ministry of Idol']
# ['Flight 97']
# ['Durga Jasraj']
# ['Maria Cecília & Rodolfo']
# ['Dreyh']
# ['Pratagy']
# ['TEXTBOX']
# ['Digeer Soren']
# ['Chia Madani']
# ['Milva']
# ['Luis Alberto Posada']
# ['Burhan Toprak']
# ['Olimpo Cardenas']
# ['Joseph Krikorian']
# ['Hozan Şervan']
# ['Bibhu Kishore']
# ['Leon Markcus']
# ['Asif Akbar']
# ['Hozan Muzaffer']
# ['Alberto Cortez']
# ['平川美香']
# ['Sagar Janardhan']
# ['Jack Simard']
# ['C Sanga']
# ['Badassvon']
# ['Rafter']
# ['Baraka']
# ['Crod']
# ['Irma Libohova']
# ['Nonini Mgenge2Ru']
# ['The Smithereens']
# ['Ivo Robic']
# ['Sri Fayola']
# ['Anu Kadyan']
# ['POLY']
# ['Yossi Shtendig']
# ['Arthur White']
# ['Ruan Mikael']
# ['Ruchika Jangid']
# ['Sujatha']
# ['ZUNDARE']
# ['Kaushik Bharwad']
# ['Sgotti x Maggi']
# ['Murillo Zyess']
# ['Kaku Kanwar']
# ['Thaeme & Thiago']
# ['Henrique & Diego']

# %%
def bio(artist, api_key):
    url = 'http://ws.audioscrobbler.com/2.0/'
    params = {
        'method': 'artist.getinfo',
        'artist' : artist,
        'api_key': api_key,
        'format': 'json'
        }
    biografias = []
    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(f"Da error")
    else:
        datos = response.json()
        resumen = datos['artist']['bio']['summary']
        return resumen

# %%
resultados_nombres = []
limit = 200
contador = 0
for i in lista_artistas:
    if contador >= limit:
        break
    resumen = bio(i, api_key)
    resultados_nombres.append({
        'artista': i,
        'biografia': resumen
    })

    contador += 1

# %%
df = pd.DataFrame(resultados_nombres)

# %%
df
# Out:
#                 artista                                          biografia
# 0                [Gari]  There are several artists with this name.\n\n1...
# 1         [Joan Colomo]   <a href="https://www.last.fm/music/Joan+Colom...
# 2    [Familia Caamagno]   <a href="https://www.last.fm/music/Familia+Ca...
# 3       [Los Negativos]  Los Negativos es un grupo español de música ro...
# 4        [Igor Paskual]   <a href="https://www.last.fm/music/Igor+Pasku...
# ..                  ...                                                ...
# 195  [Jane's Addiction]  Jane's Addiction are an American alternative r...
# 196    [La Gossa Sorda]  La Gossa Sorda, translated as "The Deaf Dog"(r...
# 197       [Roger Usart]   <a href="https://www.last.fm/music/Roger+Usar...
# 198      [Jacobo Serra]   <a href="https://www.last.fm/music/Jacobo+Ser...
# 199            [Kokein]   <a href="https://www.last.fm/music/Kokein">Re...
#
# [200 rows x 2 columns]

# %% [markdown]
# ------------

# %%
# quitar corchetes

# %%
lista_artistas_limpia = [artista[0] if isinstance(artista, list) else artista for artista in lista_artistas]

# %%
df['artista'] = df['artista'].apply(lambda x: x[0] if isinstance(x, list) else x)

# %%
df
# Out:
#               artista                                          biografia
# 0                Gari  There are several artists with this name.\n\n1...
# 1         Joan Colomo   <a href="https://www.last.fm/music/Joan+Colom...
# 2    Familia Caamagno   <a href="https://www.last.fm/music/Familia+Ca...
# 3       Los Negativos  Los Negativos es un grupo español de música ro...
# 4        Igor Paskual   <a href="https://www.last.fm/music/Igor+Pasku...
# ..                ...                                                ...
# 195  Jane's Addiction  Jane's Addiction are an American alternative r...
# 196    La Gossa Sorda  La Gossa Sorda, translated as "The Deaf Dog"(r...
# 197       Roger Usart   <a href="https://www.last.fm/music/Roger+Usar...
# 198      Jacobo Serra   <a href="https://www.last.fm/music/Jacobo+Ser...
# 199            Kokein   <a href="https://www.last.fm/music/Kokein">Re...
#
# [200 rows x 2 columns]

# %%
df.to_csv('bio_rock.csv', index=False)
